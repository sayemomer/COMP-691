# %% [markdown]
# # **Week 2: Lab Exercises for COMP499/691 Conversational AI**

# %% [markdown]
# The goal of this lab is to familiarize yourself with SpeechBrain and its coding style.  Before starting, you should have read our basic tutorials (https://speechbrain.github.io/).
#
# ## **Exercise 1: Train an audio digit classifier**
#
# In this lab, you are going to write a full recipe in SpeechBrain. What we call *“recipe”* is the set of all the scripts (data preparation, training, hyperparameters) needed to train some model with some dataset.
#
# In this case, we will work on audio digit recognition using the [audio MNIST dataset](https://www.kaggle.com/datasets/alanchn31/free-spoken-digits). The input is a speech recording of a spoken digit, while the output is the corresponding number (between 0 and 9).

# %% [markdown]
# ![Untitled Diagram.drawio.png](data:image/png;base64,...)

# %% [markdown]
# **Run the code below** to install SpeechBrain:

# %%
# %%capture
# !pip install speechbrain

# %% [markdown]
# If everything works well, you should be able to import speechbrain like this:

# %%
import speechbrain

# %% [markdown]
# Let's also import some libraries that will be useful later

# %%
import torch
import torchaudio
import matplotlib.pyplot as plt
from IPython.display import Audio
torch.manual_seed(2023)

# %% [markdown]
# **Run the code below** to download the audio MNIST dataset. The dataset is quite big (downloading it might take a few minutes).

# %%
# !git clone https://github.com/soerenab/AudioMNIST /content/AudioMNIST
# Out:
# Cloning into '/content/AudioMNIST'...
# remote: Enumerating objects: 30128, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 30128 (delta 3), reused 5 (delta 1), pack-reused 30119 (from 1)
# Receiving objects: 100% (30128/30128), 944.54 MiB | 21.82 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Updating files: 100% (30018/30018), done.

# %% [markdown]
# ### **Exercise 1.1. Data Inspection**

# %% [markdown]
# Before starting, let's inspect a few data to ensure everything is fine.

# %% [markdown]
# **Write the code** to load a signal (i.e., `/content/AudioMNIST/data/01/0_01_0.wav`) using torchaudio. Print the audio shape and the sampling frequency. Plot the signal using matplotlib (take care of the audio shape before plotting it) and play it with Audio (see the speechbrain introduction tutorial to see an example of how to play signals with Audio).

# %%
# Your code here
audio_path = '/content/AudioMNIST/data/01/0_01_0.wav'
audio_shape,sampling_frequency = torchaudio.load(audio_path)
print(audio_shape.shape)
print(sampling_frequency)

plt.figure(figsize=(6, 4))
plt.plot(audio_shape.squeeze().numpy())
plt.grid()
plt.show()
# Out:
# torch.Size([1, 35877])
# 48000

# %% [markdown]
# If everything is fine, you should get the following output:

# %% [markdown]
# ```
# torch.Size([1, 35877])
# 48000
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's open another digit: `/content/AudioMNIST/data/60/9_60_9.wav`
#
#
# **Write the code** to load another signal (i.e., `/content/AudioMNIST/data/60/9_60_9.wav`) using torchaudio. Print the audio shape and the sampling frequency. Plot the signal using matplotlib (take care of the audio shape before plotting it) and play it with Audio (see the speechbrain introduction tutorial to see an example of how to play signals with Audio).

# %%
# Your code here
# Your code here
audio_path = '/content/AudioMNIST/data/60/9_60_9.wav'
audio_shape,sampling_frequency = torchaudio.load(audio_path)
print(audio_shape.shape)
print(sampling_frequency)

plt.figure(figsize=(6, 3))
plt.plot(audio_shape.squeeze().numpy())
plt.grid()
plt.show()
# Out:
# torch.Size([1, 34304])
# 48000

# %% [markdown]
# You should see the following:
#
# ```
# torch.Size([1, 34304])
# 48000
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Please, be aware of the following:
#
# *   The sampling frequency is 48 kHz. This rate is pretty high. Normally, working at 16 kHz is enough. We will downsample the signals on-the-fly n the training script directly.
#
# *  Each signal has a different shape. This is expected for audio signals because the signal varies in their length. SpeechBrain will create batches using random sentences and apply zero padding to match the longest sentence in the batch.
#
# * If you analyze the path of the audio signal, you can already retrieve the corresponding label. *Could you guess it?*

# %% [markdown]
# ###**Exercise 1.2. Data Preparation**
#
# The goal of this step is to create the data manifest files (in CSV format) that SpeechBrain expects in input. These files tell SpeechBrain where to find the speech data and their corresponding labels for the training, validation, and test sets.

# %% [markdown]
# First, let's get all the audio files into a list.
#
# **Complete the code below** to get a list of all the wav files in the `AudioMNIST/data` folder. Use the function [get_all_files](https://speechbrain.readthedocs.io/en/latest/API/speechbrain.utils.data_utils.html#speechbrain.utils.data_utils.get_all_files) from speechbrain.

# %%
from speechbrain.utils.data_utils import get_all_files

audiofiles = get_all_files('/content/AudioMNIST')

print(len(audiofiles))
# Out:
# 30044

# %% [markdown]
# If everything is fine, you should have 30000 files.
#
# The number of files is quite high and can make training slower. Just for this tutorial, we select a subset of it.
#
# In particular, we split the dataset in this way:
# - `training` with speakers from 1 to 10.
# - `validation` with speakers from 11 to 14.
# - `test` with speakers from 15 to 18.
#
# **Complete the code below** to split the data as mentioned above.

# %%
train_speakers = ['/01/','/02/','/03/','/04/','/05/','/06/','/07/','/08/','/09/','/10/']
valid_speakers = ['/11/','/12/','/13/','/14/']
test_speakers = ['/15/','/16/','/17/','/18/']

def split_data(audiofiles, spks):
  """This function takes in input a list of audio files and returns a list
  containing only files from the given list of speakers."""
  # Your code here. Aim for 5-6 lines
  filtered_speaker = []
  for file in audiofiles:
    for s in spks:
      if s in file:
        filtered_speaker.append(file)

  return filtered_speaker

# Splitting data
train_files = split_data(audiofiles, train_speakers)
valid_files = split_data(audiofiles, valid_speakers)
test_files = split_data(audiofiles, test_speakers)

print(len(train_files))
print(len(valid_files))
print(len(test_files))
# Out:
# 5000
# 2000
# 2000

# %% [markdown]
# If everything is fine, you should have 5000 (training), 2000 (validation), and 2000 (test) files.

# %% [markdown]
# Now, we can create the data-manifest files in JSON format for all these subsets.
#
# **Complete the code below** to create the data-manifest files. You can get the information needed to compute the duration in seconds (mandatory field) from `torchaudio.info`. Remember: the duration is the length of the signal divided by the sample rate. You also have to assign a unique id to each sentence. You can get the digit label from the audio path itself.
#
# *Running the code below might take a few minitues.*

# %%
print(train_files[0])
audio_shape, sample_rate = torchaudio.load(train_files[0])
print(audio_shape.shape[1]/sample_rate)
print(train_files[0].split("/")[-1].split("_")[0])
print(train_files[0].split("/")[-1])
# Out:
# /content/AudioMNIST/data/09/1_09_45.wav
# 0.6226041666666666
# 1
# 1_09_45.wav

# %%
import json

def create_json(json_file, audiolist):
  json_dict = {}
  for audiofile in audiolist:

    # Getting info
    audioinfo = audiofile

    # Compute the duration in seconds.
    # This is the number of samples divided by the sampling frequency
    waveform, sam_rate = torchaudio.load(audiofile)
    duration =  waveform.shape[1]/sam_rate

    # Get digit Label by manipulating the audio path
    digit =  audiofile.split("/")[-1].split("_")[0]

    # Get a unique utterance id
    uttid = audiofile.split("/")[-1]

    # Create entry for this utterance
    json_dict[uttid] = {
            "wav": audiofile,
            "length": duration,
            "digit": digit,
    }

    # Writing the dictionary to the json file
    with open(json_file, mode="w") as json_f:
      json.dump(json_dict, json_f, indent=2)


create_json('train.json', train_files)
create_json('valid.json', valid_files)
create_json('test.json', test_files)

    # Print the train.json file
with open('train.json', 'r') as json_f:
  train_data = json.load(json_f)  # Load the JSON content into a dictionary
  print(json.dumps(train_data, indent=2))  # Pretty print the JSON content
# Out:
# {
#   "1_09_45.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_45.wav",
#     "length": 0.6226041666666666,
#     "digit": "1"
#   },
#   "4_09_49.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_49.wav",
#     "length": 0.7732083333333334,
#     "digit": "4"
#   },
#   "8_09_17.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_17.wav",
#     "length": 0.5422916666666666,
#     "digit": "8"
#   },
#   "4_09_2.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_2.wav",
#     "length": 0.6891875,
#     "digit": "4"
#   },
#   "2_09_43.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_43.wav",
#     "length": 0.5986875,
#     "digit": "2"
#   },
#   "4_09_9.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_9.wav",
#     "length": 0.7628541666666667,
#     "digit": "4"
#   },
#   "6_09_23.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_23.wav",
#     "length": 0.896125,
#     "digit": "6"
#   },
#   "8_09_45.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_45.wav",
#     "length": 0.38685416666666667,
#     "digit": "8"
#   },
#   "6_09_13.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_13.wav",
#     "length": 0.8995416666666667,
#     "digit": "6"
#   },
#   "4_09_0.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_0.wav",
#     "length": 0.7436041666666666,
#     "digit": "4"
#   },
#   "9_09_45.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_45.wav",
#     "length": 0.73725,
#     "digit": "9"
#   },
#   "1_09_35.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_35.wav",
#     "length": 0.5995,
#     "digit": "1"
#   },
#   "3_09_3.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_3.wav",
#     "length": 0.688625,
#     "digit": "3"
#   },
#   "6_09_9.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_9.wav",
#     "length": 0.7594791666666667,
#     "digit": "6"
#   },
#   "8_09_37.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_37.wav",
#     "length": 0.36895833333333333,
#     "digit": "8"
#   },
#   "4_09_16.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_16.wav",
#     "length": 0.7426666666666667,
#     "digit": "4"
#   },
#   "4_09_42.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_42.wav",
#     "length": 0.8134166666666667,
#     "digit": "4"
#   },
#   "1_09_6.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_6.wav",
#     "length": 0.6686458333333334,
#     "digit": "1"
#   },
#   "3_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_26.wav",
#     "length": 0.6715208333333333,
#     "digit": "3"
#   },
#   "6_09_0.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_0.wav",
#     "length": 0.8269583333333334,
#     "digit": "6"
#   },
#   "4_09_18.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_18.wav",
#     "length": 0.7122916666666667,
#     "digit": "4"
#   },
#   "2_09_11.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_11.wav",
#     "length": 0.5192708333333333,
#     "digit": "2"
#   },
#   "2_09_19.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_19.wav",
#     "length": 0.45445833333333335,
#     "digit": "2"
#   },
#   "7_09_44.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_44.wav",
#     "length": 0.7646875,
#     "digit": "7"
#   },
#   "9_09_10.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_10.wav",
#     "length": 0.7163125,
#     "digit": "9"
#   },
#   "5_09_27.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_27.wav",
#     "length": 0.6148958333333333,
#     "digit": "5"
#   },
#   "8_09_49.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_49.wav",
#     "length": 0.5722916666666666,
#     "digit": "8"
#   },
#   "0_09_6.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_6.wav",
#     "length": 0.7875,
#     "digit": "0"
#   },
#   "4_09_10.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_10.wav",
#     "length": 0.559125,
#     "digit": "4"
#   },
#   "5_09_2.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_2.wav",
#     "length": 0.5900625,
#     "digit": "5"
#   },
#   "1_09_13.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_13.wav",
#     "length": 0.6575,
#     "digit": "1"
#   },
#   "7_09_13.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_13.wav",
#     "length": 0.7851458333333333,
#     "digit": "7"
#   },
#   "5_09_30.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_30.wav",
#     "length": 0.76025,
#     "digit": "5"
#   },
#   "1_09_43.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_43.wav",
#     "length": 0.6095416666666666,
#     "digit": "1"
#   },
#   "1_09_4.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_4.wav",
#     "length": 0.5761041666666666,
#     "digit": "1"
#   },
#   "7_09_1.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_1.wav",
#     "length": 0.7390208333333333,
#     "digit": "7"
#   },
#   "1_09_2.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_2.wav",
#     "length": 0.5955208333333334,
#     "digit": "1"
#   },
#   "5_09_29.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_29.wav",
#     "length": 0.7171458333333334,
#     "digit": "5"
#   },
#   "8_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_21.wav",
#     "length": 0.3735,
#     "digit": "8"
#   },
#   "9_09_13.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_13.wav",
#     "length": 0.7475208333333333,
#     "digit": "9"
#   },
#   "5_09_46.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_46.wav",
#     "length": 0.5673125,
#     "digit": "5"
#   },
#   "3_09_24.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_24.wav",
#     "length": 0.5738333333333333,
#     "digit": "3"
#   },
#   "6_09_42.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_42.wav",
#     "length": 0.724625,
#     "digit": "6"
#   },
#   "3_09_42.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_42.wav",
#     "length": 0.531,
#     "digit": "3"
#   },
#   "3_09_19.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_19.wav",
#     "length": 0.6253125,
#     "digit": "3"
#   },
#   "3_09_40.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_40.wav",
#     "length": 0.61425,
#     "digit": "3"
#   },
#   "0_09_44.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_44.wav",
#     "length": 0.7695625,
#     "digit": "0"
#   },
#   "1_09_34.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_34.wav",
#     "length": 0.6247291666666667,
#     "digit": "1"
#   },
#   "5_09_15.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_15.wav",
#     "length": 0.7610416666666666,
#     "digit": "5"
#   },
#   "1_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_38.wav",
#     "length": 0.5705625,
#     "digit": "1"
#   },
#   "1_09_29.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_29.wav",
#     "length": 0.6279375,
#     "digit": "1"
#   },
#   "9_09_30.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_30.wav",
#     "length": 0.6628541666666666,
#     "digit": "9"
#   },
#   "9_09_8.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_8.wav",
#     "length": 0.7055,
#     "digit": "9"
#   },
#   "9_09_5.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_5.wav",
#     "length": 0.8429791666666666,
#     "digit": "9"
#   },
#   "2_09_25.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_25.wav",
#     "length": 0.6525,
#     "digit": "2"
#   },
#   "2_09_14.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_14.wav",
#     "length": 0.5835,
#     "digit": "2"
#   },
#   "6_09_49.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_49.wav",
#     "length": 0.8191666666666667,
#     "digit": "6"
#   },
#   "4_09_23.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_23.wav",
#     "length": 0.7979583333333333,
#     "digit": "4"
#   },
#   "7_09_8.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_8.wav",
#     "length": 0.7756458333333334,
#     "digit": "7"
#   },
#   "8_09_2.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_2.wav",
#     "length": 0.3927291666666667,
#     "digit": "8"
#   },
#   "9_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_38.wav",
#     "length": 0.668125,
#     "digit": "9"
#   },
#   "1_09_40.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_40.wav",
#     "length": 0.6154166666666666,
#     "digit": "1"
#   },
#   "1_09_16.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_16.wav",
#     "length": 0.6606458333333334,
#     "digit": "1"
#   },
#   "2_09_0.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_0.wav",
#     "length": 0.49927083333333333,
#     "digit": "2"
#   },
#   "7_09_14.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_14.wav",
#     "length": 0.8770833333333333,
#     "digit": "7"
#   },
#   "7_09_47.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_47.wav",
#     "length": 0.8383125,
#     "digit": "7"
#   },
#   "0_09_29.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_29.wav",
#     "length": 0.8927916666666667,
#     "digit": "0"
#   },
#   "8_09_5.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_5.wav",
#     "length": 0.598,
#     "digit": "8"
#   },
#   "1_09_11.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_11.wav",
#     "length": 0.6001875,
#     "digit": "1"
#   },
#   "2_09_44.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_44.wav",
#     "length": 0.5440625,
#     "digit": "2"
#   },
#   "1_09_15.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_15.wav",
#     "length": 0.6817083333333334,
#     "digit": "1"
#   },
#   "7_09_10.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_10.wav",
#     "length": 0.8201875,
#     "digit": "7"
#   },
#   "3_09_36.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_36.wav",
#     "length": 0.5898333333333333,
#     "digit": "3"
#   },
#   "7_09_12.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_12.wav",
#     "length": 0.74825,
#     "digit": "7"
#   },
#   "8_09_23.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_23.wav",
#     "length": 0.38183333333333336,
#     "digit": "8"
#   },
#   "3_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_38.wav",
#     "length": 0.5638541666666667,
#     "digit": "3"
#   },
#   "7_09_31.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_31.wav",
#     "length": 0.7586041666666666,
#     "digit": "7"
#   },
#   "9_09_9.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_9.wav",
#     "length": 0.7865208333333333,
#     "digit": "9"
#   },
#   "6_09_37.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_37.wav",
#     "length": 0.6610416666666666,
#     "digit": "6"
#   },
#   "8_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_38.wav",
#     "length": 0.3847083333333333,
#     "digit": "8"
#   },
#   "8_09_41.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_41.wav",
#     "length": 0.4027291666666667,
#     "digit": "8"
#   },
#   "0_09_13.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_13.wav",
#     "length": 0.7335625,
#     "digit": "0"
#   },
#   "2_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_26.wav",
#     "length": 0.5247083333333333,
#     "digit": "2"
#   },
#   "0_09_12.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_12.wav",
#     "length": 0.8447916666666667,
#     "digit": "0"
#   },
#   "3_09_20.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_20.wav",
#     "length": 0.6220416666666667,
#     "digit": "3"
#   },
#   "0_09_4.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_4.wav",
#     "length": 0.9361458333333333,
#     "digit": "0"
#   },
#   "6_09_20.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_20.wav",
#     "length": 0.7599583333333333,
#     "digit": "6"
#   },
#   "6_09_32.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_32.wav",
#     "length": 0.8380208333333333,
#     "digit": "6"
#   },
#   "4_09_3.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_3.wav",
#     "length": 0.6791041666666666,
#     "digit": "4"
#   },
#   "3_09_47.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_47.wav",
#     "length": 0.5468958333333334,
#     "digit": "3"
#   },
#   "3_09_45.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_45.wav",
#     "length": 0.493,
#     "digit": "3"
#   },
#   "6_09_1.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_1.wav",
#     "length": 0.8149791666666667,
#     "digit": "6"
#   },
#   "6_09_6.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_6.wav",
#     "length": 0.7648541666666666,
#     "digit": "6"
#   },
#   "8_09_4.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_4.wav",
#     "length": 0.392625,
#     "digit": "8"
#   },
#   "8_09_30.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_30.wav",
#     "length": 0.37414583333333334,
#     "digit": "8"
#   },
#   "5_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_21.wav",
#     "length": 0.7125833333333333,
#     "digit": "5"
#   },
#   "2_09_4.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_4.wav",
#     "length": 0.5728125,
#     "digit": "2"
#   },
#   "2_09_5.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_5.wav",
#     "length": 0.5672708333333333,
#     "digit": "2"
#   },
#   "0_09_28.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_28.wav",
#     "length": 0.774625,
#     "digit": "0"
#   },
#   "0_09_47.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_47.wav",
#     "length": 0.7810833333333334,
#     "digit": "0"
#   },
#   "9_09_33.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_33.wav",
#     "length": 0.7242708333333333,
#     "digit": "9"
#   },
#   "4_09_41.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_41.wav",
#     "length": 0.874375,
#     "digit": "4"
#   },
#   "2_09_12.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_12.wav",
#     "length": 0.5761041666666666,
#     "digit": "2"
#   },
#   "4_09_48.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_48.wav",
#     "length": 0.7834791666666666,
#     "digit": "4"
#   },
#   "3_09_48.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_48.wav",
#     "length": 0.6247708333333334,
#     "digit": "3"
#   },
#   "2_09_22.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_22.wav",
#     "length": 0.58575,
#     "digit": "2"
#   },
#   "4_09_28.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_28.wav",
#     "length": 0.6564375,
#     "digit": "4"
#   },
#   "4_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_38.wav",
#     "length": 0.7581041666666667,
#     "digit": "4"
#   },
#   "4_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_26.wav",
#     "length": 0.8120833333333334,
#     "digit": "4"
#   },
#   "5_09_25.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_25.wav",
#     "length": 0.62575,
#     "digit": "5"
#   },
#   "5_09_37.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_37.wav",
#     "length": 0.7697291666666667,
#     "digit": "5"
#   },
#   "0_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_21.wav",
#     "length": 0.7633125,
#     "digit": "0"
#   },
#   "9_09_18.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_18.wav",
#     "length": 0.7237083333333333,
#     "digit": "9"
#   },
#   "7_09_34.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_34.wav",
#     "length": 0.79625,
#     "digit": "7"
#   },
#   "2_09_27.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_27.wav",
#     "length": 0.5240833333333333,
#     "digit": "2"
#   },
#   "8_09_22.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_22.wav",
#     "length": 0.60425,
#     "digit": "8"
#   },
#   "0_09_22.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_22.wav",
#     "length": 0.8680416666666667,
#     "digit": "0"
#   },
#   "4_09_20.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_20.wav",
#     "length": 0.6757291666666667,
#     "digit": "4"
#   },
#   "8_09_34.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_34.wav",
#     "length": 0.39727083333333335,
#     "digit": "8"
#   },
#   "7_09_27.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_27.wav",
#     "length": 0.7436458333333333,
#     "digit": "7"
#   },
#   "5_09_11.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_11.wav",
#     "length": 0.7410208333333334,
#     "digit": "5"
#   },
#   "4_09_15.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_15.wav",
#     "length": 0.6668333333333333,
#     "digit": "4"
#   },
#   "5_09_20.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_20.wav",
#     "length": 0.7239166666666667,
#     "digit": "5"
#   },
#   "0_09_48.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_48.wav",
#     "length": 0.8730833333333333,
#     "digit": "0"
#   },
#   "0_09_9.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_9.wav",
#     "length": 0.753,
#     "digit": "0"
#   },
#   "9_09_24.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_24.wav",
#     "length": 0.7362708333333333,
#     "digit": "9"
#   },
#   "0_09_49.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_49.wav",
#     "length": 0.7868541666666666,
#     "digit": "0"
#   },
#   "3_09_32.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_32.wav",
#     "length": 0.5291666666666667,
#     "digit": "3"
#   },
#   "9_09_37.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_37.wav",
#     "length": 0.6399166666666667,
#     "digit": "9"
#   },
#   "1_09_14.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_14.wav",
#     "length": 0.6330625,
#     "digit": "1"
#   },
#   "0_09_5.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_5.wav",
#     "length": 0.8542708333333333,
#     "digit": "0"
#   },
#   "0_09_8.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_8.wav",
#     "length": 0.7992708333333334,
#     "digit": "0"
#   },
#   "8_09_15.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_15.wav",
#     "length": 0.530625,
#     "digit": "8"
#   },
#   "8_09_16.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_16.wav",
#     "length": 0.372375,
#     "digit": "8"
#   },
#   "3_09_31.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_31.wav",
#     "length": 0.67825,
#     "digit": "3"
#   },
#   "8_09_42.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_42.wav",
#     "length": 0.5335208333333333,
#     "digit": "8"
#   },
#   "1_09_10.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_10.wav",
#     "length": 0.6227083333333333,
#     "digit": "1"
#   },
#   "4_09_36.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_36.wav",
#     "length": 0.8202708333333333,
#     "digit": "4"
#   },
#   "4_09_19.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_19.wav",
#     "length": 0.6474791666666667,
#     "digit": "4"
#   },
#   "6_09_17.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_17.wav",
#     "length": 0.8389375,
#     "digit": "6"
#   },
#   "6_09_2.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_2.wav",
#     "length": 0.9250833333333334,
#     "digit": "6"
#   },
#   "4_09_17.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_17.wav",
#     "length": 0.7569791666666666,
#     "digit": "4"
#   },
#   "2_09_15.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_15.wav",
#     "length": 0.5575208333333334,
#     "digit": "2"
#   },
#   "4_09_1.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_1.wav",
#     "length": 0.6647083333333333,
#     "digit": "4"
#   },
#   "3_09_12.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_12.wav",
#     "length": 0.6966875,
#     "digit": "3"
#   },
#   "7_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_26.wav",
#     "length": 0.77825,
#     "digit": "7"
#   },
#   "7_09_28.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_28.wav",
#     "length": 0.8816666666666667,
#     "digit": "7"
#   },
#   "8_09_44.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_44.wav",
#     "length": 0.3973333333333333,
#     "digit": "8"
#   },
#   "9_09_19.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_19.wav",
#     "length": 0.748,
#     "digit": "9"
#   },
#   "5_09_10.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_10.wav",
#     "length": 0.5577291666666667,
#     "digit": "5"
#   },
#   "0_09_32.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_32.wav",
#     "length": 0.76375,
#     "digit": "0"
#   },
#   "3_09_7.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_7.wav",
#     "length": 0.5753333333333334,
#     "digit": "3"
#   },
#   "7_09_49.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_49.wav",
#     "length": 0.7539166666666667,
#     "digit": "7"
#   },
#   "4_09_24.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_24.wav",
#     "length": 0.7793125,
#     "digit": "4"
#   },
#   "3_09_43.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_43.wav",
#     "length": 0.7353541666666666,
#     "digit": "3"
#   },
#   "7_09_3.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_3.wav",
#     "length": 0.771625,
#     "digit": "7"
#   },
#   "3_09_25.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_25.wav",
#     "length": 0.6189166666666667,
#     "digit": "3"
#   },
#   "3_09_39.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_39.wav",
#     "length": 0.6635,
#     "digit": "3"
#   },
#   "6_09_5.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_5.wav",
#     "length": 0.9148333333333334,
#     "digit": "6"
#   },
#   "4_09_37.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_37.wav",
#     "length": 0.653375,
#     "digit": "4"
#   },
#   "6_09_12.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_12.wav",
#     "length": 0.7422916666666667,
#     "digit": "6"
#   },
#   "0_09_0.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_0.wav",
#     "length": 0.8298125,
#     "digit": "0"
#   },
#   "5_09_8.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_8.wav",
#     "length": 0.6737916666666667,
#     "digit": "5"
#   },
#   "4_09_27.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_27.wav",
#     "length": 0.8077083333333334,
#     "digit": "4"
#   },
#   "3_09_27.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_27.wav",
#     "length": 0.6859375,
#     "digit": "3"
#   },
#   "4_09_44.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_44.wav",
#     "length": 0.7273333333333334,
#     "digit": "4"
#   },
#   "2_09_40.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_40.wav",
#     "length": 0.47433333333333333,
#     "digit": "2"
#   },
#   "6_09_18.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_18.wav",
#     "length": 0.9462708333333333,
#     "digit": "6"
#   },
#   "6_09_40.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_40.wav",
#     "length": 0.8534375,
#     "digit": "6"
#   },
#   "2_09_10.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_10.wav",
#     "length": 0.5312291666666666,
#     "digit": "2"
#   },
#   "1_09_24.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_24.wav",
#     "length": 0.6904166666666667,
#     "digit": "1"
#   },
#   "8_09_36.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_36.wav",
#     "length": 0.5569166666666666,
#     "digit": "8"
#   },
#   "7_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_38.wav",
#     "length": 0.9196666666666666,
#     "digit": "7"
#   },
#   "6_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_26.wav",
#     "length": 0.8212708333333333,
#     "digit": "6"
#   },
#   "3_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_21.wav",
#     "length": 0.6508958333333333,
#     "digit": "3"
#   },
#   "1_09_19.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_19.wav",
#     "length": 0.6854791666666666,
#     "digit": "1"
#   },
#   "7_09_6.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_6.wav",
#     "length": 0.7538333333333334,
#     "digit": "7"
#   },
#   "6_09_25.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_25.wav",
#     "length": 0.807125,
#     "digit": "6"
#   },
#   "1_09_44.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_44.wav",
#     "length": 0.6213958333333334,
#     "digit": "1"
#   },
#   "0_09_2.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_2.wav",
#     "length": 0.8803541666666667,
#     "digit": "0"
#   },
#   "9_09_35.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_35.wav",
#     "length": 0.803875,
#     "digit": "9"
#   },
#   "8_09_43.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_43.wav",
#     "length": 0.37895833333333334,
#     "digit": "8"
#   },
#   "1_09_17.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_17.wav",
#     "length": 0.5638958333333334,
#     "digit": "1"
#   },
#   "1_09_39.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_39.wav",
#     "length": 0.6355625,
#     "digit": "1"
#   },
#   "7_09_30.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_30.wav",
#     "length": 0.8839375,
#     "digit": "7"
#   },
#   "7_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_21.wav",
#     "length": 0.848,
#     "digit": "7"
#   },
#   "5_09_19.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_19.wav",
#     "length": 0.8658541666666667,
#     "digit": "5"
#   },
#   "3_09_18.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_18.wav",
#     "length": 0.730125,
#     "digit": "3"
#   },
#   "8_09_48.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_48.wav",
#     "length": 0.52975,
#     "digit": "8"
#   },
#   "7_09_7.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_7.wav",
#     "length": 0.7802083333333333,
#     "digit": "7"
#   },
#   "9_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_26.wav",
#     "length": 0.71275,
#     "digit": "9"
#   },
#   "6_09_10.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_10.wav",
#     "length": 0.9067916666666667,
#     "digit": "6"
#   },
#   "1_09_28.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_28.wav",
#     "length": 0.61375,
#     "digit": "1"
#   },
#   "2_09_29.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_29.wav",
#     "length": 0.49502083333333335,
#     "digit": "2"
#   },
#   "6_09_22.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_22.wav",
#     "length": 0.8938125,
#     "digit": "6"
#   },
#   "0_09_43.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_43.wav",
#     "length": 0.7559375,
#     "digit": "0"
#   },
#   "2_09_23.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_23.wav",
#     "length": 0.5803958333333333,
#     "digit": "2"
#   },
#   "4_09_30.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_30.wav",
#     "length": 0.7143541666666666,
#     "digit": "4"
#   },
#   "5_09_18.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_18.wav",
#     "length": 0.6798125,
#     "digit": "5"
#   },
#   "9_09_28.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_28.wav",
#     "length": 0.7245,
#     "digit": "9"
#   },
#   "0_09_46.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_46.wav",
#     "length": 0.8985833333333333,
#     "digit": "0"
#   },
#   "8_09_6.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_6.wav",
#     "length": 0.42825,
#     "digit": "8"
#   },
#   "6_09_47.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_47.wav",
#     "length": 0.7734791666666667,
#     "digit": "6"
#   },
#   "7_09_32.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_32.wav",
#     "length": 0.7092708333333333,
#     "digit": "7"
#   },
#   "7_09_40.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_40.wav",
#     "length": 0.7918125,
#     "digit": "7"
#   },
#   "9_09_36.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_36.wav",
#     "length": 0.8111666666666667,
#     "digit": "9"
#   },
#   "5_09_0.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_0.wav",
#     "length": 0.6012708333333333,
#     "digit": "5"
#   },
#   "7_09_9.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_9.wav",
#     "length": 0.7695833333333333,
#     "digit": "7"
#   },
#   "2_09_33.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_33.wav",
#     "length": 0.6663333333333333,
#     "digit": "2"
#   },
#   "5_09_28.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_28.wav",
#     "length": 0.7460833333333333,
#     "digit": "5"
#   },
#   "9_09_15.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_15.wav",
#     "length": 0.7980208333333333,
#     "digit": "9"
#   },
#   "7_09_41.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_41.wav",
#     "length": 0.7902708333333334,
#     "digit": "7"
#   },
#   "2_09_41.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_41.wav",
#     "length": 0.46558333333333335,
#     "digit": "2"
#   },
#   "0_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_26.wav",
#     "length": 0.8142708333333334,
#     "digit": "0"
#   },
#   "0_09_36.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_36.wav",
#     "length": 0.7267708333333334,
#     "digit": "0"
#   },
#   "5_09_6.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_6.wav",
#     "length": 0.7287916666666666,
#     "digit": "5"
#   },
#   "2_09_2.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_2.wav",
#     "length": 0.5544166666666667,
#     "digit": "2"
#   },
#   "6_09_27.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_27.wav",
#     "length": 0.8525416666666666,
#     "digit": "6"
#   },
#   "0_09_10.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_10.wav",
#     "length": 0.7658541666666666,
#     "digit": "0"
#   },
#   "3_09_37.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_37.wav",
#     "length": 0.6134166666666667,
#     "digit": "3"
#   },
#   "4_09_6.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_6.wav",
#     "length": 0.8959375,
#     "digit": "4"
#   },
#   "2_09_9.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_9.wav",
#     "length": 0.4870625,
#     "digit": "2"
#   },
#   "5_09_49.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_49.wav",
#     "length": 0.8581666666666666,
#     "digit": "5"
#   },
#   "7_09_22.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_22.wav",
#     "length": 0.8152916666666666,
#     "digit": "7"
#   },
#   "0_09_20.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_20.wav",
#     "length": 0.8530416666666667,
#     "digit": "0"
#   },
#   "2_09_32.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_32.wav",
#     "length": 0.605625,
#     "digit": "2"
#   },
#   "1_09_37.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_37.wav",
#     "length": 0.6974166666666667,
#     "digit": "1"
#   },
#   "0_09_27.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_27.wav",
#     "length": 0.7286458333333333,
#     "digit": "0"
#   },
#   "4_09_31.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_31.wav",
#     "length": 0.767,
#     "digit": "4"
#   },
#   "0_09_41.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_41.wav",
#     "length": 0.74625,
#     "digit": "0"
#   },
#   "2_09_46.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_46.wav",
#     "length": 0.5669791666666667,
#     "digit": "2"
#   },
#   "6_09_24.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_24.wav",
#     "length": 0.7286041666666667,
#     "digit": "6"
#   },
#   "7_09_36.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_36.wav",
#     "length": 0.74925,
#     "digit": "7"
#   },
#   "3_09_11.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_11.wav",
#     "length": 0.5585208333333334,
#     "digit": "3"
#   },
#   "7_09_4.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_4.wav",
#     "length": 0.8084583333333333,
#     "digit": "7"
#   },
#   "6_09_43.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_43.wav",
#     "length": 0.8520625,
#     "digit": "6"
#   },
#   "9_09_0.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_0.wav",
#     "length": 0.6658125,
#     "digit": "9"
#   },
#   "4_09_34.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_34.wav",
#     "length": 0.7784583333333334,
#     "digit": "4"
#   },
#   "8_09_3.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_3.wav",
#     "length": 0.5718958333333334,
#     "digit": "8"
#   },
#   "6_09_28.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_28.wav",
#     "length": 0.7747291666666667,
#     "digit": "6"
#   },
#   "7_09_17.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_17.wav",
#     "length": 0.7730625,
#     "digit": "7"
#   },
#   "4_09_8.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_8.wav",
#     "length": 0.5688541666666667,
#     "digit": "4"
#   },
#   "0_09_1.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_1.wav",
#     "length": 0.7639166666666667,
#     "digit": "0"
#   },
#   "4_09_45.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_45.wav",
#     "length": 0.7919791666666667,
#     "digit": "4"
#   },
#   "7_09_5.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_5.wav",
#     "length": 0.7770208333333334,
#     "digit": "7"
#   },
#   "2_09_7.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_7.wav",
#     "length": 0.4303125,
#     "digit": "2"
#   },
#   "2_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_21.wav",
#     "length": 0.5366041666666667,
#     "digit": "2"
#   },
#   "5_09_1.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_1.wav",
#     "length": 0.77975,
#     "digit": "5"
#   },
#   "8_09_40.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_40.wav",
#     "length": 0.542,
#     "digit": "8"
#   },
#   "7_09_15.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_15.wav",
#     "length": 0.7316041666666667,
#     "digit": "7"
#   },
#   "1_09_49.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_49.wav",
#     "length": 0.6377708333333333,
#     "digit": "1"
#   },
#   "0_09_7.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_7.wav",
#     "length": 0.7925625,
#     "digit": "0"
#   },
#   "2_09_49.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_49.wav",
#     "length": 0.48020833333333335,
#     "digit": "2"
#   },
#   "9_09_7.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_7.wav",
#     "length": 0.7726666666666666,
#     "digit": "9"
#   },
#   "5_09_16.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_16.wav",
#     "length": 0.6467291666666667,
#     "digit": "5"
#   },
#   "8_09_19.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_19.wav",
#     "length": 0.381875,
#     "digit": "8"
#   },
#   "1_09_8.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_8.wav",
#     "length": 0.6201875,
#     "digit": "1"
#   },
#   "5_09_12.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_12.wav",
#     "length": 0.7672916666666667,
#     "digit": "5"
#   },
#   "1_09_9.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_9.wav",
#     "length": 0.5949583333333334,
#     "digit": "1"
#   },
#   "6_09_3.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_3.wav",
#     "length": 0.7709375,
#     "digit": "6"
#   },
#   "2_09_6.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_6.wav",
#     "length": 0.5945208333333334,
#     "digit": "2"
#   },
#   "8_09_24.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_24.wav",
#     "length": 0.5186041666666666,
#     "digit": "8"
#   },
#   "4_09_5.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_5.wav",
#     "length": 0.7502291666666666,
#     "digit": "4"
#   },
#   "7_09_48.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_48.wav",
#     "length": 0.8079583333333333,
#     "digit": "7"
#   },
#   "1_09_7.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_7.wav",
#     "length": 0.5847708333333334,
#     "digit": "1"
#   },
#   "6_09_4.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_4.wav",
#     "length": 0.7529375,
#     "digit": "6"
#   },
#   "0_09_16.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_16.wav",
#     "length": 0.7981041666666666,
#     "digit": "0"
#   },
#   "9_09_22.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_22.wav",
#     "length": 0.687125,
#     "digit": "9"
#   },
#   "2_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_38.wav",
#     "length": 0.48720833333333335,
#     "digit": "2"
#   },
#   "8_09_14.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_14.wav",
#     "length": 0.5673333333333334,
#     "digit": "8"
#   },
#   "8_09_46.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_46.wav",
#     "length": 0.3935625,
#     "digit": "8"
#   },
#   "0_09_18.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_18.wav",
#     "length": 0.8536875,
#     "digit": "0"
#   },
#   "1_09_36.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_36.wav",
#     "length": 0.633125,
#     "digit": "1"
#   },
#   "9_09_3.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_3.wav",
#     "length": 0.7261458333333334,
#     "digit": "9"
#   },
#   "8_09_13.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_13.wav",
#     "length": 0.37975,
#     "digit": "8"
#   },
#   "8_09_47.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_47.wav",
#     "length": 0.4114583333333333,
#     "digit": "8"
#   },
#   "3_09_10.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_10.wav",
#     "length": 0.7216666666666667,
#     "digit": "3"
#   },
#   "4_09_25.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_25.wav",
#     "length": 0.75075,
#     "digit": "4"
#   },
#   "9_09_4.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_4.wav",
#     "length": 0.788625,
#     "digit": "9"
#   },
#   "9_09_46.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_46.wav",
#     "length": 0.7149375,
#     "digit": "9"
#   },
#   "7_09_33.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_33.wav",
#     "length": 0.8229166666666666,
#     "digit": "7"
#   },
#   "3_09_22.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_22.wav",
#     "length": 0.6411666666666667,
#     "digit": "3"
#   },
#   "0_09_34.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_34.wav",
#     "length": 0.921875,
#     "digit": "0"
#   },
#   "3_09_30.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_30.wav",
#     "length": 0.6715208333333333,
#     "digit": "3"
#   },
#   "4_09_40.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_40.wav",
#     "length": 0.6927916666666667,
#     "digit": "4"
#   },
#   "5_09_9.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_9.wav",
#     "length": 0.7980416666666666,
#     "digit": "5"
#   },
#   "4_09_39.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_39.wav",
#     "length": 0.7891875,
#     "digit": "4"
#   },
#   "8_09_35.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_35.wav",
#     "length": 0.36160416666666667,
#     "digit": "8"
#   },
#   "8_09_12.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_12.wav",
#     "length": 0.3928125,
#     "digit": "8"
#   },
#   "7_09_45.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_45.wav",
#     "length": 0.8106041666666667,
#     "digit": "7"
#   },
#   "8_09_0.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_0.wav",
#     "length": 0.3981458333333333,
#     "digit": "8"
#   },
#   "5_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_26.wav",
#     "length": 0.7871041666666667,
#     "digit": "5"
#   },
#   "4_09_46.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_46.wav",
#     "length": 0.7020416666666667,
#     "digit": "4"
#   },
#   "9_09_12.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_12.wav",
#     "length": 0.7686875,
#     "digit": "9"
#   },
#   "2_09_37.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_37.wav",
#     "length": 0.5675,
#     "digit": "2"
#   },
#   "6_09_11.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_11.wav",
#     "length": 0.7858333333333334,
#     "digit": "6"
#   },
#   "8_09_31.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_31.wav",
#     "length": 0.42275,
#     "digit": "8"
#   },
#   "9_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_21.wav",
#     "length": 0.7905208333333333,
#     "digit": "9"
#   },
#   "1_09_41.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_41.wav",
#     "length": 0.6123958333333334,
#     "digit": "1"
#   },
#   "0_09_23.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_23.wav",
#     "length": 0.719625,
#     "digit": "0"
#   },
#   "2_09_8.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_8.wav",
#     "length": 0.582,
#     "digit": "2"
#   },
#   "2_09_3.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_3.wav",
#     "length": 0.4410833333333333,
#     "digit": "2"
#   },
#   "6_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_38.wav",
#     "length": 0.8543958333333334,
#     "digit": "6"
#   },
#   "6_09_35.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_35.wav",
#     "length": 0.8125208333333334,
#     "digit": "6"
#   },
#   "4_09_35.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_35.wav",
#     "length": 0.7138125,
#     "digit": "4"
#   },
#   "1_09_32.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_32.wav",
#     "length": 0.6581875,
#     "digit": "1"
#   },
#   "8_09_20.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_20.wav",
#     "length": 0.3665833333333333,
#     "digit": "8"
#   },
#   "5_09_44.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_44.wav",
#     "length": 0.5767083333333334,
#     "digit": "5"
#   },
#   "1_09_46.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_46.wav",
#     "length": 0.6627083333333333,
#     "digit": "1"
#   },
#   "6_09_7.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_7.wav",
#     "length": 0.7374583333333333,
#     "digit": "6"
#   },
#   "9_09_49.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_49.wav",
#     "length": 0.7197708333333334,
#     "digit": "9"
#   },
#   "5_09_35.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_35.wav",
#     "length": 0.7705625,
#     "digit": "5"
#   },
#   "7_09_25.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_25.wav",
#     "length": 0.7333958333333334,
#     "digit": "7"
#   },
#   "7_09_0.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_0.wav",
#     "length": 0.8328125,
#     "digit": "7"
#   },
#   "1_09_25.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_25.wav",
#     "length": 0.616625,
#     "digit": "1"
#   },
#   "8_09_18.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_18.wav",
#     "length": 0.639125,
#     "digit": "8"
#   },
#   "5_09_17.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_17.wav",
#     "length": 0.7427708333333334,
#     "digit": "5"
#   },
#   "9_09_47.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_47.wav",
#     "length": 0.7688958333333333,
#     "digit": "9"
#   },
#   "0_09_37.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_37.wav",
#     "length": 0.8801458333333333,
#     "digit": "0"
#   },
#   "5_09_33.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_33.wav",
#     "length": 0.5605416666666667,
#     "digit": "5"
#   },
#   "5_09_4.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_4.wav",
#     "length": 0.5456666666666666,
#     "digit": "5"
#   },
#   "8_09_27.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_27.wav",
#     "length": 0.5286458333333334,
#     "digit": "8"
#   },
#   "7_09_18.wav": {
#     "wav": "/content/AudioMNIST/data/09/7_09_18.wav",
#     "length": 0.7628333333333334,
#     "digit": "7"
#   },
#   "3_09_1.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_1.wav",
#     "length": 0.5270625,
#     "digit": "3"
#   },
#   "9_09_27.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_27.wav",
#     "length": 0.7706458333333334,
#     "digit": "9"
#   },
#   "5_09_40.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_40.wav",
#     "length": 0.7937916666666667,
#     "digit": "5"
#   },
#   "5_09_7.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_7.wav",
#     "length": 0.8606666666666667,
#     "digit": "5"
#   },
#   "9_09_11.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_11.wav",
#     "length": 0.8170416666666667,
#     "digit": "9"
#   },
#   "2_09_30.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_30.wav",
#     "length": 0.5894583333333333,
#     "digit": "2"
#   },
#   "5_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_38.wav",
#     "length": 0.7807291666666667,
#     "digit": "5"
#   },
#   "8_09_28.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_28.wav",
#     "length": 0.47570833333333334,
#     "digit": "8"
#   },
#   "5_09_14.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_14.wav",
#     "length": 0.6692708333333334,
#     "digit": "5"
#   },
#   "9_09_44.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_44.wav",
#     "length": 0.7188333333333333,
#     "digit": "9"
#   },
#   "6_09_45.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_45.wav",
#     "length": 0.858,
#     "digit": "6"
#   },
#   "6_09_16.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_16.wav",
#     "length": 0.7720625,
#     "digit": "6"
#   },
#   "8_09_32.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_32.wav",
#     "length": 0.4035,
#     "digit": "8"
#   },
#   "5_09_47.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_47.wav",
#     "length": 0.8239166666666666,
#     "digit": "5"
#   },
#   "1_09_23.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_23.wav",
#     "length": 0.672625,
#     "digit": "1"
#   },
#   "9_09_43.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_43.wav",
#     "length": 0.76575,
#     "digit": "9"
#   },
#   "6_09_46.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_46.wav",
#     "length": 0.9152291666666666,
#     "digit": "6"
#   },
#   "4_09_14.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_14.wav",
#     "length": 0.8164583333333333,
#     "digit": "4"
#   },
#   "5_09_5.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_5.wav",
#     "length": 0.8105833333333333,
#     "digit": "5"
#   },
#   "3_09_35.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_35.wav",
#     "length": 0.551,
#     "digit": "3"
#   },
#   "4_09_33.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_33.wav",
#     "length": 0.67725,
#     "digit": "4"
#   },
#   "6_09_8.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_8.wav",
#     "length": 0.9935416666666667,
#     "digit": "6"
#   },
#   "9_09_48.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_48.wav",
#     "length": 0.695125,
#     "digit": "9"
#   },
#   "3_09_29.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_29.wav",
#     "length": 0.6741458333333333,
#     "digit": "3"
#   },
#   "2_09_16.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_16.wav",
#     "length": 0.4987916666666667,
#     "digit": "2"
#   },
#   "2_09_13.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_13.wav",
#     "length": 0.5480625,
#     "digit": "2"
#   },
#   "4_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_21.wav",
#     "length": 0.5229791666666667,
#     "digit": "4"
#   },
#   "5_09_43.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_43.wav",
#     "length": 0.6408333333333334,
#     "digit": "5"
#   },
#   "8_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_26.wav",
#     "length": 0.3966875,
#     "digit": "8"
#   },
#   "1_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_21.wav",
#     "length": 0.61025,
#     "digit": "1"
#   },
#   "8_09_39.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_39.wav",
#     "length": 0.38475,
#     "digit": "8"
#   },
#   "2_09_17.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_17.wav",
#     "length": 0.5049166666666667,
#     "digit": "2"
#   },
#   "2_09_31.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_31.wav",
#     "length": 0.6031666666666666,
#     "digit": "2"
#   },
#   "1_09_42.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_42.wav",
#     "length": 0.6149166666666667,
#     "digit": "1"
#   },
#   "9_09_42.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_42.wav",
#     "length": 0.7632083333333334,
#     "digit": "9"
#   },
#   "0_09_3.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_3.wav",
#     "length": 0.7818541666666666,
#     "digit": "0"
#   },
#   "5_09_41.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_41.wav",
#     "length": 0.7723333333333333,
#     "digit": "5"
#   },
#   "3_09_23.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_23.wav",
#     "length": 0.7279583333333334,
#     "digit": "3"
#   },
#   "3_09_9.wav": {
#     "wav": "/content/AudioMNIST/data/09/3_09_9.wav",
#     "length": 0.6028333333333333,
#     "digit": "3"
#   },
#   "6_09_19.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_19.wav",
#     "length": 0.8705833333333334,
#     "digit": "6"
#   },
#   "5_09_22.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_22.wav",
#     "length": 0.7579583333333333,
#     "digit": "5"
#   },
#   "0_09_25.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_25.wav",
#     "length": 0.7283541666666666,
#     "digit": "0"
#   },
#   "9_09_23.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_23.wav",
#     "length": 0.8442708333333333,
#     "digit": "9"
#   },
#   "6_09_36.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_36.wav",
#     "length": 0.89575,
#     "digit": "6"
#   },
#   "5_09_45.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_45.wav",
#     "length": 0.7921041666666667,
#     "digit": "5"
#   },
#   "5_09_36.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_36.wav",
#     "length": 0.8260625,
#     "digit": "5"
#   },
#   "5_09_34.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_34.wav",
#     "length": 0.660375,
#     "digit": "5"
#   },
#   "6_09_34.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_34.wav",
#     "length": 0.7757916666666667,
#     "digit": "6"
#   },
#   "1_09_26.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_26.wav",
#     "length": 0.6147291666666667,
#     "digit": "1"
#   },
#   "5_09_32.wav": {
#     "wav": "/content/AudioMNIST/data/09/5_09_32.wav",
#     "length": 0.7100833333333333,
#     "digit": "5"
#   },
#   "8_09_8.wav": {
#     "wav": "/content/AudioMNIST/data/09/8_09_8.wav",
#     "length": 0.3780833333333333,
#     "digit": "8"
#   },
#   "2_09_39.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_39.wav",
#     "length": 0.45779166666666665,
#     "digit": "2"
#   },
#   "9_09_20.wav": {
#     "wav": "/content/AudioMNIST/data/09/9_09_20.wav",
#     "length": 0.8095833333333333,
#     "digit": "9"
#   },
#   "6_09_21.wav": {
#     "wav": "/content/AudioMNIST/data/09/6_09_21.wav",
#     "length": 0.8211875,
#     "digit": "6"
#   },
#   "2_09_45.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_45.wav",
#     "length": 0.49435416666666665,
#     "digit": "2"
#   },
#   "0_09_38.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_38.wav",
#     "length": 0.8127083333333334,
#     "digit": "0"
#   },
#   "2_09_48.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_48.wav",
#     "length": 0.5560416666666667,
#     "digit": "2"
#   },
#   "4_09_47.wav": {
#     "wav": "/content/AudioMNIST/data/09/4_09_47.wav",
#     "length": 0.7304791666666667,
#     "digit": "4"
#   },
#   "0_09_19.wav": {
#     "wav": "/content/AudioMNIST/data/09/0_09_19.wav",
#     "length": 0.8354166666666667,
#     "digit": "0"
#   },
#   "2_09_35.wav": {
#     "wav": "/content/AudioMNIST/data/09/2_09_35.wav",
#     "length": 0.4445,
#     "digit": "2"
#   },
#   "1_09_12.wav": {
#     "wav": "/content/AudioMNIST/data/09/1_09_12.wav",
# ...
#     "length": 0.5492708333333334,
#     "digit": "3"
#   },
#   "8_05_34.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_34.wav",
#     "length": 0.604375,
#     "digit": "8"
#   },
#   "1_05_23.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_23.wav",
#     "length": 0.49341666666666667,
#     "digit": "1"
#   },
#   "5_05_22.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_22.wav",
#     "length": 0.5307708333333333,
#     "digit": "5"
#   },
#   "1_05_36.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_36.wav",
#     "length": 0.4901875,
#     "digit": "1"
#   },
#   "9_05_24.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_24.wav",
#     "length": 0.6062708333333333,
#     "digit": "9"
#   },
#   "9_05_17.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_17.wav",
#     "length": 0.6244166666666666,
#     "digit": "9"
#   },
#   "7_05_44.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_44.wav",
#     "length": 0.6301458333333333,
#     "digit": "7"
#   },
#   "3_05_47.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_47.wav",
#     "length": 0.5554375,
#     "digit": "3"
#   },
#   "8_05_8.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_8.wav",
#     "length": 0.48672916666666666,
#     "digit": "8"
#   },
#   "3_05_41.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_41.wav",
#     "length": 0.5422708333333334,
#     "digit": "3"
#   },
#   "4_05_45.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_45.wav",
#     "length": 0.48672916666666666,
#     "digit": "4"
#   },
#   "5_05_8.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_8.wav",
#     "length": 0.47097916666666667,
#     "digit": "5"
#   },
#   "1_05_1.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_1.wav",
#     "length": 0.46791666666666665,
#     "digit": "1"
#   },
#   "2_05_21.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_21.wav",
#     "length": 0.45429166666666665,
#     "digit": "2"
#   },
#   "6_05_41.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_41.wav",
#     "length": 0.6494791666666667,
#     "digit": "6"
#   },
#   "2_05_26.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_26.wav",
#     "length": 0.589875,
#     "digit": "2"
#   },
#   "7_05_1.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_1.wav",
#     "length": 0.5615208333333334,
#     "digit": "7"
#   },
#   "2_05_16.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_16.wav",
#     "length": 0.45595833333333335,
#     "digit": "2"
#   },
#   "6_05_9.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_9.wav",
#     "length": 0.667125,
#     "digit": "6"
#   },
#   "2_05_23.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_23.wav",
#     "length": 0.512875,
#     "digit": "2"
#   },
#   "8_05_16.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_16.wav",
#     "length": 0.5210416666666666,
#     "digit": "8"
#   },
#   "0_05_30.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_30.wav",
#     "length": 0.5794583333333333,
#     "digit": "0"
#   },
#   "6_05_19.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_19.wav",
#     "length": 0.5841666666666666,
#     "digit": "6"
#   },
#   "8_05_19.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_19.wav",
#     "length": 0.5344166666666667,
#     "digit": "8"
#   },
#   "3_05_21.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_21.wav",
#     "length": 0.5366458333333334,
#     "digit": "3"
#   },
#   "8_05_32.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_32.wav",
#     "length": 0.5705208333333334,
#     "digit": "8"
#   },
#   "0_05_26.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_26.wav",
#     "length": 0.5979375,
#     "digit": "0"
#   },
#   "5_05_16.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_16.wav",
#     "length": 0.68425,
#     "digit": "5"
#   },
#   "4_05_17.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_17.wav",
#     "length": 0.5125833333333333,
#     "digit": "4"
#   },
#   "0_05_29.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_29.wav",
#     "length": 0.6027916666666666,
#     "digit": "0"
#   },
#   "4_05_28.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_28.wav",
#     "length": 0.5316875,
#     "digit": "4"
#   },
#   "2_05_20.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_20.wav",
#     "length": 0.5241041666666667,
#     "digit": "2"
#   },
#   "2_05_34.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_34.wav",
#     "length": 0.4814583333333333,
#     "digit": "2"
#   },
#   "5_05_33.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_33.wav",
#     "length": 0.5557708333333333,
#     "digit": "5"
#   },
#   "8_05_13.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_13.wav",
#     "length": 0.55425,
#     "digit": "8"
#   },
#   "3_05_36.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_36.wav",
#     "length": 0.5456458333333334,
#     "digit": "3"
#   },
#   "8_05_9.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_9.wav",
#     "length": 0.496,
#     "digit": "8"
#   },
#   "9_05_33.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_33.wav",
#     "length": 0.5848333333333333,
#     "digit": "9"
#   },
#   "6_05_32.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_32.wav",
#     "length": 0.7049791666666667,
#     "digit": "6"
#   },
#   "7_05_9.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_9.wav",
#     "length": 0.6179375,
#     "digit": "7"
#   },
#   "9_05_49.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_49.wav",
#     "length": 0.5908125,
#     "digit": "9"
#   },
#   "4_05_3.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_3.wav",
#     "length": 0.5446458333333334,
#     "digit": "4"
#   },
#   "0_05_3.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_3.wav",
#     "length": 0.5738541666666667,
#     "digit": "0"
#   },
#   "4_05_16.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_16.wav",
#     "length": 0.5322291666666666,
#     "digit": "4"
#   },
#   "1_05_46.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_46.wav",
#     "length": 0.49372916666666666,
#     "digit": "1"
#   },
#   "2_05_45.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_45.wav",
#     "length": 0.558375,
#     "digit": "2"
#   },
#   "4_05_0.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_0.wav",
#     "length": 0.5352708333333334,
#     "digit": "4"
#   },
#   "6_05_49.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_49.wav",
#     "length": 0.6381666666666667,
#     "digit": "6"
#   },
#   "2_05_5.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_5.wav",
#     "length": 0.56875,
#     "digit": "2"
#   },
#   "0_05_45.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_45.wav",
#     "length": 0.6111041666666667,
#     "digit": "0"
#   },
#   "7_05_26.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_26.wav",
#     "length": 0.6039375,
#     "digit": "7"
#   },
#   "1_05_22.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_22.wav",
#     "length": 0.4755,
#     "digit": "1"
#   },
#   "1_05_35.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_35.wav",
#     "length": 0.48966666666666664,
#     "digit": "1"
#   },
#   "2_05_3.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_3.wav",
#     "length": 0.5178125,
#     "digit": "2"
#   },
#   "4_05_35.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_35.wav",
#     "length": 0.487375,
#     "digit": "4"
#   },
#   "4_05_8.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_8.wav",
#     "length": 0.5518958333333334,
#     "digit": "4"
#   },
#   "1_05_27.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_27.wav",
#     "length": 0.48870833333333336,
#     "digit": "1"
#   },
#   "3_05_10.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_10.wav",
#     "length": 0.5382916666666666,
#     "digit": "3"
#   },
#   "4_05_7.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_7.wav",
#     "length": 0.5203333333333333,
#     "digit": "4"
#   },
#   "3_05_25.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_25.wav",
#     "length": 0.5239791666666667,
#     "digit": "3"
#   },
#   "6_05_0.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_0.wav",
#     "length": 0.6475625,
#     "digit": "6"
#   },
#   "1_05_38.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_38.wav",
#     "length": 0.465625,
#     "digit": "1"
#   },
#   "8_05_14.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_14.wav",
#     "length": 0.5670208333333333,
#     "digit": "8"
#   },
#   "2_05_48.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_48.wav",
#     "length": 0.5532083333333333,
#     "digit": "2"
#   },
#   "2_05_17.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_17.wav",
#     "length": 0.5104791666666667,
#     "digit": "2"
#   },
#   "7_05_46.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_46.wav",
#     "length": 0.5668541666666667,
#     "digit": "7"
#   },
#   "6_05_45.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_45.wav",
#     "length": 0.5898125,
#     "digit": "6"
#   },
#   "5_05_15.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_15.wav",
#     "length": 0.5196458333333334,
#     "digit": "5"
#   },
#   "1_05_31.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_31.wav",
#     "length": 0.485,
#     "digit": "1"
#   },
#   "1_05_17.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_17.wav",
#     "length": 0.49075,
#     "digit": "1"
#   },
#   "3_05_13.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_13.wav",
#     "length": 0.5691875,
#     "digit": "3"
#   },
#   "4_05_27.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_27.wav",
#     "length": 0.5316875,
#     "digit": "4"
#   },
#   "1_05_12.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_12.wav",
#     "length": 0.46229166666666666,
#     "digit": "1"
#   },
#   "4_05_15.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_15.wav",
#     "length": 0.5204166666666666,
#     "digit": "4"
#   },
#   "3_05_6.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_6.wav",
#     "length": 0.5296458333333334,
#     "digit": "3"
#   },
#   "9_05_44.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_44.wav",
#     "length": 0.5815208333333334,
#     "digit": "9"
#   },
#   "2_05_25.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_25.wav",
#     "length": 0.5579583333333333,
#     "digit": "2"
#   },
#   "0_05_13.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_13.wav",
#     "length": 0.6128125,
#     "digit": "0"
#   },
#   "9_05_16.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_16.wav",
#     "length": 0.5205833333333333,
#     "digit": "9"
#   },
#   "2_05_19.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_19.wav",
#     "length": 0.609625,
#     "digit": "2"
#   },
#   "7_05_11.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_11.wav",
#     "length": 0.6196458333333333,
#     "digit": "7"
#   },
#   "6_05_15.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_15.wav",
#     "length": 0.6216875,
#     "digit": "6"
#   },
#   "5_05_9.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_9.wav",
#     "length": 0.4800833333333333,
#     "digit": "5"
#   },
#   "0_05_10.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_10.wav",
#     "length": 0.5998333333333333,
#     "digit": "0"
#   },
#   "0_05_34.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_34.wav",
#     "length": 0.5901875,
#     "digit": "0"
#   },
#   "8_05_38.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_38.wav",
#     "length": 0.5783333333333334,
#     "digit": "8"
#   },
#   "1_05_47.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_47.wav",
#     "length": 0.496125,
#     "digit": "1"
#   },
#   "4_05_21.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_21.wav",
#     "length": 0.5304375,
#     "digit": "4"
#   },
#   "3_05_48.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_48.wav",
#     "length": 0.5385,
#     "digit": "3"
#   },
#   "4_05_24.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_24.wav",
#     "length": 0.5567708333333333,
#     "digit": "4"
#   },
#   "8_05_20.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_20.wav",
#     "length": 0.4876666666666667,
#     "digit": "8"
#   },
#   "2_05_44.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_44.wav",
#     "length": 0.6008333333333333,
#     "digit": "2"
#   },
#   "9_05_25.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_25.wav",
#     "length": 0.589375,
#     "digit": "9"
#   },
#   "9_05_30.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_30.wav",
#     "length": 0.5915208333333334,
#     "digit": "9"
#   },
#   "0_05_35.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_35.wav",
#     "length": 0.6223333333333333,
#     "digit": "0"
#   },
#   "2_05_4.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_4.wav",
#     "length": 0.5178958333333333,
#     "digit": "2"
#   },
#   "7_05_48.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_48.wav",
#     "length": 0.5754166666666667,
#     "digit": "7"
#   },
#   "2_05_8.wav": {
#     "wav": "/content/AudioMNIST/data/05/2_05_8.wav",
#     "length": 0.504625,
#     "digit": "2"
#   },
#   "8_05_17.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_17.wav",
#     "length": 0.5458333333333333,
#     "digit": "8"
#   },
#   "5_05_25.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_25.wav",
#     "length": 0.6887083333333334,
#     "digit": "5"
#   },
#   "1_05_2.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_2.wav",
#     "length": 0.5003333333333333,
#     "digit": "1"
#   },
#   "9_05_14.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_14.wav",
#     "length": 0.5888333333333333,
#     "digit": "9"
#   },
#   "7_05_5.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_5.wav",
#     "length": 0.5659375,
#     "digit": "7"
#   },
#   "3_05_20.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_20.wav",
#     "length": 0.5704583333333333,
#     "digit": "3"
#   },
#   "7_05_43.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_43.wav",
#     "length": 0.5439791666666667,
#     "digit": "7"
#   },
#   "8_05_41.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_41.wav",
#     "length": 0.5661666666666667,
#     "digit": "8"
#   },
#   "1_05_45.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_45.wav",
#     "length": 0.48441666666666666,
#     "digit": "1"
#   },
#   "5_05_29.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_29.wav",
#     "length": 0.6916458333333333,
#     "digit": "5"
#   },
#   "5_05_12.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_12.wav",
#     "length": 0.545,
#     "digit": "5"
#   },
#   "6_05_29.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_29.wav",
#     "length": 0.7000208333333333,
#     "digit": "6"
#   },
#   "8_05_15.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_15.wav",
#     "length": 0.5322291666666666,
#     "digit": "8"
#   },
#   "9_05_47.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_47.wav",
#     "length": 0.6346666666666667,
#     "digit": "9"
#   },
#   "7_05_33.wav": {
#     "wav": "/content/AudioMNIST/data/05/7_05_33.wav",
#     "length": 0.578,
#     "digit": "7"
#   },
#   "4_05_39.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_39.wav",
#     "length": 0.5645,
#     "digit": "4"
#   },
#   "8_05_29.wav": {
#     "wav": "/content/AudioMNIST/data/05/8_05_29.wav",
#     "length": 0.4676875,
#     "digit": "8"
#   },
#   "4_05_10.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_10.wav",
#     "length": 0.5440208333333333,
#     "digit": "4"
#   },
#   "6_05_46.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_46.wav",
#     "length": 0.6801458333333333,
#     "digit": "6"
#   },
#   "5_05_42.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_42.wav",
#     "length": 0.5297916666666667,
#     "digit": "5"
#   },
#   "0_05_33.wav": {
#     "wav": "/content/AudioMNIST/data/05/0_05_33.wav",
#     "length": 0.60975,
#     "digit": "0"
#   },
#   "3_05_33.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_33.wav",
#     "length": 0.5193125,
#     "digit": "3"
#   },
#   "4_05_29.wav": {
#     "wav": "/content/AudioMNIST/data/05/4_05_29.wav",
#     "length": 0.5549375,
#     "digit": "4"
#   },
#   "1_05_29.wav": {
#     "wav": "/content/AudioMNIST/data/05/1_05_29.wav",
#     "length": 0.48802083333333335,
#     "digit": "1"
#   },
#   "5_05_18.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_18.wav",
#     "length": 0.52775,
#     "digit": "5"
#   },
#   "5_05_34.wav": {
#     "wav": "/content/AudioMNIST/data/05/5_05_34.wav",
#     "length": 0.5960416666666667,
#     "digit": "5"
#   },
#   "9_05_40.wav": {
#     "wav": "/content/AudioMNIST/data/05/9_05_40.wav",
#     "length": 0.6211875,
#     "digit": "9"
#   },
#   "3_05_19.wav": {
#     "wav": "/content/AudioMNIST/data/05/3_05_19.wav",
#     "length": 0.5211666666666667,
#     "digit": "3"
#   },
#   "6_05_42.wav": {
#     "wav": "/content/AudioMNIST/data/05/6_05_42.wav",
#     "length": 0.9156666666666666,
#     "digit": "6"
#   }
# }

# %% [markdown]
# If everything is fine, the first two entries of the JSON files should look like this:
#
#
# **train.json**
# ```
# {
#   "6_10_30.wav": {
#     "wav": "AudioMNIST/data/10/6_10_30.wav",
#     "length": 0.7466041666666666,
#     "digit": "6"
#   },
#   "4_10_22.wav": {
#     "wav": "AudioMNIST/data/10/4_10_22.wav",
#     "length": 0.6258125,
#     "digit": "4"
#   },
#   ........
# ```
#
# **valid.json**
#
# ```
# {
#   "8_13_43.wav": {
#     "wav": "AudioMNIST/data/13/8_13_43.wav",
#     "length": 0.6086041666666666,
#     "digit": "8"
#   },
#   "9_13_41.wav": {
#     "wav": "AudioMNIST/data/13/9_13_41.wav",
#     "length": 0.8174166666666667,
#     "digit": "9"
#   },
#   ........
# ```
#
# **test.json**
#
#
# ```
# {
#   "9_17_16.wav": {
#     "wav": "AudioMNIST/data/17/9_17_16.wav",
#     "length": 0.6987708333333333,
#     "digit": "9"
#   },
#   "3_17_20.wav": {
#     "wav": "AudioMNIST/data/17/3_17_20.wav",
#     "length": 0.6341458333333333,
#     "digit": "3"
#   },
#   ........
# ```

# %% [markdown]
# ###**Exercise 1.3. Training**
#
# We can now proceed with training. In particular, we want to train our digit classifier with an [xvector-based model](https://www.danielpovey.com/files/2018_icassp_xvectors.pdf).
#
# This model extracts embeddings using an [time-delay neural network (TDNN)](https://en.wikipedia.org/wiki/Time_delay_neural_network).
#
# To get embeddings of fixed size out of variable size audio recordings, it uses statistics pooling.
# The statistics pooling layer aggregates all frame-level latent representations from the encoder layer and computes their mean and standard deviations.
#
# On top of the aforementioned fixed-size embeddings, a simple MLP classifier is applied.
#
# The xvector model is implemented in speechbrain [here](https://github.com/speechbrain/speechbrain/blob/develop/speechbrain/lobes/models/Xvector.py).

# %% [markdown]
# ![pictures.drawio (1).png](data:image/png;base64,...)

# %% [markdown]
# **Run the code below** to store the hyperparameter file that defines the xvector-based digit classifier. Take a look at the adopted hyperparameters.
# As you can see, we use 40 fbanks, and we normalize their mean and variance.
# The system iterates for 10 epochs with a batch size of 64. The learning rate starts at 0.001, and is annealed linearly over the epochs to reach 0.0001 at the end of training.

# %% [markdown]
# Now, we need to work on the training script itself (train.py).
#
# **Complete the code below** and start training a model. In particular, you should write your code for the `compute_foward` and `compute objective` methods.
# You can draw inspiration from the tutorial seen in the lab session. Moreover, you have to complete the code in the `audio_pipeline` function and add the resampling function to downsample the signal to 16 kHz. You can use `torchaudio.functional.resample` (make sure the dimensionality of the returned signal matches with the expected format: `[batch, time]`).

# %%
# %%file hparams_xvector.yaml
#
# # #################################
# # Basic training parameters for digit classification with Xvector
# #
# # Author:
# #  * Mirco Ravanelli 2021
# # #################################
#
# # Seed needs to be set at top of yaml, before objects with parameters are made
# seed: 1986
# __set_seed: !!python/object/apply:torch.manual_seed [!ref <seed>]
#
# output_folder: !ref ./results/AudioMNIST/Xvector/<seed>
# save_folder: !ref <output_folder>/save
# train_log: !ref <output_folder>/train_log.txt
#
# # Path where data manifest files are stored
# train_annotation: train.json
# valid_annotation: valid.json
# test_annotation: test.json
#
# # The train logger writes training statistics to a file, as well as stdout.
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
#
# error_stats: !name:speechbrain.utils.metric_stats.MetricStats
#     metric: !name:speechbrain.nnet.losses.classification_error
#         reduction: batch
#
# # Feature parameters
# n_mels: 40
#
# # Training Parameters
# sample_rate: 16000
# number_of_epochs: 10
# batch_size: 64
# lr_start: 0.001
# lr_final: 0.0001
# n_classes: 10 # In this case, we have 10 digits
# emb_dim: 128 # dimensionality of the embeddings
# dataloader_options:
#     batch_size: !ref <batch_size>
#
# # Feature extraction
# compute_features: !new:speechbrain.lobes.features.Fbank
#     n_mels: !ref <n_mels>
#
# # Mean and std normalization of the input features
# mean_var_norm: !new:speechbrain.processing.features.InputNormalization
#     norm_type: global
#
# # Embedding model: from variable size digits gets a fixed size embedding vector
# embedding_model: !new:speechbrain.lobes.models.Xvector.Xvector
#     in_channels: !ref <n_mels>
#     activation: !name:torch.nn.LeakyReLU
#     tdnn_blocks: 5
#     tdnn_channels: [64, 64, 64, 64, 128]
#     tdnn_kernel_sizes: [5, 3, 3, 1, 1]
#     tdnn_dilations: [1, 2, 3, 1, 1]
#     lin_neurons: !ref <emb_dim>
#
# # Clasifier applied on top of the embeddings
# classifier: !new:speechbrain.lobes.models.Xvector.Classifier
#     input_shape: [null, null, !ref <emb_dim>]
#     activation: !name:torch.nn.LeakyReLU
#     lin_blocks: 1
#     lin_neurons: !ref <emb_dim>
#     out_neurons: !ref <n_classes>
#
# # The first object passed to the Brain class is this "Epoch Counter"
# # which is saved by the Checkpointer so that training can be resumed
# # if it gets interrupted at any point.
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <number_of_epochs>
#
# # Objects in "modules" dict will have their parameters moved to the correct
# # device, as well as having train()/eval() called on them by the Brain class.
# modules:
#     compute_features: !ref <compute_features>
#     mean_var_norm: !ref <mean_var_norm>
#     embedding_model: !ref <embedding_model>
#     classifier: !ref <classifier>
#
# # This optimizer will be constructed by the Brain class after all parameters
# # are moved to the correct device. Then it will be added to the checkpointer.
# opt_class: !name:torch.optim.Adam
#     lr: !ref <lr_start>
#
# # This function manages learning rate annealing over the epochs.
# # We here use the simple lr annealing method that linearly decreases
# # the lr from the initial value to the final one.
# lr_annealing: !new:speechbrain.nnet.schedulers.LinearScheduler
#     initial_value: !ref <lr_start>
#     final_value: !ref <lr_final>
#     epoch_count: !ref <number_of_epochs>
#
# # This object is used for saving the state of training both so that it
# # can be resumed if it gets interrupted, and also so that the best checkpoint
# # can be later loaded for evaluation or inference.
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         embedding_model: !ref <embedding_model>
#         classifier: !ref <classifier>
#         normalizer: !ref <mean_var_norm>
#         counter: !ref <epoch_counter>
# Out:
# Writing hparams_xvector.yaml

# %%
# %%file train.py

#!/usr/bin/env python3
"Recipe for training a digit classification system."
import os
import sys
import torch
import torchaudio
import speechbrain as sb
from hyperpyyaml import load_hyperpyyaml
import torchaudio.functional as F


# Brain class for speech enhancement training
class DigitBrain(sb.Brain):
    """Class that manages the training loop. See speechbrain.core.Brain."""

    def compute_forward(self, batch, stage):
        """Runs all the computations that transforms the input into the
        output probabilities over the N classes.

        Arguments
        ---------
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        Returns
        -------
        predictions : Tensor
            Tensor that contains the posterior probabilities over the N classes.
        """
        # Your code here. Aim for 7-8 lines
        batch = batch.to(self.device)

        audio_shape,batch_size = batch.sig

        if stage == sb.Stage.TRAIN and hasattr(self.hparams, "wav_augment"):
            wavs, lens = self.hparams.wav_augment(wavs, lens)

        features = self.modules.compute_features(audio_shape)

        features = self.modules.mean_var_norm(features,batch_size)

        embeddings = self.modules.embedding_model(features,batch_size)

        predictions = self.modules.classifier(embeddings)

        return predictions


    def compute_objectives(self, predictions, batch, stage):
        """Computes the loss given the predicted and targeted outputs.

        Arguments
        ---------
        predictions : tensor
            The output tensor from `compute_forward`.
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        Returns
        -------
        loss : torch.Tensor
            A one-element tensor used for backpropagating the gradient.
        """

        # Your code here. Aim for 7-8 lines

        _, lens = batch.sig
        digit, _ = batch.digit_encoded

          # Concatenate labels (due to data augmentation)
        if stage == sb.Stage.TRAIN and hasattr(self.modules, "env_corrupt"):
            digit = torch.cat([digit, digit], dim=0)
            lens = torch.cat([lens, lens])

                # Compute the cost function
        loss = sb.nnet.losses.nll_loss(predictions, digit, lens)


        # Append this batch of losses to the loss metric for easy
        self.loss_metric.append(
            batch.id, predictions, digit, lens, reduction="batch"
        )

                # Compute classification error at test time
        if stage != sb.Stage.TRAIN:
            self.error_metrics.append(batch.id, predictions, digit, lens)

        return loss

    def on_stage_start(self, stage, epoch=None):
        """Gets called at the beginning of each epoch.
        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Set up statistics trackers for this stage
        self.loss_metric = sb.utils.metric_stats.MetricStats(
            metric=sb.nnet.losses.nll_loss
        )

        # Set up evaluation-only statistics trackers
        if stage != sb.Stage.TRAIN:
            self.error_metrics = self.hparams.error_stats()

    def on_stage_end(self, stage, stage_loss, epoch=None):
        """Gets called at the end of an epoch.
        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, sb.Stage.TEST
        stage_loss : float
            The average loss for all of the data processed in this stage.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Store the train loss until the validation stage.
        if stage == sb.Stage.TRAIN:
            self.train_loss = stage_loss

        # Summarize the statistics from the stage for record-keeping.
        else:
            stats = {
                "loss": stage_loss,
                "error": self.error_metrics.summarize("average"),
            }

        # At the end of validation...
        if stage == sb.Stage.VALID:

            old_lr, new_lr = self.hparams.lr_annealing(epoch)
            sb.nnet.schedulers.update_learning_rate(self.optimizer, new_lr)

            # The train_logger writes a summary to stdout and to the logfile.
            self.hparams.train_logger.log_stats(
                {"Epoch": epoch, "lr": old_lr},
                train_stats={"loss": self.train_loss},
                valid_stats=stats,
            )

            # Save the current checkpoint and delete previous checkpoints,
            self.checkpointer.save_and_keep_only(meta=stats, min_keys=["error"])

        # We also write statistics about test data to stdout and to the logfile.
        if stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                {"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stats,
            )


def dataio_prep(hparams):
    """This function prepares the datasets to be used in the brain class.
    It also defines the data processing pipeline through user-defined functions.
    We expect `prepare_mini_librispeech` to have been called before this,
    so that the `train.json`, `valid.json`,  and `valid.json` manifest files
    are available.
    Arguments
    ---------
    hparams : dict
        This dictionary is loaded from the `train.yaml` file, and it includes
        all the hyperparameters needed for dataset construction and loading.
    Returns
    -------
    datasets : dict
        Contains two keys, "train" and "valid" that correspond
        to the appropriate DynamicItemDataset object.
    """

    # Initialization of the label encoder. The label encoder assigns to each
    # of the observed label a unique index (e.g, 'digit0': 0, 'digit1': 1, ..)
    label_encoder = sb.dataio.encoder.CategoricalEncoder()

    # Define audio pipeline
    @sb.utils.data_pipeline.takes("wav")
    @sb.utils.data_pipeline.provides("sig")
    def audio_pipeline(wav):
        """Load the signal, and pass it and its length to the corruption class.
        This is done on the CPU in the `collate_fn`."""
        sig, fs = torchaudio.load(wav)

        # Resampling
        # sig = # Your code here. Aim for 1-2 lines
        sig = sb.dataio.dataio.read_audio(wav)
        original_fs = torchaudio.info(wav).sample_rate
        if original_fs != 16000:
            sig = F.resample(sig, orig_freq=original_fs, new_freq=16000)

        return sig

    # Define label pipeline:
    @sb.utils.data_pipeline.takes("digit")
    @sb.utils.data_pipeline.provides("digit", "digit_encoded")
    def label_pipeline(digit):
        """Defines the pipeline to process the digit labels.
        Note that we have to assign a different integer to each class
        through the label encoder.
        """
        yield digit
        digit_encoded = label_encoder.encode_label_torch(digit)
        yield digit_encoded

    # Define datasets. We also connect the dataset with the data processing
    # functions defined above.
    datasets = {}
    data_info = {
        "train": hparams["train_annotation"],
        "valid": hparams["valid_annotation"],
        "test": hparams["test_annotation"],
    }
    hparams["dataloader_options"]["shuffle"] = True
    for dataset in data_info:
        datasets[dataset] = sb.dataio.dataset.DynamicItemDataset.from_json(
            json_path=data_info[dataset],
            dynamic_items=[audio_pipeline, label_pipeline],
            output_keys=["id", "sig", "digit_encoded"],
        )

    # Load or compute the label encoder (with multi-GPU DDP support)
    # Please, take a look into the lab_enc_file to see the label to index
    # mapping.
    lab_enc_file = os.path.join(hparams["save_folder"], "label_encoder.txt")
    label_encoder.load_or_create(
        path=lab_enc_file,
        from_didatasets=[datasets["train"]],
        output_key="digit",
    )

    return datasets


# Recipe begins!
if __name__ == "__main__":

    # Reading command line arguments.
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])

    # Load hyperparameters file with command-line overrides.
    with open(hparams_file) as fin:
        hparams = load_hyperpyyaml(fin,  overrides)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )

    # Create dataset objects "train", "valid", and "test".
    datasets = dataio_prep(hparams)

    # Initialize the Brain object to prepare for mask training.
    digit_brain = DigitBrain(
        modules=hparams["modules"],
        opt_class=hparams["opt_class"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )

    # The `fit()` method iterates the training loop, calling the methods
    # necessary to update the parameters of the model. Since all objects
    # with changing state are managed by the Checkpointer, training can be
    # stopped at any point, and will be resumed on next call.
    digit_brain.fit(
        epoch_counter=digit_brain.hparams.epoch_counter,
        train_set=datasets["train"],
        valid_set=datasets["valid"],
        train_loader_kwargs=hparams["dataloader_options"],
        valid_loader_kwargs=hparams["dataloader_options"],
    )

    # Load the best checkpoint for evaluation
    test_stats = digit_brain.evaluate(
        test_set=datasets["test"],
        min_key="error",
        test_loader_kwargs=hparams["dataloader_options"],
    )
# Out:
# Writing train.py

# %% [markdown]
# **Run the code below** to train the model.

# %%
# Delete the output folder to start training from scratch
# (and not from a previous checkpoint).
# !rm -rf results/AudioMNIST/Xvector/1986

# Run training
# !python train.py hparams_xvector.yaml
# Out:
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:68: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: ./results/AudioMNIST/Xvector/1986
# speechbrain.dataio.encoder - Load called, but CategoricalEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# /usr/local/lib/python3.11/dist-packages/speechbrain/core.py:796: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=gradscaler_enabled)
# speechbrain.core - DigitBrain Model Statistics:
# * Total Number of Trainable Parameters: 102.0k
# * Total Number of Parameters: 102.0k
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
# speechbrain.dataio.encoder - CategoricalEncoder.expect_len was never called: assuming category count of 10 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
# 100% 79/79 [01:50<00:00,  1.40s/it, train_loss=0.247]
# 100% 32/32 [00:44<00:00,  1.40s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.001 to 0.0009
# speechbrain.utils.train_logger - Epoch: 1, lr: 1.00e-03 - train loss: 2.47e-01 - valid loss: 2.26e-01, valid error: 7.20e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+00-51-05+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100% 79/79 [01:49<00:00,  1.38s/it, train_loss=0.0251]
# 100% 32/32 [00:46<00:00,  1.47s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0009 to 0.0008
# speechbrain.utils.train_logger - Epoch: 2, lr: 9.00e-04 - train loss: 2.51e-02 - valid loss: 1.73e-01, valid error: 7.25e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+00-53-41+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100% 79/79 [01:50<00:00,  1.40s/it, train_loss=0.00866]
# 100% 32/32 [00:47<00:00,  1.48s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0008 to 0.0007
# speechbrain.utils.train_logger - Epoch: 3, lr: 8.00e-04 - train loss: 8.66e-03 - valid loss: 1.26e-01, valid error: 5.25e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+00-56-19+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+00-51-05+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+00-53-41+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100% 79/79 [01:50<00:00,  1.40s/it, train_loss=0.00303]
# 100% 32/32 [00:45<00:00,  1.43s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0007 to 0.0006
# speechbrain.utils.train_logger - Epoch: 4, lr: 7.00e-04 - train loss: 3.03e-03 - valid loss: 1.59e-01, valid error: 6.70e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+00-58-55+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100% 79/79 [01:50<00:00,  1.39s/it, train_loss=0.0022]
# 100% 32/32 [00:47<00:00,  1.49s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0006 to 0.0005
# speechbrain.utils.train_logger - Epoch: 5, lr: 6.00e-04 - train loss: 2.20e-03 - valid loss: 2.05e-01, valid error: 7.95e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-01-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+00-58-55+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100% 79/79 [01:51<00:00,  1.41s/it, train_loss=0.00278]
# 100% 32/32 [00:45<00:00,  1.42s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0005 to 0.0004
# speechbrain.utils.train_logger - Epoch: 6, lr: 5.00e-04 - train loss: 2.78e-03 - valid loss: 2.08e-01, valid error: 6.60e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-04-09+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-01-33+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100% 79/79 [01:49<00:00,  1.39s/it, train_loss=0.00463]
# 100% 32/32 [00:46<00:00,  1.46s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0004 to 0.0003
# speechbrain.utils.train_logger - Epoch: 7, lr: 4.00e-04 - train loss: 4.63e-03 - valid loss: 2.58e-01, valid error: 6.80e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-06-46+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-04-09+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100% 79/79 [01:53<00:00,  1.44s/it, train_loss=0.00337]
# 100% 32/32 [00:45<00:00,  1.43s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0003 to 0.0002
# speechbrain.utils.train_logger - Epoch: 8, lr: 3.00e-04 - train loss: 3.37e-03 - valid loss: 1.69e-01, valid error: 6.20e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-09-25+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-06-46+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# 100% 79/79 [01:50<00:00,  1.40s/it, train_loss=0.00124]
# 100% 32/32 [00:47<00:00,  1.47s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0002 to 0.0001
# speechbrain.utils.train_logger - Epoch: 9, lr: 2.00e-04 - train loss: 1.24e-03 - valid loss: 2.59e-01, valid error: 8.30e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-12-03+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-09-25+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# 100% 79/79 [01:50<00:00,  1.40s/it, train_loss=0.0012]
# 100% 32/32 [00:45<00:00,  1.43s/it]
# speechbrain.utils.train_logger - Epoch: 10, lr: 1.00e-04 - train loss: 1.20e-03 - valid loss: 2.52e-01, valid error: 7.75e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-14-40+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+01-12-03+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/AudioMNIST/Xvector/1986/save/CKPT+2025-01-27+00-56-19+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/processing/features.py:1311: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   stats = torch.load(path, map_location=device)
# 100% 32/32 [00:44<00:00,  1.39s/it]
# speechbrain.utils.train_logger - Epoch loaded: 3 - test loss: 1.55e-01, test error: 5.55e-02

# %% [markdown]
# If  everything is fine, the training logs (see `results/AudioMNIST/Xvector/1986/train_log.txt`) should look like this:

# %% [markdown]
# ```
# Epoch: 1, lr: 1.00e-03 - train loss: 2.57e-01 - valid loss: 3.42e-01, valid error: 1.20e-01
# Epoch: 2, lr: 9.00e-04 - train loss: 1.60e-02 - valid loss: 2.20e-01, valid error: 7.00e-02
# Epoch: 3, lr: 8.00e-04 - train loss: 1.91e-02 - valid loss: 4.19e-01, valid error: 1.14e-01
# Epoch: 4, lr: 7.00e-04 - train loss: 6.26e-03 - valid loss: 2.68e-01, valid error: 6.00e-02
# Epoch: 5, lr: 6.00e-04 - train loss: 6.53e-03 - valid loss: 3.46e-01, valid error: 1.05e-01
# Epoch: 6, lr: 5.00e-04 - train loss: 2.03e-03 - valid loss: 2.11e-01, valid error: 5.70e-02
# Epoch: 7, lr: 4.00e-04 - train loss: 1.42e-03 - valid loss: 2.23e-01, valid error: 5.70e-02
# Epoch: 8, lr: 3.00e-04 - train loss: 2.45e-03 - valid loss: 2.05e-01, valid error: 5.05e-02
# Epoch: 9, lr: 2.00e-04 - train loss: 1.54e-03 - valid loss: 2.01e-01, valid error: 5.10e-02
# Epoch: 10, lr: 1.00e-04 - train loss: 1.56e-03 - valid loss: 1.97e-01, valid error: 4.85e-02
# Epoch loaded: 10 - test loss: 1.40e-01, test error: 5.20e-02
# ```

# %% [markdown]
# Note that it is fine if you obtain training logs that are a bit different. Also, the convergence might be a bit "turbulent" for this model, in the sense that the validation error might oscillate a lot.
# The most important thing is that the network is converging and that the test_error is good (e.g., < 7%).

# %% [markdown]
# ###**Exercise 1.4 Training with a user-defined model**
#
# We now would like to define a new model and use it to train our digit classifier.  In particular, we want to implement the following combination of CNN and RNN models:

# %% [markdown]
# ![pictures.drawio (2).png](data:image/png;base64,...)

# %% [markdown]
# As you can see, we have two convolutional layers followed by a Gated Recurrent Unit (GRU). After that, we need to add a layer that averages the embeddings over time. This way, just like the xvector, we can have fixed-size embeddings whose dimensionality does not depend on the time axis.
#
# Note that the numbers in each block correspond to the hyperparameters to use (in the given order). For instance, in the first conv1d block you see (40,32,3,1). This corresponds to the number of input channels, output channels, kernel_size, and stride factor, respectively (as in https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html).
#
# **Complete the code below** to implement this model.

# %%
# %%file CRNN.py

import torch
from speechbrain.dataio.dataio import length_to_mask

class CRNN(torch.nn.Module):
  def __init__(self,in_channels=40, emb_dim=128):
    super(CRNN,self).__init__()

    # Your code here. Aim for 9-10 lines. Use the sequential container.
    # Convolutional Block
    self.cnn =  torch.nn.Sequential(
        torch.nn.Conv1d(in_channels, 32, kernel_size=3, stride=1, padding=1),
        torch.nn.BatchNorm1d(32),
        torch.nn.ReLU(),
        torch.nn.MaxPool1d(kernel_size=2, stride=2),
        torch.nn.Conv1d(32, 32, kernel_size=3, stride=1, padding=1),
        torch.nn.BatchNorm1d(32),
        torch.nn.ReLU(),
        torch.nn.MaxPool1d(kernel_size=2, stride=2),
    )

    # Recurrent Block. Aim for 1 line
    self.rnn = torch.nn.GRU(input_size=32, hidden_size=emb_dim, batch_first=True)

  def forward(self,x, lens):

    # Your code here. Aim for 3-5 lines. Take care of the dimensionalities required
    # by each block. You need to transpose/reshape the tensors properly
    x = x.transpose(1, 2)
    x = self.cnn(x)
    x = x.transpose(1, 2)
    x, _ = self.rnn(x)

    # Mean Computation. Here we average all the time steps. Note that we remove
    # the zero-padded time steps using a mask.
    abs_len = (lens * x.shape[1]).int()
    mask = length_to_mask(abs_len)
    masked_x = x * mask.unsqueeze(2)
    emb = masked_x.sum(dim=1)/mask.sum(dim=1, keepdim=True)
    return emb.unsqueeze(1)
# Out:
# Overwriting CRNN.py

# %% [markdown]
# **Run the code below** to test the model.

# %%
# Importing the library from the file.
# This is reloaded every time to allow modifications of library file.
import importlib
import CRNN
importlib.reload(CRNN)
from CRNN import CRNN

# Example
input = torch.rand(16,120,40)
model = CRNN()
output = model(input,torch.ones(16))
print(output.shape)
# Out:
# torch.Size([16, 1, 128])

# %% [markdown]
# If everything is fine, you should get the following output shape:
#
# `torch.Size([16, 1, 128])`

# %% [markdown]
# Now, you have to write the new hyperparameter file.
#
# **Write the hyperpameter YAML file** for your new model. You can copy and paste the xvector one and do the few modifications needed to import the new model.
# In particular:
# - change the output folder to `/results/AudioMNIST/CRNN/<seed>`
# - replace the xvector embedding_model with the CRNN one. Keep calling it `embedding_model `. This way, we can reuse the same train.py as before without any modification. You can use the same MLP classifier as before.

# %%
# %%writefile hparams_CRNN.yaml
#
# seed: 1986
# __set_seed: !!python/object/apply:torch.manual_seed [!ref <seed>]
#
# output_folder: !ref ./results/AudioMNIST/CRNN/<seed>
# save_folder: !ref <output_folder>/save
# train_log: !ref <output_folder>/train_log.txt
#
# # Path where data manifest files are stored
# train_annotation: train.json
# valid_annotation: valid.json
# test_annotation: test.json
#
# # The train logger writes training statistics to a file, as well as stdout.
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
#
# error_stats: !name:speechbrain.utils.metric_stats.MetricStats
#     metric: !name:speechbrain.nnet.losses.classification_error
#         reduction: batch
#
# # Feature parameters
# n_mels: 40
#
# # Training Parameters
# sample_rate: 16000
# number_of_epochs: 10
# batch_size: 64
# lr_start: 0.001
# lr_final: 0.0001
# n_classes: 10 # In this case, we have 10 digits
# emb_dim: 128 # dimensionality of the embeddings
# dataloader_options:
#     batch_size: !ref <batch_size>
#
# # Feature extraction
# compute_features: !new:speechbrain.lobes.features.Fbank
#     n_mels: !ref <n_mels>
#
# # Mean and std normalization of the input features
# mean_var_norm: !new:speechbrain.processing.features.InputNormalization
#     norm_type: global
#
# # Embedding model: CRNN replaces xvector
# embedding_model: !new:CRNN.CRNN
#     in_channels: !ref <n_mels>
#     emb_dim: !ref <emb_dim>
#
# # Classifier applied on top of the embeddings
# classifier: !new:speechbrain.lobes.models.Xvector.Classifier
#     input_shape: [null, null, !ref <emb_dim>]
#     activation: !name:torch.nn.LeakyReLU
#     lin_blocks: 1
#     lin_neurons: !ref <emb_dim>
#     out_neurons: !ref <n_classes>
#
# # Epoch Counter
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <number_of_epochs>
#
# # Objects in "modules" dict will have their parameters moved to the correct
# # device, as well as having train()/eval() called on them by the Brain class.
# modules:
#     compute_features: !ref <compute_features>
#     mean_var_norm: !ref <mean_var_norm>
#     embedding_model: !ref <embedding_model>
#     classifier: !ref <classifier>
#
# # Optimizer
# opt_class: !name:torch.optim.Adam
#     lr: !ref <lr_start>
#
# # Learning rate scheduler
# lr_annealing: !new:speechbrain.nnet.schedulers.LinearScheduler
#     initial_value: !ref <lr_start>
#     final_value: !ref <lr_final>
#     epoch_count: !ref <number_of_epochs>
#
# # Checkpointer
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         embedding_model: !ref <embedding_model>
#         classifier: !ref <classifier>
#         normalizer: !ref <mean_var_norm>
#         counter: !ref <epoch_counter>
# Out:
# Overwriting hparams_CRNN.yaml

# %% [markdown]
# **Run the code below** to train the model.

# %%
# Delete the output folder to start training from scratch
# (and not from a previous checkpoint).
# !rm -rf results/AudioMNIST/CRNN/1986

# Run training
# !python train.py hparams_CRNN.yaml --device=cpu
# Out:
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:68: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: ./results/AudioMNIST/CRNN/1986
# speechbrain.dataio.encoder - Load called, but CategoricalEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# /usr/local/lib/python3.11/dist-packages/speechbrain/core.py:796: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=gradscaler_enabled)
# speechbrain.core - DigitBrain Model Statistics:
# * Total Number of Trainable Parameters: 87.6k
# * Total Number of Parameters: 87.6k
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
# speechbrain.dataio.encoder - CategoricalEncoder.expect_len was never called: assuming category count of 10 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
# 100% 79/79 [02:22<00:00,  1.80s/it, train_loss=0.381]
# 100% 32/32 [00:59<00:00,  1.87s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.001 to 0.0009
# speechbrain.utils.train_logger - Epoch: 1, lr: 1.00e-03 - train loss: 3.81e-01 - valid loss: 4.43e-01, valid error: 1.31e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-35-27+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100% 79/79 [02:23<00:00,  1.82s/it, train_loss=0.0384]
# 100% 32/32 [00:59<00:00,  1.86s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0009 to 0.0008
# speechbrain.utils.train_logger - Epoch: 2, lr: 9.00e-04 - train loss: 3.84e-02 - valid loss: 4.25e-01, valid error: 1.02e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-38-51+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-35-27+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100% 79/79 [02:24<00:00,  1.83s/it, train_loss=0.0154]
# 100% 32/32 [01:00<00:00,  1.90s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0008 to 0.0007
# speechbrain.utils.train_logger - Epoch: 3, lr: 8.00e-04 - train loss: 1.54e-02 - valid loss: 4.56e-01, valid error: 1.01e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-42-16+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-38-51+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100% 79/79 [02:24<00:00,  1.83s/it, train_loss=0.00891]
# 100% 32/32 [01:00<00:00,  1.88s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0007 to 0.0006
# speechbrain.utils.train_logger - Epoch: 4, lr: 7.00e-04 - train loss: 8.91e-03 - valid loss: 3.56e-01, valid error: 7.30e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-45-41+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-42-16+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100% 79/79 [02:24<00:00,  1.82s/it, train_loss=0.00569]
# 100% 32/32 [01:00<00:00,  1.88s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0006 to 0.0005
# speechbrain.utils.train_logger - Epoch: 5, lr: 6.00e-04 - train loss: 5.69e-03 - valid loss: 4.30e-01, valid error: 9.55e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-49-05+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100% 79/79 [02:27<00:00,  1.87s/it, train_loss=0.00541]
# 100% 32/32 [01:01<00:00,  1.92s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0005 to 0.0004
# speechbrain.utils.train_logger - Epoch: 6, lr: 5.00e-04 - train loss: 5.41e-03 - valid loss: 5.26e-01, valid error: 1.00e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-52-34+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-49-05+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100% 79/79 [02:23<00:00,  1.82s/it, train_loss=0.00488]
# 100% 32/32 [01:00<00:00,  1.90s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0004 to 0.0003
# speechbrain.utils.train_logger - Epoch: 7, lr: 4.00e-04 - train loss: 4.88e-03 - valid loss: 5.42e-01, valid error: 1.04e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-55-58+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-52-34+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100% 79/79 [02:24<00:00,  1.83s/it, train_loss=0.00723]
# 100% 32/32 [01:00<00:00,  1.89s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0003 to 0.0002
# speechbrain.utils.train_logger - Epoch: 8, lr: 3.00e-04 - train loss: 7.23e-03 - valid loss: 5.25e-01, valid error: 9.45e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-59-24+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-55-58+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# 100% 79/79 [02:28<00:00,  1.88s/it, train_loss=0.00306]
# 100% 32/32 [01:00<00:00,  1.89s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0002 to 0.0001
# speechbrain.utils.train_logger - Epoch: 9, lr: 2.00e-04 - train loss: 3.06e-03 - valid loss: 5.57e-01, valid error: 1.11e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+03-02-53+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-59-24+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# 100% 79/79 [02:24<00:00,  1.84s/it, train_loss=0.00272]
# 100% 32/32 [01:01<00:00,  1.92s/it]
# speechbrain.utils.train_logger - Epoch: 10, lr: 1.00e-04 - train loss: 2.72e-03 - valid loss: 4.98e-01, valid error: 9.80e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+03-06-19+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+03-02-53+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/AudioMNIST/CRNN/1986/save/CKPT+2025-01-27+02-45-41+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/processing/features.py:1311: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   stats = torch.load(path, map_location=device)
# 100% 32/32 [00:59<00:00,  1.85s/it]
# speechbrain.utils.train_logger - Epoch loaded: 4 - test loss: 2.75e-01, test error: 7.65e-02

# %% [markdown]
# If everything works, the training log file should look like this:
#
#
# ```
# Epoch: 1, lr: 1.00e-03 - train loss: 6.09e-01 - valid loss: 7.75e-01, valid error: 2.03e-01
# Epoch: 2, lr: 9.00e-04 - train loss: 5.61e-02 - valid loss: 7.53e-01, valid error: 1.62e-01
# Epoch: 3, lr: 8.00e-04 - train loss: 2.76e-02 - valid loss: 8.11e-01, valid error: 1.72e-01
# Epoch: 4, lr: 7.00e-04 - train loss: 1.60e-02 - valid loss: 7.71e-01, valid error: 1.51e-01
# Epoch: 5, lr: 6.00e-04 - train loss: 1.10e-02 - valid loss: 7.70e-01, valid error: 1.52e-01
# Epoch: 6, lr: 5.00e-04 - train loss: 9.15e-03 - valid loss: 7.36e-01, valid error: 1.46e-01
# Epoch: 7, lr: 4.00e-04 - train loss: 9.67e-03 - valid loss: 6.76e-01, valid error: 1.31e-01
# Epoch: 8, lr: 3.00e-04 - train loss: 5.59e-03 - valid loss: 6.71e-01, valid error: 1.27e-01
# Epoch: 9, lr: 2.00e-04 - train loss: 4.43e-03 - valid loss: 7.09e-01, valid error: 1.32e-01
# Epoch: 10, lr: 1.00e-04 - train loss: 3.52e-03 - valid loss: 7.46e-01, valid error: 1.35e-01
# Epoch loaded: 8 - test loss: 2.97e-01, test error: 1.01e-01
#
# ```
#
# Note that the variability is pretty high for this task (depending on the run you can achive errors between 10 and 5%). The previous xvector model, which is much more complex than this simple one, generally (but not always) provides better performance.

# %% [markdown]
# That's all for this lab!
