# %% [markdown]
# # **Week 6: Lab Exercises for COMP499/691 Conversational AI**
#
# The goal of this lab is to further familiarize yourself with SpeechBrain.
# In the previous labs, you had to properly complete some "prefilled" code that implemented some speechbrain model. In this lab, instead, you will do a little step ahead and write a full training recipe from scratch.
#
# ## **Task Description**
#
# This time we will work on speaker identification. The task is very simple: you have a speech signal in input, and you have to tell which of the N speakers in the pool is speaking.

# %% [markdown]
# ![pictures-Page-1.drawio (3).png](data:image/png;base64,...)

# %% [markdown]
# This problem is a supervised classification task, which is conceptually very similar to the audio digit classification already addressed in Lab 2 (the difference is that now we have speaker identities instead of digits in the output).
#
# We will work on a small portion of the TIMIT dataset that contains 26 different speakers.
#
#
# **Run the code below** to download and unzip the dataset.

# %%
# !wget -O TIMIT_tiny.zip  https://www.dropbox.com/scl/fi/7t7fi0t4cv424p7zem46g/TIMIT_tiny.zip?rlkey=efh571iyya5sb7w1kvk2xfi9h&dl=0
# Out:
# --2025-02-24 01:40:04--  https://www.dropbox.com/scl/fi/7t7fi0t4cv424p7zem46g/TIMIT_tiny.zip?rlkey=efh571iyya5sb7w1kvk2xfi9h
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca5d3b1d15dcf051e5077bf1477.dl.dropboxusercontent.com/cd/0/inline/Ckvr5N85UfBy6Xaax4btzsn8EVeCTJhsUm-lUjRheXWLb-0EubIyPfrheND7kpZzslhQERF8JXNrb97fprl7errT4IN2jfrYrHJgxmN8-ly9ILVVen8GWG1JGJVRN98sykUdMj-mUI77JpNlQnWMInJU/file# [following]
# --2025-02-24 01:40:05--  https://uca5d3b1d15dcf051e5077bf1477.dl.dropboxusercontent.com/cd/0/inline/Ckvr5N85UfBy6Xaax4btzsn8EVeCTJhsUm-lUjRheXWLb-0EubIyPfrheND7kpZzslhQERF8JXNrb97fprl7errT4IN2jfrYrHJgxmN8-ly9ILVVen8GWG1JGJVRN98sykUdMj-mUI77JpNlQnWMInJU/file
# Resolving uca5d3b1d15dcf051e5077bf1477.dl.dropboxusercontent.com (uca5d3b1d15dcf051e5077bf1477.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uca5d3b1d15dcf051e5077bf1477.dl.dropboxusercontent.com (uca5d3b1d15dcf051e5077bf1477.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CkuKLSAaO7W6u5Ah-bo09wcCY9sFqv5NNaJ__hA52kF7CdDYjiH30XDnAq2cR9cfj8zlX3_osvPC6vOGUrhnk4NQBODmngKE3MK7UM2rPs8VWrIule7poEZU0Tu50vBnBwxAn1wwkN_knQJmjC4QfAK3LAZzCjzdgHOe4zidV0JKh4Co4raYJi3PiR-yy05Lj33ip960nELHreCheLwsTTo82D8eyUKbEWImFWlKubzP1e5L6_vuAOtbpLp7-uW9TKUIpu8f04gF0lm56ZVhDSJjUvYH-8qqSFRrrxeRsw_OGZuCwwhYmWpI8EMlmb2AcGbp-OaCUFucECJc0qImraZEDUbovHCUzeuLRPrUwE77zAjMLZbbDaHb79jRROxG8bI/file [following]
# --2025-02-24 01:40:06--  https://uca5d3b1d15dcf051e5077bf1477.dl.dropboxusercontent.com/cd/0/inline2/CkuKLSAaO7W6u5Ah-bo09wcCY9sFqv5NNaJ__hA52kF7CdDYjiH30XDnAq2cR9cfj8zlX3_osvPC6vOGUrhnk4NQBODmngKE3MK7UM2rPs8VWrIule7poEZU0Tu50vBnBwxAn1wwkN_knQJmjC4QfAK3LAZzCjzdgHOe4zidV0JKh4Co4raYJi3PiR-yy05Lj33ip960nELHreCheLwsTTo82D8eyUKbEWImFWlKubzP1e5L6_vuAOtbpLp7-uW9TKUIpu8f04gF0lm56ZVhDSJjUvYH-8qqSFRrrxeRsw_OGZuCwwhYmWpI8EMlmb2AcGbp-OaCUFucECJc0qImraZEDUbovHCUzeuLRPrUwE77zAjMLZbbDaHb79jRROxG8bI/file
# Reusing existing connection to uca5d3b1d15dcf051e5077bf1477.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 37496786 (36M) [application/zip]
# Saving to: ‘TIMIT_tiny.zip’
#
# TIMIT_tiny.zip      100%[===================>]  35.76M  72.5MB/s    in 0.5s
#
# 2025-02-24 01:40:06 (72.5 MB/s) - ‘TIMIT_tiny.zip’ saved [37496786/37496786]

# %% [markdown]
# **Run the code below** to unzip the dataset.

# %%
# !unzip /content/TIMIT_tiny.zip -d data
# Out:
# Archive:  /content/TIMIT_tiny.zip
#    creating: data/fcmr0/
#   inflating: data/fcmr0/sx385.wav
#   inflating: data/fcmr0/si475.mfc25
#   inflating: data/fcmr0/sa1.lab
#   inflating: data/fcmr0/sx385.txt
#   inflating: data/fcmr0/si1105.phn
#   inflating: data/fcmr0/sx385.mfc30
#   inflating: data/fcmr0/si475.txt
#   inflating: data/fcmr0/sx115.txt
#   inflating: data/fcmr0/si1105.PHN_SP
#   inflating: data/fcmr0/si1735.mfc50
#   inflating: data/fcmr0/sa1.wav
#   inflating: data/fcmr0/sa1.phn
#   inflating: data/fcmr0/sx115.mfc30
#   inflating: data/fcmr0/si475.mfc30
#   inflating: data/fcmr0/sx25.mfc30
#   inflating: data/fcmr0/sx295.PHN_SP
#   inflating: data/fcmr0/sx205.wrd
#   inflating: data/fcmr0/si475.PHN_SP
#   inflating: data/fcmr0/sa1.mfc25
#   inflating: data/fcmr0/sx385.wrd
#   inflating: data/fcmr0/sx115.wav
#   inflating: data/fcmr0/si1105.mfc50
#   inflating: data/fcmr0/sx25.wav
#   inflating: data/fcmr0/sa1.txt
#   inflating: data/fcmr0/sx295.phn
#   inflating: data/fcmr0/sa2.wav
#   inflating: data/fcmr0/sx205.lab
#   inflating: data/fcmr0/si1105.mfc30
#   inflating: data/fcmr0/si1105.wav
#   inflating: data/fcmr0/sx115.lab
#   inflating: data/fcmr0/sx295.wav
#   inflating: data/fcmr0/sx115.mfc25
#   inflating: data/fcmr0/si1735.mfc20
#   inflating: data/fcmr0/si1735.wrd
#   inflating: data/fcmr0/sx25.mfc40
#   inflating: data/fcmr0/si1735.lab
#   inflating: data/fcmr0/si1735.wav
#   inflating: data/fcmr0/sx25.mfc20
#   inflating: data/fcmr0/si1105.lab
#   inflating: data/fcmr0/sx25.mfc50
#   inflating: data/fcmr0/si475.mfc50
#   inflating: data/fcmr0/sx385.mfc40
#   inflating: data/fcmr0/si475.mfc20
#   inflating: data/fcmr0/si1735.mfc40
#   inflating: data/fcmr0/sx25.wrd
#   inflating: data/fcmr0/si1105.mfc20
#   inflating: data/fcmr0/sx205.txt
#   inflating: data/fcmr0/sx205.mfc20
#   inflating: data/fcmr0/si1735.txt
#   inflating: data/fcmr0/si475.phn
#   inflating: data/fcmr0/si1105.wrd
#   inflating: data/fcmr0/si1735.mfc30
#   inflating: data/fcmr0/sx25.txt
#   inflating: data/fcmr0/sx385.PHN_SP
#   inflating: data/fcmr0/sx205.mfc30
#   inflating: data/fcmr0/sx25.PHN_SP
#   inflating: data/fcmr0/si475.mfc40
#   inflating: data/fcmr0/sx295.mfc20
#   inflating: data/fcmr0/sx115.mfc50
#   inflating: data/fcmr0/sx295.mfc25
#   inflating: data/fcmr0/sx385.lab
#   inflating: data/fcmr0/sa1.mfc20
#   inflating: data/fcmr0/sa2.mfc20
#   inflating: data/fcmr0/si475.wav
#   inflating: data/fcmr0/sx295.mfc50
#   inflating: data/fcmr0/sx385.mfc20
#   inflating: data/fcmr0/sx25.phn
#   inflating: data/fcmr0/sx115.wrd
#   inflating: data/fcmr0/sx205.phn
#   inflating: data/fcmr0/si1735.phn
#   inflating: data/fcmr0/si1735.PHN_SP
#   inflating: data/fcmr0/sx295.lab
#   inflating: data/fcmr0/sx115.PHN_SP
#   inflating: data/fcmr0/sx295.mfc30
#   inflating: data/fcmr0/sx295.wrd
#   inflating: data/fcmr0/sx205.mfc50
#   inflating: data/fcmr0/sx25.mfc25
#   inflating: data/fcmr0/sx385.mfc50
#   inflating: data/fcmr0/si475.lab
#   inflating: data/fcmr0/sa2.mfc25
#   inflating: data/fcmr0/sx115.mfc40
#   inflating: data/fcmr0/sx205.PHN_SP
#   inflating: data/fcmr0/sx205.mfc40
#   inflating: data/fcmr0/sa2.phn
#   inflating: data/fcmr0/sa2.txt
#   inflating: data/fcmr0/sa1.wrd
#   inflating: data/fcmr0/sa1.PHN_SP
#   inflating: data/fcmr0/si1105.mfc40
#   inflating: data/fcmr0/sa2.PHN_SP
#   inflating: data/fcmr0/sx115.phn
#   inflating: data/fcmr0/sx25.lab
#   inflating: data/fcmr0/sx205.wav
#   inflating: data/fcmr0/sx295.txt
#   inflating: data/fcmr0/sx205.mfc25
#   inflating: data/fcmr0/sx115.mfc20
#   inflating: data/fcmr0/si475.wrd
#   inflating: data/fcmr0/si1735.mfc25
#   inflating: data/fcmr0/si1105.txt
#   inflating: data/fcmr0/sx385.phn
#   inflating: data/fcmr0/si1105.mfc25
#   inflating: data/fcmr0/sa2.wrd
#   inflating: data/fcmr0/sx385.mfc25
#   inflating: data/fcmr0/sa2.lab
#   inflating: data/fcmr0/sx295.mfc40
#    creating: data/fdrd1/
#   inflating: data/fdrd1/si2149.phn
#   inflating: data/fdrd1/sa1.lab
#   inflating: data/fdrd1/si1544.mfc30
#   inflating: data/fdrd1/sx104.mfc40
#   inflating: data/fdrd1/sx284.PHN_SP
#   inflating: data/fdrd1/si1544.PHN_SP
#   inflating: data/fdrd1/sx284.wrd
#   inflating: data/fdrd1/sx104.wav
#   inflating: data/fdrd1/sx284.mfc25
#   inflating: data/fdrd1/sx14.lab
#   inflating: data/fdrd1/sx284.mfc20
#   inflating: data/fdrd1/sa1.wav
#   inflating: data/fdrd1/sx284.mfc40
#   inflating: data/fdrd1/sa1.phn
#   inflating: data/fdrd1/sx104.PHN_SP
#   inflating: data/fdrd1/sa2.txt
#   inflating: data/fdrd1/si1544.wav
#   inflating: data/fdrd1/sa1.wrd
#   inflating: data/fdrd1/sa1.PHN_SP
#   inflating: data/fdrd1/sx374.mfc50
#   inflating: data/fdrd1/si1544.mfc25
#   inflating: data/fdrd1/sx104.phn
#   inflating: data/fdrd1/si1566.mfc30
#   inflating: data/fdrd1/sa2.PHN_SP
#   inflating: data/fdrd1/sx104.wrd
#   inflating: data/fdrd1/sx374.mfc25
#   inflating: data/fdrd1/sx374.lab
#   inflating: data/fdrd1/si1566.wrd
#   inflating: data/fdrd1/si2149.lab
#   inflating: data/fdrd1/si2149.mfc25
#   inflating: data/fdrd1/sx284.mfc30
#   inflating: data/fdrd1/sx194.mfc20
#   inflating: data/fdrd1/sx374.mfc30
#   inflating: data/fdrd1/sa2.wrd
#   inflating: data/fdrd1/sa2.lab
#   inflating: data/fdrd1/sx104.mfc25
#    creating: data/fjas0/
#   inflating: data/fjas0/sx50.mfc50
#   inflating: data/fjas0/sa1.lab
#   inflating: data/fjas0/si770.mfc50
#   inflating: data/fjas0/sx320.mfc20
#   inflating: data/fjas0/si2030.mfc25
#   inflating: data/fjas0/si1400.wav
#   inflating: data/fjas0/sx230.lab
#   inflating: data/fjas0/si770.PHN_SP
#   inflating: data/fjas0/sx140.wav
#   inflating: data/fjas0/sx230.wrd
#   inflating: data/fjas0/si1400.mfc30
#   inflating: data/fjas0/sx50.lab
#   inflating: data/fjas0/sa1.wav
#   inflating: data/fjas0/si2030.mfc40
#   inflating: data/fjas0/sx50.mfc25
#   inflating: data/fjas0/sa1.phn
#   inflating: data/fjas0/sx320.PHN_SP
#   inflating: data/fjas0/sx50.PHN_SP
#   inflating: data/fjas0/sx140.lab
#   inflating: data/fjas0/sx320.wrd
#   inflating: data/fjas0/si2030.mfc50
#   inflating: data/fjas0/sx230.mfc50
#   inflating: data/fjas0/sa1.mfc25
#   inflating: data/fjas0/sa1.txt
#   inflating: data/fjas0/sx140.mfc20
#   inflating: data/fjas0/si1400.lab
#   inflating: data/fjas0/si770.mfc30
#   inflating: data/fjas0/si1400.mfc50
#   inflating: data/fjas0/sx140.mfc50
#   inflating: data/fjas0/sa2.wav
#   inflating: data/fjas0/si2030.PHN_SP
#   inflating: data/fjas0/sx230.wav
#   inflating: data/fjas0/sx320.phn
#   inflating: data/fjas0/sx410.wrd
#   inflating: data/fjas0/si1400.mfc25
#   inflating: data/fjas0/sx320.lab
#   inflating: data/fjas0/si770.wrd
#   inflating: data/fjas0/sx50.wav
#   inflating: data/fjas0/sx230.mfc30
#   inflating: data/fjas0/si2030.wav
#   inflating: data/fjas0/sx140.mfc40
#   inflating: data/fjas0/si2030.mfc20
#   inflating: data/fjas0/sx140.PHN_SP
#   inflating: data/fjas0/sx50.wrd
#   inflating: data/fjas0/sx410.mfc20
#   inflating: data/fjas0/sx50.phn
#   inflating: data/fjas0/sx410.wav
#   inflating: data/fjas0/sx230.mfc40
#   inflating: data/fjas0/si770.lab
#   inflating: data/fjas0/si1400.txt
#   inflating: data/fjas0/si2030.wrd
#   inflating: data/fjas0/sx320.mfc40
#   inflating: data/fjas0/si770.phn
#   inflating: data/fjas0/sx140.txt
#   inflating: data/fjas0/sx410.mfc25
#   inflating: data/fjas0/si770.mfc25
#   inflating: data/fjas0/sx410.mfc40
#   inflating: data/fjas0/sa1.mfc20
#   inflating: data/fjas0/sa2.mfc20
#   inflating: data/fjas0/sx140.phn
#   inflating: data/fjas0/si770.mfc20
#   inflating: data/fjas0/sx320.mfc50
#   inflating: data/fjas0/si1400.phn
#   inflating: data/fjas0/si2030.lab
#   inflating: data/fjas0/sx320.mfc30
#   inflating: data/fjas0/sx410.PHN_SP
#   inflating: data/fjas0/si2030.txt
#   inflating: data/fjas0/si2030.mfc30
#   inflating: data/fjas0/si1400.mfc40
#   inflating: data/fjas0/si770.txt
#   inflating: data/fjas0/si1400.wrd
#   inflating: data/fjas0/sx410.lab
#   inflating: data/fjas0/sx140.wrd
#   inflating: data/fjas0/sx320.wav
#   inflating: data/fjas0/sx230.mfc25
#   inflating: data/fjas0/sa2.mfc25
#   inflating: data/fjas0/sx410.mfc50
#   inflating: data/fjas0/si770.mfc40
#   inflating: data/fjas0/sa2.phn
#   inflating: data/fjas0/sx230.mfc20
#   inflating: data/fjas0/sa2.txt
#   inflating: data/fjas0/sx410.mfc30
#   inflating: data/fjas0/sx230.phn
#   inflating: data/fjas0/sa1.wrd
#   inflating: data/fjas0/sa1.PHN_SP
#   inflating: data/fjas0/sa2.PHN_SP
#   inflating: data/fjas0/si1400.PHN_SP
#   inflating: data/fjas0/sx50.mfc20
#   inflating: data/fjas0/sx50.txt
#   inflating: data/fjas0/sx230.PHN_SP
#   inflating: data/fjas0/si770.wav
#   inflating: data/fjas0/sx320.txt
#   inflating: data/fjas0/si1400.mfc20
#   inflating: data/fjas0/sx50.mfc40
#   inflating: data/fjas0/sx230.txt
#   inflating: data/fjas0/si2030.phn
#   inflating: data/fjas0/sx410.phn
#   inflating: data/fjas0/sx320.mfc25
#   inflating: data/fjas0/sx140.mfc25
#   inflating: data/fjas0/sx50.mfc30
#   inflating: data/fjas0/sx410.txt
#   inflating: data/fjas0/sa2.wrd
#   inflating: data/fjas0/sa2.lab
#   inflating: data/fjas0/sx140.mfc30
#    creating: data/fjre0/
#   inflating: data/fjre0/sx36.PHN_SP
#   inflating: data/fjre0/si1746.mfc30
#   inflating: data/fjre0/sa1.lab
#   inflating: data/fjre0/si1587.mfc20
#   inflating: data/fjre0/sx306.lab
#   inflating: data/fjre0/si1116.lab
#   inflating: data/fjre0/si1116.phn
#   inflating: data/fjre0/sx126.wrd
#   inflating: data/fjre0/sx36.mfc50
#   inflating: data/fjre0/si1587.PHN_SP
#   inflating: data/fjre0/sx36.txt
#   inflating: data/fjre0/sx126.mfc25
#   inflating: data/fjre0/sa1.wav
#   inflating: data/fjre0/sa1.phn
#   inflating: data/fjre0/si1587.wav
#   inflating: data/fpas0/sx134.wav
#   inflating: data/fpas0/sx224.wav
#   inflating: data/fpas0/sx404.mfc25
#   inflating: data/fpas0/sa1.mfc25
#   inflating: data/fpas0/sx224.mfc50
#   inflating: data/fpas0/sa1.txt
#   inflating: data/fpas0/si944.mfc40
#   inflating: data/fpas0/sx404.mfc40
#   inflating: data/fpas0/sx44.mfc20
#   inflating: data/fpas0/sx44.txt
#   inflating: data/fpas0/si944.wav
#   inflating: data/fpas0/sx134.txt
#   inflating: data/fpas0/sa2.wav
#   inflating: data/fpas0/sx44.lab
#   inflating: data/fpas0/sx314.phn
#   inflating: data/fpas0/si2204.mfc30
#   inflating: data/fpas0/si944.wrd
#   inflating: data/fpas0/sx404.wrd
#   inflating: data/fpas0/sx44.phn
#   inflating: data/fpas0/sx44.wav
#   inflating: data/fpas0/si1272.mfc20
#   inflating: data/fpas0/sx404.PHN_SP
#   inflating: data/fpas0/si2204.PHN_SP
#   inflating: data/fpas0/sx134.wrd
#   inflating: data/fpas0/sx134.mfc30
#   inflating: data/fpas0/sx404.mfc30
#   inflating: data/fpas0/si944.mfc30
#   inflating: data/fpas0/si1272.txt
#   inflating: data/fpas0/sx224.wrd
#   inflating: data/fpas0/si1272.mfc25
#   inflating: data/fpas0/si2204.phn
#   inflating: data/fpas0/si1272.wav
#   inflating: data/fpas0/sx314.wrd
#   inflating: data/fpas0/sx224.mfc30
#   inflating: data/fpas0/sx404.txt
#   inflating: data/fpas0/sx134.PHN_SP
#   inflating: data/fpas0/sx224.phn
#   inflating: data/fpas0/si1272.PHN_SP
#   inflating: data/fpas0/si944.txt
#   inflating: data/fpas0/sa1.mfc20
#   inflating: data/fpas0/sa2.mfc20
#   inflating: data/fpas0/sx44.mfc30
#   inflating: data/fpas0/sx44.wrd
#   inflating: data/fpas0/si1272.phn
#   inflating: data/fpas0/sx224.lab
#   inflating: data/fpas0/si1272.wrd
#   inflating: data/fpas0/sx224.mfc25
#   inflating: data/fpas0/sx314.mfc30
#   inflating: data/fpas0/si944.phn
#   inflating: data/fpas0/si2204.lab
#   inflating: data/fpas0/sx134.mfc20
#   inflating: data/fpas0/sx134.lab
#   inflating: data/fpas0/sx224.PHN_SP
#   inflating: data/fpas0/sx314.lab
#   inflating: data/fpas0/si2204.txt
#   inflating: data/fpas0/sx314.txt
#   inflating: data/fpas0/sx404.mfc50
#   inflating: data/fpas0/si2204.mfc50
#   inflating: data/fpas0/si944.mfc25
#   inflating: data/fpas0/sx404.wav
#   inflating: data/fpas0/sx134.phn
#   inflating: data/fpas0/sx44.mfc25
#   inflating: data/fpas0/sa2.mfc25
#   inflating: data/fpas0/si1272.mfc50
#   inflating: data/fpas0/sa2.phn
#   inflating: data/fpas0/si2204.mfc20
#   inflating: data/fpas0/sa2.txt
#   inflating: data/fpas0/sx314.PHN_SP
#   inflating: data/fpas0/sx44.mfc40
#   inflating: data/fpas0/sx134.mfc40
#   inflating: data/fpas0/sa1.wrd
#   inflating: data/fpas0/si2204.mfc25
#   inflating: data/fpas0/sa1.PHN_SP
#   inflating: data/fpas0/sx224.mfc20
#   inflating: data/fpas0/sa2.PHN_SP
#   inflating: data/fpas0/si944.PHN_SP
#   inflating: data/fpas0/si944.mfc50
#   inflating: data/fpas0/sx44.mfc50
#   inflating: data/fpas0/sx134.mfc50
#   inflating: data/fpas0/si1272.mfc40
#   inflating: data/fpas0/si1272.mfc30
#   inflating: data/fpas0/si944.mfc20
#   inflating: data/fpas0/sx314.mfc40
#   inflating: data/fpas0/sx224.txt
#   inflating: data/fpas0/si2204.wav
#   inflating: data/fpas0/si2204.wrd
#   inflating: data/fpas0/sa2.wrd
#   inflating: data/fpas0/sa2.lab
#    creating: data/fram1/
#   inflating: data/fram1/sx10.mfc20
#   inflating: data/fram1/sx190.lab
#   inflating: data/fram1/sa1.lab
#   inflating: data/fram1/si522.wav
#   inflating: data/fram1/si730.mfc30
#   inflating: data/fram1/si1360.mfc50
#   inflating: data/fram1/sx370.mfc25
#   inflating: data/fram1/sx10.mfc25
#   inflating: data/fram1/si730.mfc20
#   inflating: data/fram1/si730.mfc50
#   inflating: data/fram1/si1360.phn
#   inflating: data/fram1/si730.txt
#   inflating: data/fram1/sa1.wav
#   inflating: data/fram1/sx370.PHN_SP
#   inflating: data/fram1/sx100.wav
#   inflating: data/fram1/sa1.phn
#   inflating: data/fram1/sx100.wrd
#   inflating: data/fram1/si730.mfc40
#   inflating: data/fram1/sx10.txt
#   inflating: data/fram1/sx190.mfc50
#   inflating: data/fram1/si522.phn
#   inflating: data/fram1/sa1.mfc25
#   inflating: data/fram1/sa1.txt
#   inflating: data/fram1/si730.wav
#   inflating: data/fram1/sx280.mfc50
#   inflating: data/fram1/si730.mfc25
#   inflating: data/fram1/sx190.wrd
#   inflating: data/fram1/sa2.wav
#   inflating: data/fram1/sx190.PHN_SP
#   inflating: data/fram1/si1360.mfc30
#   inflating: data/fram1/sx280.mfc25
#   inflating: data/fram1/si1360.PHN_SP
#   inflating: data/fram1/sx280.wrd
#   inflating: data/fram1/si1360.wav
#   inflating: data/fram1/sx10.mfc50
#   inflating: data/fram1/sx10.mfc40
#   inflating: data/fram1/sx280.lab
#   inflating: data/fram1/sx190.mfc40
#   inflating: data/fram1/sx370.mfc30
#   inflating: data/fram1/sx280.wav
#   inflating: data/fram1/si1360.mfc25
#   inflating: data/fram1/sx10.wav
#   inflating: data/fram1/si522.lab
#   inflating: data/fram1/sx190.mfc25
#   inflating: data/fram1/si522.mfc40
#   inflating: data/fram1/si730.wrd
#   inflating: data/fram1/si1360.mfc40
#   inflating: data/fram1/si522.mfc50
#   inflating: data/fram1/sx100.phn
#   inflating: data/fram1/si1360.wrd
#   inflating: data/fram1/sx10.wrd
#   inflating: data/fram1/sx10.mfc30
#   inflating: data/fram1/sa1.mfc20
#   inflating: data/fram1/sx370.txt
#   inflating: data/fram1/sx190.txt
#   inflating: data/fram1/sa2.mfc20
#   inflating: data/fram1/si1360.mfc20
#   inflating: data/fram1/si522.PHN_SP
#   inflating: data/fslb1/si1904.mfc20
#   inflating: data/fslb1/sa2.wrd
#   inflating: data/fslb1/sa2.lab
#   inflating: data/fslb1/sx104.mfc25
#    creating: data/mabw0/
#   inflating: data/mabw0/si1664.mfc40
#   inflating: data/mabw0/sx404.phn
#   inflating: data/mabw0/sx404.mfc20
#   inflating: data/mabw0/sa1.lab
#   inflating: data/mabw0/sx404.lab
#   inflating: data/mabw0/sx314.wav
#   inflating: data/mabw0/sx314.mfc50
#   inflating: data/mabw0/si1664.PHN_SP
#   inflating: data/mabw0/si2294.wrd
#   inflating: data/mabw0/si1230.wrd
#   inflating: data/mabw0/sx134.mfc25
#   inflating: data/mabw0/sx44.PHN_SP
#   inflating: data/mabw0/sx314.mfc25
#   inflating: data/mabw0/sx314.mfc20
#   inflating: data/mabw0/sa1.wav
#   inflating: data/mabw0/sx224.mfc40
#   inflating: data/mabw0/sa1.phn
#   inflating: data/mabw0/sx134.wav
#   inflating: data/mabw0/si1664.lab
#   inflating: data/mabw0/sx224.wav
#   inflating: data/mabw0/sx404.mfc25
#   inflating: data/mabw0/sa1.mfc25
#   inflating: data/mabw0/si1664.mfc30
#   inflating: data/mabw0/sx224.mfc50
#   inflating: data/mabw0/sa1.txt
#   inflating: data/mabw0/sx404.mfc40
#   inflating: data/mabw0/si2294.PHN_SP
#   inflating: data/mabw0/sx44.mfc20
#   inflating: data/mabw0/sx44.txt
#   inflating: data/mabw0/si1230.lab
#   inflating: data/mabw0/sx134.txt
#   inflating: data/mabw0/sa2.wav
#   inflating: data/mabw0/sx44.lab
#   inflating: data/mabw0/si1664.wav
#   inflating: data/mabw0/sx314.phn
#   inflating: data/mabw0/si2294.mfc30
#   inflating: data/mabw0/si2294.mfc25
#   inflating: data/mabw0/si1230.mfc30
#   inflating: data/mabw0/sx404.wrd
#   inflating: data/mabw0/sx44.phn
#   inflating: data/mabw0/sx44.wav
#   inflating: data/mabw0/si2294.phn
#   inflating: data/mabw0/sx404.PHN_SP
#   inflating: data/mabw0/sx134.wrd
#   inflating: data/mabw0/sx134.mfc30
#   inflating: data/mabw0/sx404.mfc30
#   inflating: data/mabw0/sx224.wrd
#   inflating: data/mabw0/sx314.wrd
#   inflating: data/mabw0/si2294.mfc20
#   inflating: data/mabw0/si1230.txt
#   inflating: data/mabw0/sx224.mfc30
#   inflating: data/mabw0/si2294.mfc40
#   inflating: data/mabw0/sx404.txt
#   inflating: data/mabw0/si1664.txt
#   inflating: data/mabw0/si1230.mfc40
#   inflating: data/mabw0/si2294.lab
#   inflating: data/mabw0/sx134.PHN_SP
#   inflating: data/mabw0/sx224.phn
#   inflating: data/mabw0/sa1.mfc20
#   inflating: data/mabw0/si1230.wav
#   inflating: data/mabw0/sa2.mfc20
#   inflating: data/mabw0/sx44.mfc30
#   inflating: data/mabw0/sx44.wrd
#   inflating: data/mabw0/sx224.lab
#   inflating: data/mabw0/si2294.txt
#   inflating: data/mabw0/sx224.mfc25
#   inflating: data/mabw0/si1664.phn
#   inflating: data/mabw0/sx314.mfc30
#   inflating: data/mabw0/sx134.mfc20
#   inflating: data/mabw0/sx134.lab
#   inflating: data/mabw0/sx224.PHN_SP
#   inflating: data/mabw0/sx314.lab
#   inflating: data/mabw0/sx314.txt
#   inflating: data/mabw0/sx404.mfc50
#   inflating: data/mabw0/si1230.phn
#   inflating: data/mabw0/si2294.wav
#   inflating: data/mabw0/sx404.wav
#   inflating: data/mabw0/si2294.mfc50
#   inflating: data/mabw0/sx134.phn
#   inflating: data/mabw0/sx44.mfc25
#   inflating: data/mabw0/sa2.mfc25
#   inflating: data/mabw0/si1664.wrd
#   inflating: data/mabw0/sa2.phn
#   inflating: data/mabw0/sa2.txt
#   inflating: data/mabw0/sx314.PHN_SP
#   inflating: data/mabw0/sx44.mfc40
#   inflating: data/mabw0/sx134.mfc40
#   inflating: data/mabw0/sa1.wrd
#   inflating: data/mabw0/sa1.PHN_SP
#   inflating: data/mabw0/sx224.mfc20
#   inflating: data/mabw0/si1230.mfc20
#   inflating: data/mabw0/si1230.mfc25
#   inflating: data/mabw0/sa2.PHN_SP
#   inflating: data/mabw0/si1230.mfc50
#   inflating: data/mabw0/sx44.mfc50
#   inflating: data/mabw0/si1664.mfc25
#   inflating: data/mabw0/sx134.mfc50
#   inflating: data/mabw0/sx314.mfc40
#   inflating: data/mabw0/si1664.mfc20
#   inflating: data/mabw0/sx224.txt
#   inflating: data/mabw0/si1230.PHN_SP
#   inflating: data/mabw0/sa2.wrd
#   inflating: data/mabw0/sa2.lab
#   inflating: data/mabw0/si1664.mfc50
#    creating: data/mbjk0/
#   inflating: data/mbjk0/sx185.lab
#   inflating: data/mbjk0/sa1.lab
#   inflating: data/mbjk0/si2128.PHN_SP
#   inflating: data/mbjk0/sx275.mfc30
#   inflating: data/mbjk0/sx95.wav
#   inflating: data/mbjk0/si545.PHN_SP
#   inflating: data/mbjk0/sx275.lab
#   inflating: data/mbjk0/sx5.lab
#   inflating: data/mbjk0/sx275.mfc50
#   inflating: data/mbjk0/si1175.mfc20
#   inflating: data/mbjk0/sx185.mfc40
#   inflating: data/mbjk0/si1175.wav
#   inflating: data/mbjk0/sx5.mfc30
#   inflating: data/mbjk0/sx275.mfc20
#   inflating: data/mbjk0/si545.mfc25
#   inflating: data/mbjk0/sx5.wrd
#   inflating: data/mbjk0/sx185.PHN_SP
#   inflating: data/mbjk0/sa1.wav
#   inflating: data/mbjk0/si545.mfc30
#   inflating: data/mbjk0/sa1.phn
#   inflating: data/mbjk0/si1175.mfc25
#   inflating: data/mbjk0/si545.mfc40
#   inflating: data/mbjk0/sx5.mfc25
#   inflating: data/mbjk0/si1175.mfc40
#   inflating: data/mbjk0/sa1.mfc25
#   inflating: data/mbjk0/sx185.txt
#   inflating: data/mbjk0/sa1.txt
#   inflating: data/mbjk0/sx275.mfc40
#   inflating: data/mbjk0/sa2.wav
#   inflating: data/mbjk0/si1175.txt
#   inflating: data/mbjk0/sx95.mfc50
#   inflating: data/mbjk0/si545.wav
#   inflating: data/mbjk0/si2128.mfc40
#   inflating: data/mbjk0/si545.wrd
#   inflating: data/mbjk0/sx5.mfc50
#   inflating: data/mbjk0/sx95.mfc40
#   inflating: data/mbjk0/si2128.wrd
#   inflating: data/mbjk0/si1175.wrd
#   inflating: data/mbjk0/si1175.PHN_SP
#   inflating: data/mbjk0/sx185.mfc20
#   inflating: data/mbjk0/sx5.txt
#   inflating: data/mbjk0/sx365.lab
#   inflating: data/mbjk0/si545.phn
#   inflating: data/mbjk0/sx275.PHN_SP
#   inflating: data/mbjk0/sx95.phn
#   inflating: data/mbjk0/sx185.wav
#   inflating: data/mbjk0/si1175.phn
#   inflating: data/mbjk0/si545.mfc50
#   inflating: data/mbjk0/sx365.PHN_SP
#   inflating: data/mbjk0/sx365.mfc20
#   inflating: data/mbjk0/sx275.wav
#   inflating: data/mbjk0/si2128.mfc20
#   inflating: data/mbjk0/sx275.wrd
#   inflating: data/mbjk0/sx275.txt
#   inflating: data/mbjk0/sa1.mfc20
#   inflating: data/mbjk0/sa2.mfc20
#   inflating: data/mbjk0/sx95.mfc30
#   inflating: data/mbjk0/si1175.mfc50
#   inflating: data/mbjk0/sx365.mfc50
#   inflating: data/mbjk0/sx365.mfc40
#   inflating: data/mbjk0/sx5.mfc40
#   inflating: data/mbjk0/si2128.wav
#   inflating: data/mbjk0/sx275.mfc25
#   inflating: data/mbjk0/sx95.wrd
#   inflating: data/mbjk0/sx365.mfc30
#   inflating: data/mbjk0/sx185.mfc30
#   inflating: data/mbjk0/sx5.PHN_SP
#   inflating: data/mbjk0/sx275.phn
#   inflating: data/mbjk0/sx95.lab
#   inflating: data/mbjk0/sx95.PHN_SP
#   inflating: data/mbjk0/sx365.wrd
#   inflating: data/mbjk0/sx365.mfc25
#   inflating: data/mbjk0/si545.txt
#   inflating: data/mbjk0/sa2.mfc25
#   inflating: data/mbjk0/sx185.phn
#   inflating: data/mbjk0/sa2.phn
#   inflating: data/mbjk0/sa2.txt
#   inflating: data/mbjk0/sx365.wav
#   inflating: data/mbjk0/sx95.mfc25
#   inflating: data/mbjk0/sx185.wrd
#   inflating: data/mbjk0/sx185.mfc25
#   inflating: data/mbjk0/sa1.wrd
#   inflating: data/mbjk0/si2128.mfc50
#   inflating: data/mbjk0/sx365.phn
#   inflating: data/mbjk0/sa1.PHN_SP
#   inflating: data/mbjk0/si1175.lab
#   inflating: data/mbjk0/si2128.phn
#   inflating: data/mbjk0/si2128.txt
#   inflating: data/mbjk0/sa2.PHN_SP
#   inflating: data/mbjk0/sx5.wav
#   inflating: data/mbjk0/sx5.mfc20
#   inflating: data/mbjk0/si545.mfc20
#   inflating: data/mbjk0/sx5.phn
#   inflating: data/mbjk0/si2128.mfc30
#   inflating: data/mbjk0/sx365.txt
#   inflating: data/mbjk0/si1175.mfc30
#   inflating: data/mbjk0/sx185.mfc50
#   inflating: data/mbjk0/si545.lab
#   inflating: data/mbjk0/sx95.mfc20
#   inflating: data/mbjk0/si2128.lab
#   inflating: data/mbjk0/sa2.wrd
#   inflating: data/mccs0/sx119.mfc20
#   inflating: data/mccs0/sx119.mfc30
#   inflating: data/mccs0/sx29.phn
#   inflating: data/mccs0/sx389.lab
#   inflating: data/mccs0/sx209.mfc50
#   inflating: data/mccs0/sx209.PHN_SP
#   inflating: data/mccs0/sx29.txt
#   inflating: data/mccs0/sa2.mfc25
#   inflating: data/mccs0/si2099.wav
#   inflating: data/mccs0/sa2.phn
#   inflating: data/mccs0/si839.PHN_SP
#   inflating: data/mccs0/sa2.txt
#   inflating: data/mccs0/si2099.txt
#   inflating: data/mccs0/si1469.wav
#   inflating: data/mccs0/sa1.wrd
#   inflating: data/mccs0/sx299.mfc50
#   inflating: data/mccs0/sa1.PHN_SP
#   inflating: data/mccs0/si1469.mfc30
#   inflating: data/mccs0/sx209.wrd
#   inflating: data/mccs0/sa2.PHN_SP
#   inflating: data/mccs0/sx29.PHN_SP
#   inflating: data/mccs0/sx209.phn
#   inflating: data/mccs0/sx299.PHN_SP
#   inflating: data/mccs0/sx29.mfc30
#   inflating: data/mccs0/sx389.mfc40
#   inflating: data/mccs0/sx119.mfc25
#   inflating: data/mccs0/si1469.phn
#   inflating: data/mccs0/sx209.lab
#   inflating: data/mccs0/si839.wav
#   inflating: data/mccs0/si839.mfc50
#   inflating: data/mccs0/sx389.txt
#   inflating: data/mccs0/sx119.mfc40
#   inflating: data/mccs0/sa2.wrd
#   inflating: data/mccs0/si2099.lab
#   inflating: data/mccs0/sx389.mfc20
#   inflating: data/mccs0/sa2.lab
#    creating: data/mcem0/
#   inflating: data/mcem0/sx48.mfc40
#   inflating: data/mcem0/si1398.wrd
#   inflating: data/mcem0/sx228.wrd
#   inflating: data/mcem0/sx48.lab
#   inflating: data/mcem0/si2028.mfc25
#   inflating: data/mcem0/si768.mfc20
#   inflating: data/mcem0/sa1.lab
#   inflating: data/mcem0/si2028.wav
#   inflating: data/mcem0/sx228.mfc30
#   inflating: data/mcem0/si768.phn
#   inflating: data/mcem0/sx48.mfc50
#   inflating: data/mcem0/si768.PHN_SP
#   inflating: data/mcem0/si1398.phn
#   inflating: data/mcem0/sx48.phn
#   inflating: data/mcem0/sx138.mfc20
#   inflating: data/mcem0/sx408.mfc50
#   inflating: data/mcem0/sx228.mfc40
#   inflating: data/mcem0/sa1.wav
#   inflating: data/mcem0/sx408.wrd
#   inflating: data/mcem0/sx138.mfc25
#   inflating: data/mcem0/sa1.phn
#   inflating: data/mcem0/si2028.lab
#   inflating: data/mcem0/sx48.mfc20
#   inflating: data/mcem0/sa1.mfc25
#   inflating: data/mcem0/si1398.PHN_SP
#   inflating: data/mcem0/sx408.mfc25
#   inflating: data/mcem0/sa1.txt
#   inflating: data/mcem0/si1398.mfc20
#   inflating: data/mcem0/sa2.wav
#   inflating: data/mcem0/sx318.mfc20
#   inflating: data/mcem0/si1398.mfc30
#   inflating: data/mcem0/sx318.phn
#   inflating: data/mcem0/sx228.lab
#   inflating: data/mcem0/si2028.mfc20
#   inflating: data/mcem0/si2028.phn
#   inflating: data/mcem0/sx138.PHN_SP
#   inflating: data/mcem0/si768.mfc30
#   inflating: data/mcem0/si2028.mfc40
#   inflating: data/mcem0/sx408.lab
#   inflating: data/mcem0/sx318.mfc40
#   inflating: data/mcem0/si768.lab
#   inflating: data/mcem0/sx138.phn
#   inflating: data/mcem0/sx408.wav
#   inflating: data/mcem0/si1398.mfc50
#   inflating: data/mcem0/sx318.lab
#   inflating: data/mcem0/sx228.mfc50
#   inflating: data/mcem0/sx318.wrd
#   inflating: data/mcem0/sx138.mfc30
#   inflating: data/mcem0/si768.txt
#   inflating: data/mcem0/sx48.mfc25
#   inflating: data/mcem0/si768.mfc40
#   inflating: data/mcem0/sx408.mfc30
#   inflating: data/mcem0/si768.wrd
#   inflating: data/mcem0/si2028.txt
#   inflating: data/mcem0/si2028.mfc50
#   inflating: data/mcem0/sx408.mfc20
#   inflating: data/mcem0/si768.mfc50
#   inflating: data/mcem0/sx318.mfc25
#   inflating: data/mcem0/sx228.PHN_SP
#   inflating: data/mcem0/sa1.mfc20
#   inflating: data/mcem0/sx48.PHN_SP
#   inflating: data/mcem0/sa2.mfc20
#   inflating: data/mcem0/sx318.PHN_SP
#   inflating: data/mcem0/sx48.mfc30
#   inflating: data/mcem0/sx48.wrd
#   inflating: data/mcem0/sx408.PHN_SP
#   inflating: data/mcem0/si1398.mfc40
#   inflating: data/mcem0/sx408.txt
#   inflating: data/mcem0/sx228.mfc20
#   inflating: data/mcem0/si1398.wav
#   inflating: data/mcem0/sx318.mfc30
#   inflating: data/mcem0/si768.mfc25
#   inflating: data/mcem0/sx228.wav
#   inflating: data/mcem0/si768.wav
#   inflating: data/mcem0/sx48.txt
#   inflating: data/mcem0/sx48.wav
#   inflating: data/mcem0/sx138.wrd
#   inflating: data/mcem0/sx228.txt
#   inflating: data/mcem0/sx138.wav
#   inflating: data/mcem0/si1398.mfc25
#   inflating: data/mcem0/sa2.mfc25
#   inflating: data/mcem0/sx318.txt
#   inflating: data/mcem0/sx318.mfc50
#   inflating: data/mcem0/si2028.PHN_SP
#   inflating: data/mcem0/sa2.phn
#   inflating: data/mcem0/si1398.txt
#   inflating: data/mcem0/sx138.mfc40
#   inflating: data/mcem0/sx318.wav
#   inflating: data/mcem0/sa2.txt
#   inflating: data/mcem0/sx138.mfc50
#   inflating: data/mcem0/sa1.wrd
#   inflating: data/mcem0/sa1.PHN_SP
#   inflating: data/mcem0/sx228.phn
#   inflating: data/mcem0/sa2.PHN_SP
#   inflating: data/mcem0/sx138.lab
#   inflating: data/mcem0/sx408.phn
#   inflating: data/mcem0/si2028.wrd
#   inflating: data/mcem0/si1398.lab
#   inflating: data/mcem0/sx228.mfc25
#   inflating: data/mcem0/si2028.mfc30
#   inflating: data/mcem0/sx408.mfc40
#   inflating: data/mcem0/sa2.wrd
#   inflating: data/mcem0/sa2.lab
#   inflating: data/mcem0/sx138.txt
# ...
#    creating: data/mtas1/
#   inflating: data/mtas1/sx208.mfc30
#   inflating: data/mtas1/sx388.phn
#   inflating: data/mtas1/si1473.phn
#   inflating: data/mtas1/si838.mfc30
#   inflating: data/mtas1/sa1.lab
#   inflating: data/mtas1/si2098.PHN_SP
#   inflating: data/mtas1/si1473.mfc20
#   inflating: data/mtas1/si838.PHN_SP
#   inflating: data/mtas1/si2098.phn
#   inflating: data/mtas1/sx388.wrd
#   inflating: data/mtas1/sx298.lab
#   inflating: data/mtas1/sx118.mfc40
#   inflating: data/mtas1/sx208.mfc50
#   inflating: data/mtas1/sx208.txt
#   inflating: data/mtas1/sa1.wav
#   inflating: data/mtas1/sa1.phn
#   inflating: data/mtas1/si1473.PHN_SP
#   inflating: data/mtas1/sx298.phn
#   inflating: data/mtas1/sx388.PHN_SP
#   inflating: data/mtas1/si1473.wrd
#   inflating: data/mtas1/sx28.wrd
#   inflating: data/mtas1/sx388.mfc40
#   inflating: data/mtas1/sx28.wav
#   inflating: data/mtas1/sa1.mfc25
#   inflating: data/mtas1/sx118.phn
#   inflating: data/mtas1/sx28.mfc40
#   inflating: data/mtas1/sa1.txt
#   inflating: data/mtas1/sx388.mfc30
#   inflating: data/mtas1/sx118.mfc30
#   inflating: data/mtas1/sx118.lab
#   inflating: data/mtas1/sa2.wav
#   inflating: data/mtas1/si2098.mfc20
#   inflating: data/mtas1/si838.mfc20
#   inflating: data/mtas1/si1473.mfc40
#   inflating: data/mtas1/sx208.wrd
#   inflating: data/mtas1/si2098.mfc25
#   inflating: data/mtas1/sx208.phn
#   inflating: data/mtas1/sx28.lab
#   inflating: data/mtas1/sx388.mfc20
#   inflating: data/mtas1/sx118.txt
#   inflating: data/mtas1/si2098.mfc40
#   inflating: data/mtas1/si1473.wav
#   inflating: data/mtas1/si838.lab
#   inflating: data/mtas1/sx118.PHN_SP
#   inflating: data/mtas1/sx208.mfc25
#   inflating: data/mtas1/sx28.PHN_SP
#   inflating: data/mtas1/si2098.lab
#   inflating: data/mtas1/si1473.mfc50
#   inflating: data/mtas1/sx388.txt
#   inflating: data/mtas1/sx28.mfc20
#   inflating: data/mtas1/sx208.PHN_SP
#   inflating: data/mtas1/si1473.lab
#   inflating: data/mtas1/sx118.mfc20
#   inflating: data/mtas1/sx298.mfc20
#   inflating: data/mtas1/si1473.mfc30
#   inflating: data/mtas1/si838.mfc40
#   inflating: data/mtas1/si838.mfc25
#   inflating: data/mtas1/sa1.mfc20
#   inflating: data/mtas1/sa2.mfc20
#   inflating: data/mtas1/sx208.lab
#   inflating: data/mtas1/si2098.wav
#   inflating: data/mtas1/sx388.wav
#   inflating: data/mtas1/si1473.mfc25
#   inflating: data/mtas1/sx28.txt
#   inflating: data/mtas1/sx298.mfc40
#   inflating: data/mtas1/sx298.mfc30
#   inflating: data/mtas1/sx298.mfc25
#   inflating: data/mtas1/si838.wav
#   inflating: data/mtas1/sx208.mfc40
#   inflating: data/mtas1/sx208.wav
#   inflating: data/mtas1/si838.mfc50
#   inflating: data/mtas1/sx298.wav
#   inflating: data/mtas1/sx388.mfc25
#   inflating: data/mtas1/sx118.wrd
#   inflating: data/mtas1/sx28.mfc50
#   inflating: data/mtas1/si2098.mfc30
#   inflating: data/mtas1/sx388.lab
#   inflating: data/mtas1/sx298.txt
#   inflating: data/mtas1/sx388.mfc50
#   inflating: data/mtas1/sx28.mfc30
#   inflating: data/mtas1/sa2.mfc25
#   inflating: data/mtas1/sx118.mfc50
#   inflating: data/mtas1/sa2.phn
#   inflating: data/mtas1/sx208.mfc20
#   inflating: data/mtas1/sx118.wav
#   inflating: data/mtas1/sa2.txt
#   inflating: data/mtas1/sa1.wrd
#   inflating: data/mtas1/sx28.mfc25
#   inflating: data/mtas1/sx298.mfc50
#   inflating: data/mtas1/si838.wrd
#   inflating: data/mtas1/sa1.PHN_SP
#   inflating: data/mtas1/sa2.PHN_SP
#   inflating: data/mtas1/sx298.wrd
#   inflating: data/mtas1/si838.phn
#   inflating: data/mtas1/si2098.txt
#   inflating: data/mtas1/sx298.PHN_SP
#   inflating: data/mtas1/si838.txt
#   inflating: data/mtas1/sx28.phn
#   inflating: data/mtas1/sx118.mfc25
#   inflating: data/mtas1/si2098.wrd
#   inflating: data/mtas1/sa2.wrd
#   inflating: data/mtas1/sa2.lab
#   inflating: data/mtas1/si2098.mfc50
#   inflating: data/mtas1/si1473.txt
#    creating: data/mtmr0/
#   inflating: data/mtmr0/sa1.lab
#   inflating: data/mtmr0/si1933.mfc50
#   inflating: data/mtmr0/sx223.lab
#   inflating: data/mtmr0/sx403.mfc50
#   inflating: data/mtmr0/sx403.phn
#   inflating: data/mtmr0/sx313.phn
#   inflating: data/mtmr0/si1933.phn
#   inflating: data/mtmr0/si673.phn
#   inflating: data/mtmr0/si1933.mfc40
#   inflating: data/mtmr0/si1933.mfc20
#   inflating: data/mtmr0/si1303.wav
#   inflating: data/mtmr0/sx313.mfc25
#   inflating: data/mtmr0/sa1.wav
#   inflating: data/mtmr0/sx313.wav
#   inflating: data/mtmr0/si1933.mfc25
#   inflating: data/mtmr0/sa1.phn
#   inflating: data/mtmr0/sx133.mfc30
#   inflating: data/mtmr0/si673.mfc40
#   inflating: data/mtmr0/sx223.PHN_SP
#   inflating: data/mtmr0/sa1.mfc25
#   inflating: data/mtmr0/sx43.PHN_SP
#   inflating: data/mtmr0/sa1.txt
#   inflating: data/mtmr0/si1933.wrd
#   inflating: data/mtmr0/si1303.phn
#   inflating: data/mtmr0/sx133.txt
#   inflating: data/mtmr0/sx223.phn
#   inflating: data/mtmr0/sx43.mfc50
#   inflating: data/mtmr0/si1933.txt
#   inflating: data/mtmr0/sx43.mfc20
#   inflating: data/mtmr0/sx223.txt
#   inflating: data/mtmr0/sx403.PHN_SP
#   inflating: data/mtmr0/sa2.wav
#   inflating: data/mtmr0/si1303.mfc40
#   inflating: data/mtmr0/sx223.mfc50
#   inflating: data/mtmr0/sx133.wav
#   inflating: data/mtmr0/sx43.lab
#   inflating: data/mtmr0/sx313.lab
#   inflating: data/mtmr0/sx403.mfc40
#   inflating: data/mtmr0/sx43.mfc30
#   inflating: data/mtmr0/si1933.lab
#   inflating: data/mtmr0/sx313.mfc20
#   inflating: data/mtmr0/sx403.lab
#   inflating: data/mtmr0/sx313.mfc50
#   inflating: data/mtmr0/sx403.wav
#   inflating: data/mtmr0/sx403.wrd
#   inflating: data/mtmr0/si673.txt
#   inflating: data/mtmr0/sx403.mfc25
#   inflating: data/mtmr0/si673.PHN_SP
#   inflating: data/mtmr0/si1303.PHN_SP
#   inflating: data/mtmr0/si1303.mfc20
#   inflating: data/mtmr0/sx223.wav
#   inflating: data/mtmr0/sx43.mfc25
#   inflating: data/mtmr0/sx223.mfc30
#   inflating: data/mtmr0/sx223.mfc20
#   inflating: data/mtmr0/sx403.mfc20
#   inflating: data/mtmr0/sa1.mfc20
#   inflating: data/mtmr0/sa2.mfc20
#   inflating: data/mtmr0/si1303.txt
#   inflating: data/mtmr0/sx313.txt
#   inflating: data/mtmr0/si1933.wav
#   inflating: data/mtmr0/si673.mfc50
#   inflating: data/mtmr0/sx403.txt
#   inflating: data/mtmr0/sx43.phn
#   inflating: data/mtmr0/sx223.wrd
#   inflating: data/mtmr0/si673.mfc20
#   inflating: data/mtmr0/sx223.mfc25
#   inflating: data/mtmr0/sx223.mfc40
#   inflating: data/mtmr0/sx313.mfc30
#   inflating: data/mtmr0/sx133.phn
#   inflating: data/mtmr0/si1303.lab
#   inflating: data/mtmr0/si673.wrd
#   inflating: data/mtmr0/si673.wav
#   inflating: data/mtmr0/sx133.PHN_SP
#   inflating: data/mtmr0/si673.mfc30
#   inflating: data/mtmr0/sx133.mfc25
#   inflating: data/mtmr0/sa2.mfc25
#   inflating: data/mtmr0/si1303.wrd
#   inflating: data/mtmr0/sx133.wrd
#   inflating: data/mtmr0/sx133.lab
#   inflating: data/mtmr0/sx43.wav
#   inflating: data/mtmr0/sa2.phn
#   inflating: data/mtmr0/sx133.mfc20
#   inflating: data/mtmr0/sa2.txt
#   inflating: data/mtmr0/sa1.wrd
#   inflating: data/mtmr0/sa1.PHN_SP
#   inflating: data/mtmr0/sx313.PHN_SP
#   inflating: data/mtmr0/sx403.mfc30
#   inflating: data/mtmr0/si1303.mfc25
#   inflating: data/mtmr0/si1933.mfc30
#   inflating: data/mtmr0/si1303.mfc30
#   inflating: data/mtmr0/sa2.PHN_SP
#   inflating: data/mtmr0/si673.mfc25
#   inflating: data/mtmr0/sx43.mfc40
#   inflating: data/mtmr0/si1303.mfc50
#   inflating: data/mtmr0/sx43.wrd
#   inflating: data/mtmr0/sx133.mfc40
#   inflating: data/mtmr0/si673.lab
#   inflating: data/mtmr0/si1933.PHN_SP
#   inflating: data/mtmr0/sx313.mfc40
#   inflating: data/mtmr0/sx313.wrd
#   inflating: data/mtmr0/sa2.wrd
#   inflating: data/mtmr0/sa2.lab
#   inflating: data/mtmr0/sx133.mfc50
#   inflating: data/mtmr0/sx43.txt
#    creating: data/mwew0/
#   inflating: data/mwew0/sx11.mfc25
#   inflating: data/mwew0/sa1.lab
#   inflating: data/mwew0/sx191.phn
#   inflating: data/mwew0/si1361.wav
#   inflating: data/mwew0/sx191.mfc40
#   inflating: data/mwew0/sx371.wrd
#   inflating: data/mwew0/si1991.mfc50
#   inflating: data/mwew0/sx11.mfc20
#   inflating: data/mwew0/si731.wav
#   inflating: data/mwew0/sa1.wav
#   inflating: data/mwew0/sx371.phn
#   inflating: data/mwew0/si1361.lab
#   inflating: data/mwew0/sx281.mfc20
#   inflating: data/mwew0/sa1.phn
#   inflating: data/mwew0/si731.txt
#   inflating: data/mwew0/si1361.mfc20
#   inflating: data/mwew0/si1991.mfc40
#   inflating: data/mwew0/sa1.mfc25
#   inflating: data/mwew0/sx101.wrd
#   inflating: data/mwew0/si731.mfc40
#   inflating: data/mwew0/sa1.txt
#   inflating: data/mwew0/si731.wrd
#   inflating: data/mwew0/sx191.mfc25
#   inflating: data/mwew0/sx191.mfc50
#   inflating: data/mwew0/sa2.wav
#   inflating: data/mwew0/si1361.mfc40
#   inflating: data/mwew0/sx11.mfc40
#   inflating: data/mwew0/si1991.wrd
#   inflating: data/mwew0/sx191.lab
#   inflating: data/mwew0/sx281.mfc25
#   inflating: data/mwew0/sx281.mfc30
#   inflating: data/mwew0/sx281.mfc40
#   inflating: data/mwew0/si1991.phn
#   inflating: data/mwew0/si1361.wrd
#   inflating: data/mwew0/sx371.wav
#   inflating: data/mwew0/sx11.phn
#   inflating: data/mwew0/si731.PHN_SP
#   inflating: data/mwew0/sx11.mfc30
#   inflating: data/mwew0/sx191.PHN_SP
#   inflating: data/mwew0/sx281.wrd
#   inflating: data/mwew0/sx371.lab
#   inflating: data/mwew0/sx371.txt
#   inflating: data/mwew0/si1991.mfc20
#   inflating: data/mwew0/sx281.PHN_SP
#   inflating: data/mwew0/si731.phn
#   inflating: data/mwew0/sx281.wav
#   inflating: data/mwew0/sa1.mfc20
#   inflating: data/mwew0/sa2.mfc20
#   inflating: data/mwew0/si1361.phn
#   inflating: data/mwew0/sx11.mfc50
#   inflating: data/mwew0/sx11.wrd
#   inflating: data/mwew0/si1361.mfc25
#   inflating: data/mwew0/si1991.lab
#   inflating: data/mwew0/si731.lab
#   inflating: data/mwew0/sx371.PHN_SP
#   inflating: data/mwew0/sx281.mfc50
#   inflating: data/mwew0/si1361.txt
#   inflating: data/mwew0/sx101.wav
#   inflating: data/mwew0/sx371.mfc25
#   inflating: data/mwew0/si1991.txt
#   inflating: data/mwew0/si731.mfc25
#   inflating: data/mwew0/sx101.mfc30
#   inflating: data/mwew0/si1361.mfc50
#   inflating: data/mwew0/sx371.mfc20
#   inflating: data/mwew0/sx101.txt
#   inflating: data/mwew0/sx101.mfc50
#   inflating: data/mwew0/sx11.lab
#   inflating: data/mwew0/sx191.mfc30
#   inflating: data/mwew0/si1361.mfc30
#   inflating: data/mwew0/sx371.mfc40
#   inflating: data/mwew0/si1991.mfc30
#   inflating: data/mwew0/sx371.mfc50
#   inflating: data/mwew0/sx101.lab
#   inflating: data/mwew0/si1991.mfc25
#   inflating: data/mwew0/sx191.txt
#   inflating: data/mwew0/sx191.mfc20
#   inflating: data/mwew0/sa2.mfc25
#   inflating: data/mwew0/sx11.PHN_SP
#   inflating: data/mwew0/si731.mfc30
#   inflating: data/mwew0/sx281.phn
#   inflating: data/mwew0/sa2.phn
#   inflating: data/mwew0/si1991.PHN_SP
#   inflating: data/mwew0/sx101.PHN_SP
#   inflating: data/mwew0/sa2.txt
#   inflating: data/mwew0/sa1.wrd
#   inflating: data/mwew0/si731.mfc20
#   inflating: data/mwew0/sa1.PHN_SP
#   inflating: data/mwew0/si1991.wav
#   inflating: data/mwew0/sx191.wrd
#   inflating: data/mwew0/sx11.wav
#   inflating: data/mwew0/sx101.mfc40
#   inflating: data/mwew0/sa2.PHN_SP
#   inflating: data/mwew0/sx101.mfc25
#   inflating: data/mwew0/si1361.PHN_SP
#   inflating: data/mwew0/sx281.txt
#   inflating: data/mwew0/sx371.mfc30
#   inflating: data/mwew0/sx191.wav
#   inflating: data/mwew0/sx101.phn
#   inflating: data/mwew0/sx101.mfc20
#   inflating: data/mwew0/sa2.wrd
#   inflating: data/mwew0/sa2.lab
#   inflating: data/mwew0/sx281.lab
#   inflating: data/mwew0/si731.mfc50
#   inflating: data/mwew0/sx11.txt
#    creating: data/mwvw0/
#   inflating: data/mwvw0/sx36.PHN_SP
#   inflating: data/mwvw0/si846.phn
#   inflating: data/mwvw0/sa1.lab
#   inflating: data/mwvw0/si1476.mfc30
#   inflating: data/mwvw0/sx306.lab
#   inflating: data/mwvw0/si1476.wav
#   inflating: data/mwvw0/si846.txt
#   inflating: data/mwvw0/si846.mfc25
#   inflating: data/mwvw0/sx126.wrd
#   inflating: data/mwvw0/sx36.mfc50
#   inflating: data/mwvw0/si846.wav
#   inflating: data/mwvw0/sx36.txt
#   inflating: data/mwvw0/si2106.lab
#   inflating: data/mwvw0/si1476.wrd
#   inflating: data/mwvw0/sx126.mfc25
#   inflating: data/mwvw0/si1476.PHN_SP
#   inflating: data/mwvw0/sa1.wav
#   inflating: data/mwvw0/sa1.phn
#   inflating: data/mwvw0/sx306.txt
#   inflating: data/mwvw0/sx216.mfc25
#   inflating: data/mwvw0/sx396.wav
#   inflating: data/mwvw0/sa1.mfc25
#   inflating: data/mwvw0/sx216.wrd
#   inflating: data/mwvw0/sx36.mfc40
#   inflating: data/mwvw0/sx306.phn
#   inflating: data/mwvw0/sx396.mfc20
#   inflating: data/mwvw0/sa1.txt
#   inflating: data/mwvw0/si846.lab
#   inflating: data/mwvw0/sx306.wav
#   inflating: data/mwvw0/sx306.wrd
#   inflating: data/mwvw0/sa2.wav
#   inflating: data/mwvw0/sx306.mfc20
#   inflating: data/mwvw0/sx126.mfc20
#   inflating: data/mwvw0/sx126.PHN_SP
#   inflating: data/mwvw0/sx36.wrd
#   inflating: data/mwvw0/sx36.wav
#   inflating: data/mwvw0/si2106.mfc30
#   inflating: data/mwvw0/sx126.phn
#   inflating: data/mwvw0/sx216.mfc30
#   inflating: data/mwvw0/sx36.mfc20
#   inflating: data/mwvw0/si2106.wrd
#   inflating: data/mwvw0/sx396.txt
#   inflating: data/mwvw0/sx36.mfc25
#   inflating: data/mwvw0/sx36.lab
#   inflating: data/mwvw0/si2106.mfc25
#   inflating: data/mwvw0/sx216.wav
#   inflating: data/mwvw0/sx396.mfc40
#   inflating: data/mwvw0/sx306.mfc25
#   inflating: data/mwvw0/sx396.PHN_SP
#   inflating: data/mwvw0/sx126.mfc50
#   inflating: data/mwvw0/sx396.lab
#   inflating: data/mwvw0/si2106.wav
#   inflating: data/mwvw0/si846.mfc40
#   inflating: data/mwvw0/si2106.txt
#   inflating: data/mwvw0/sx216.phn
#   inflating: data/mwvw0/sa1.mfc20
#   inflating: data/mwvw0/sa2.mfc20
#   inflating: data/mwvw0/sx126.wav
#   inflating: data/mwvw0/sx216.mfc20
#   inflating: data/mwvw0/si846.mfc20
#   inflating: data/mwvw0/sx126.mfc40
#   inflating: data/mwvw0/sx216.mfc50
#   inflating: data/mwvw0/si846.mfc30
#   inflating: data/mwvw0/si1476.txt
#   inflating: data/mwvw0/sx216.txt
#   inflating: data/mwvw0/sx306.PHN_SP
#   inflating: data/mwvw0/sx36.mfc30
#   inflating: data/mwvw0/sx396.phn
#   inflating: data/mwvw0/sx306.mfc30
#   inflating: data/mwvw0/sx126.lab
#   inflating: data/mwvw0/si1476.mfc40
#   inflating: data/mwvw0/sx396.mfc50
#   inflating: data/mwvw0/sx396.wrd
#   inflating: data/mwvw0/si1476.mfc50
#   inflating: data/mwvw0/si2106.PHN_SP
#   inflating: data/mwvw0/sx306.mfc40
#   inflating: data/mwvw0/sx216.lab
#   inflating: data/mwvw0/sx306.mfc50
#   inflating: data/mwvw0/sx36.phn
#   inflating: data/mwvw0/sa2.mfc25
#   inflating: data/mwvw0/sx216.mfc40
#   inflating: data/mwvw0/sa2.phn
#   inflating: data/mwvw0/sa2.txt
#   inflating: data/mwvw0/si846.mfc50
#   inflating: data/mwvw0/si2106.mfc20
#   inflating: data/mwvw0/sa1.wrd
#   inflating: data/mwvw0/si1476.lab
#   inflating: data/mwvw0/sa1.PHN_SP
#   inflating: data/mwvw0/sx216.PHN_SP
#   inflating: data/mwvw0/si1476.mfc20
#   inflating: data/mwvw0/sa2.PHN_SP
#   inflating: data/mwvw0/sx396.mfc30
#   inflating: data/mwvw0/si2106.mfc50
#   inflating: data/mwvw0/si846.wrd
#   inflating: data/mwvw0/sx126.mfc30
#   inflating: data/mwvw0/si2106.mfc40
#   inflating: data/mwvw0/si2106.phn
#   inflating: data/mwvw0/sx126.txt
#   inflating: data/mwvw0/sx396.mfc25
#   inflating: data/mwvw0/si1476.mfc25
#   inflating: data/mwvw0/si1476.phn
#   inflating: data/mwvw0/sa2.wrd
#   inflating: data/mwvw0/sa2.lab
#   inflating: data/mwvw0/si846.PHN_SP

# %% [markdown]
# **Run the code below to install speechbrain**.

# %%
# %%capture
# Installing SpeechBrain via pip
BRANCH = 'develop'
# !python -m pip install git+https://github.com/speechbrain/speechbrain.git@$BRANCH

# Clone SpeechBrain repository
# !git clone https://github.com/speechbrain/speechbrain/

# %% [markdown]
# ## **Exercise 1: Data Preparation**
#
# If you inspect the data stored in `/content/data` you will see 26 folders. Each folder contains the audio signals recorded for a single speaker. You can see different types of files in each folder. For this lab, you only need to consider the ".wav" ones. The name of each file (e.g., `si475.wav`) is a sentence identifier (`si475`). Each signal is sampled at 16 kHz.
#
# **Write the code for preparing the JSON data-manifest files**. You have to split the dataset into train, validation, and test sets. Always use the sentence 'sa1.wav' (available for each speaker) for validation. Use the sentence 'sa2.wav' (available for each speaker) for testing. Use all the other sentences for training.
#
# You have to create 3 JSON files:
# - 'train.json'
# - 'valid.json'
# - 'test.json'
#
# They should be formatted in the following way:
#
#
# **train.json**
# ```
# {
#   "mpgl0_si469": {
#     "path": "data/mpgl0/si469.wav",
#     "length": 2.88,
#     "spk": "mpgl0"
#   },
#   "mpgl0_si1729": {
#     "path": "data/mpgl0/si1729.wav",
#     "length": 3.5904375,
#     "spk": "mpgl0"
#   },
#   "mpgl0_si1099": {
#     "path": "data/mpgl0/si1099.wav",
#     "length": 2.86725,
#     "spk": "mpgl0"
#   },
# ....
#
# ```
#
# **valid.json**
# ```
# {
#   "mpgl0_sa1": {
#     "path": "data/mpgl0/sa1.wav",
#     "length": 3.6288125,
#     "spk": "mpgl0"
#   },
#   "mtmr0_sa1": {
#     "path": "data/mtmr0/sa1.wav",
#     "length": 3.18725,
#     "spk": "mtmr0"
#   },
#   "mwvw0_sa1": {
#     "path": "data/mwvw0/sa1.wav",
#     "length": 3.161625,
#     "spk": "mwvw0"
#   },
# ....
# ```
#
# **test.json**
#
# ```
# {
#   "mpgl0_sa2": {
#     "path": "data/mpgl0/sa2.wav",
#     "length": 3.02725,
#     "spk": "mpgl0"
#   },
#   "mtmr0_sa2": {
#     "path": "data/mtmr0/sa2.wav",
#     "length": 2.624,
#     "spk": "mtmr0"
#   },
#   "mwvw0_sa2": {
#     "path": "data/mwvw0/sa2.wav",
#     "length": 2.5088125,
#     "spk": "mwvw0"
#   },
#
# ```
#
# If everything is fine, you should have 208 files for training, 26 for validation, and 26 for testing.
#
# **Suggestions:**
# - Use the get_all_files in speechbrain.utils.data_utils to get a list of all the files with the wav extension.
# - You can get the number of samples of each wave with torchaudio.info. You have to compute the duration in seconds by diving it for the sampling frequency.

# %%
import torch
import torchaudio
import json
from speechbrain.utils.data_utils import get_all_files
import re
import json

# %% [markdown]
# **Your code here:**

# %%
import json
import torchaudio
from speechbrain.utils.data_utils import get_all_files
import os
from speechbrain.dataio.dataio import read_audio


# Your code here
audiofiles = get_all_files(os.path.join('/content/data'), match_and=[".wav"])

train_files = []
test_files = []
valid_files = []

for audiofile in audiofiles:
  if 'sa1.wav' == audiofile.split('/')[4]:
    valid_files.append(audiofile)
  elif 'sa2.wav' == audiofile.split('/')[4]:
    test_files.append(audiofile)
  elif'.wav' in audiofile.split('/')[4]:
    train_files.append(audiofile)


print(len(train_files))
print(len(test_files))
print(len(valid_files))


def create_json(json_file, audiolist):
  json_dict = {}
  for audiofile in audiofiles:

    # Getting info
    audioinfo = torchaudio.info(audiofile) # Your code here
    signal = read_audio(audiofile)


    # Compute the duration in seconds.
    # This is the number of samples divided by the sampling frequency
    duration = audioinfo.num_frames / audioinfo.sample_rate  # Your code here

    path = audiofile.split("/")[2] + "/"+ audiofile.split("/")[3] + "/" + audiofile.split("/")[4]

    speaker = audiofile.split("/")[-2]

    # Get a unique utterance id
    uttid =  audiofile.split("/")[-2] + "_" + audiofile.split("/")[-1][:-4] # Your code here (aim for 1 line)

    # Create entry for this utterance
    json_dict[uttid] = {
            "path": path,
            "length": duration,
            "spk": speaker,
    }

    # Writing the dictionary to the json file
    with open(json_file, mode="w", encoding="utf-8") as json_f:
      json.dump(json_dict, json_f, indent=2)



create_json('train.json', train_files)
create_json('valid.json', test_files)
create_json('test.json', valid_files)
# Out:
# 208
# 26
# 26

# %% [markdown]
# ## **Exercise 2: Speaker Identification with FBANKs and Xvectors**
#
# You have to implement the following model:

# %% [markdown]
# ![pictures-Page-1.drawio (6).png](data:image/png;base64,...)

# %% [markdown]
# **Suggestion:** You can copy-and-paste the code from the previous labs solving similar classification problems. You only need to do the little modifications to the hyperparameter and train.py files needed to implement the system in the figure.

# %% [markdown]
# **Write the code for the hyperparameters**:

# %%
# %%file hparams_xvector_fbanks.yaml
#
# # #################################
# # Basic training parameters for digit classification with Xvector
# #
# # Author:
# #  * Mirco Ravanelli 2021
# # #################################
#
# # Seed needs to be set at top of yaml, before objects with parameters are made
# seed: 1986
# __set_seed: !!python/object/apply:torch.manual_seed [!ref <seed>]
#
# output_folder: !ref ./results/Xvector/<seed>
# save_folder: !ref <output_folder>/save
# train_log: !ref <output_folder>/train_log.txt
#
# # Path where data manifest files are stored
# train_annotation: train.json
# valid_annotation: valid.json
# test_annotation: test.json
#
# # The train logger writes training statistics to a file, as well as stdout.
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
#
# error_stats: !name:speechbrain.utils.metric_stats.MetricStats
#     metric: !name:speechbrain.nnet.losses.classification_error
#         reduction: batch
#
# # Feature parameters
# n_mels: 40
#
# # Training Parameters
# sample_rate: 16000
# number_of_epochs: 20
# batch_size: 64
# lr_start: 0.001
# lr_final: 0.0001
# n_classes: 26 # In this case, we have 26 spekers
# emb_dim: 128 # dimensionality of the embeddings
# dataloader_options:
#     batch_size: !ref <batch_size>
#
# # Feature extraction
# compute_features: !new:speechbrain.lobes.features.Fbank
#     n_mels: !ref <n_mels>
#     deltas: False
#     context: False
#     requires_grad: False
#     sample_rate: !ref <sample_rate>
#     n_fft:  400
#     param_change_factor:  1.0
#     param_rand_factor:  0.0
#     left_frames:  5
#     right_frames: 5
#     win_length: 25
#     hop_length: 10
#
# # Mean and std normalization of the input features
# mean_var_norm: !new:speechbrain.processing.features.InputNormalization
#     norm_type: global
#
# # Embedding model: from variable size digits gets a fixed size embedding vector
# embedding_model: !new:speechbrain.lobes.models.Xvector.Xvector
#     in_channels: !ref <n_mels>
#     activation: !name:torch.nn.LeakyReLU
#     tdnn_blocks: 5
#     tdnn_channels: [64, 64, 64, 64, 128]
#     tdnn_kernel_sizes: [5, 3, 3, 1, 1]
#     tdnn_dilations: [1, 2, 3, 1, 1]
#     lin_neurons: !ref <emb_dim>
#
# # Clasifier applied on top of the embeddings
# classifier: !new:speechbrain.lobes.models.Xvector.Classifier
#     input_shape: [null, null, !ref <emb_dim>]
#     activation: !name:torch.nn.LeakyReLU
#     lin_blocks: 1
#     lin_neurons: !ref <emb_dim>
#     out_neurons: !ref <n_classes>
#
# # The first object passed to the Brain class is this "Epoch Counter"
# # which is saved by the Checkpointer so that training can be resumed
# # if it gets interrupted at any point.
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <number_of_epochs>
#
# # Objects in "modules" dict will have their parameters moved to the correct
# # device, as well as having train()/eval() called on them by the Brain class.
# modules:
#     compute_features: !ref <compute_features>
#     mean_var_norm: !ref <mean_var_norm>
#     embedding_model: !ref <embedding_model>
#     classifier: !ref <classifier>
#
# # This optimizer will be constructed by the Brain class after all parameters
# # are moved to the correct device. Then it will be added to the checkpointer.
# opt_class: !name:torch.optim.Adam
#     lr: !ref <lr_start>
#
# # This function manages learning rate annealing over the epochs.
# # We here use the simple lr annealing method that linearly decreases
# # the lr from the initial value to the final one.
# lr_annealing: !new:speechbrain.nnet.schedulers.LinearScheduler
#     initial_value: !ref <lr_start>
#     final_value: !ref <lr_final>
#     epoch_count: !ref <number_of_epochs>
#
# # This object is used for saving the state of training both so that it
# # can be resumed if it gets interrupted, and also so that the best checkpoint
# # can be later loaded for evaluation or inference.
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         embedding_model: !ref <embedding_model>
#         classifier: !ref <classifier>
#         normalizer: !ref <mean_var_norm>
#         counter: !ref <epoch_counter>
# Out:
# Overwriting hparams_xvector_fbanks.yaml

# %% [markdown]
# **Write the code for the training script**:

# %%
# %%file train.py

#!/usr/bin/env python3
"Recipe for training a speaker classification system."
import os
import sys
import torch
import torchaudio
import speechbrain as sb
from hyperpyyaml import load_hyperpyyaml
import torchaudio.functional as F

class TIMITBrain(sb.Brain):
    def compute_forward(self, batch, stage):
        """Computations from input to output probabilities"""
        batch = batch.to(self.device)
        wavs, lens = batch.sig  # unpacking of audio data

        # # Audio augmentation for training stage
        # if stage == sb.Stage.TRAIN and hasattr(self.hparams, "wav_augment"):
        #     wavs, lens = self.hparams.wav_augment(wavs, lens)

        # Feature extraction and normalization
        features = self.modules.compute_features(wavs)

        features = self.modules.mean_var_norm(features, lens)

        # Embedding generation
        embeddings = self.modules.embedding_model(features,lens)

        # Classifier predictions
        predictions = self.modules.classifier(embeddings)
        return predictions

    def compute_objectives(self, predictions, batch, stage):
        """Compute classification loss"""
        _, lens = batch.sig
        spk, _ = batch.spk_encoded

        # # Handle augmented samples
        # if stage == sb.Stage.TRAIN and hasattr(self.modules, "env_corrupt"):
        #     spk = torch.cat([spk, spk], dim=0)
        #     lens = torch.cat([lens, lens])

        loss = sb.nnet.losses.nll_loss(predictions, spk, lens)

        # Update metrics
        self.loss_metric.append(batch.id, predictions, spk, lens, reduction="batch")
        if stage != sb.Stage.TRAIN:
            self.error_metrics.append(batch.id, predictions, spk, lens)

        return loss

    def on_stage_start(self, stage, epoch=None):
        """Initialize metrics"""
        self.loss_metric = sb.utils.metric_stats.MetricStats(
            metric=sb.nnet.losses.nll_loss
        )
        if stage != sb.Stage.TRAIN:
            self.error_metrics = self.hparams.error_stats()

    def on_stage_end(self, stage, stage_loss, epoch=None):
        """Handle end-of-stage operations"""
        if stage == sb.Stage.TRAIN:
            self.train_loss = stage_loss
        else:
            stats = {"loss": stage_loss, "error": self.error_metrics.summarize("average")}

        if stage == sb.Stage.VALID:
            old_lr, new_lr = self.hparams.lr_annealing(epoch)
            sb.nnet.schedulers.update_learning_rate(self.optimizer, new_lr)
            self.hparams.train_logger.log_stats(
                {"Epoch": epoch, "lr": old_lr},
                train_stats={"loss": self.train_loss},
                valid_stats=stats,
            )
            self.checkpointer.save_and_keep_only(meta=stats, min_keys=["error"])

        if stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                {"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stats,
            )

def dataio_prep(hparams):
    """Prepare data pipelines"""
    label_encoder = sb.dataio.encoder.CategoricalEncoder()

    # # Create directories if they don't exist
    # os.makedirs(hparams["save_folder"], exist_ok=True)


    @sb.utils.data_pipeline.takes("path")
    @sb.utils.data_pipeline.provides("sig")
    def audio_pipeline(wav_path):
        sig = sb.dataio.dataio.read_audio(wav_path)
        # info = torchaudio.info(wav_path)
        # if info.sample_rate != hparams["sample_rate"]:
        #     sig = F.resample(sig, info.sample_rate, hparams["sample_rate"])
        sig =  sig.squeeze()
        return sig

    @sb.utils.data_pipeline.takes("spk")
    @sb.utils.data_pipeline.provides("spk", "spk_encoded")
    def label_pipeline(spk):
        yield spk
        spk_encoded = label_encoder.encode_label_torch(spk)
        yield spk_encoded

    datasets = {}
    data_info = {
        "train": hparams["train_annotation"],
        "valid": hparams["valid_annotation"],
        "test": hparams["test_annotation"],
    }
    hparams["dataloader_options"]["shuffle"] = True
    for dataset in data_info:
        datasets[dataset] = sb.dataio.dataset.DynamicItemDataset.from_json(
            json_path=data_info[dataset],
            dynamic_items=[audio_pipeline, label_pipeline],
            output_keys=["id", "sig", "spk_encoded"],
        )

    lab_enc_file = os.path.join(hparams["save_folder"], "label_encoder.txt")
    label_encoder.load_or_create(
        path=lab_enc_file,
        from_didatasets=[datasets["train"]],
        output_key="spk",
    )

    return datasets

if __name__ == "__main__":

    # Reading command line arguments.
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])

    # Load hyperparameters file with command-line overrides.
    with open(hparams_file) as fin:
        hparams = load_hyperpyyaml(fin,  overrides)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )

    # Create dataset objects "train", "valid", and "test".
    datasets = dataio_prep(hparams)

    # Initialize the Brain object to prepare for mask training.
    digit_brain = TIMITBrain(
        modules=hparams["modules"],
        opt_class=hparams["opt_class"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )

    # The `fit()` method iterates the training loop, calling the methods
    # necessary to update the parameters of the model. Since all objects
    # with changing state are managed by the Checkpointer, training can be
    # stopped at any point, and will be resumed on next call.
    digit_brain.fit(
        epoch_counter=digit_brain.hparams.epoch_counter,
        train_set=datasets["train"],
        valid_set=datasets["valid"],
        train_loader_kwargs=hparams["dataloader_options"],
        valid_loader_kwargs=hparams["dataloader_options"],
    )

    # Load the best checkpoint for evaluation
    test_stats = digit_brain.evaluate(
        test_set=datasets["test"],
        min_key="error",
        test_loader_kwargs=hparams["dataloader_options"],
    )
# Out:
# Overwriting train.py

# %%
# !rm -rf ./results/

# %% [markdown]
# **Run the code below to train your model.**

# %%
# Delete the output folder to start training from scratch
# (and not from a previous checkpoint).
# !rm -rf ./results/

# Run Training
# !python train.py hparams_xvector_fbanks.yaml --device='cpu'
# Out:
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:68: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: ./results/Xvector/1986
# speechbrain.dataio.encoder - Load called, but CategoricalEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# /usr/local/lib/python3.11/dist-packages/speechbrain/core.py:798: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=gradscaler_enabled)
# speechbrain.core - TIMITBrain Model Statistics:
# * Total Number of Trainable Parameters: 104.1k
# * Total Number of Parameters: 104.1k
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
# speechbrain.dataio.encoder - CategoricalEncoder.expect_len was never called: assuming category count of 26 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
# 100% 5/5 [00:08<00:00,  1.77s/it, train_loss=2.92]
# 100% 5/5 [00:02<00:00,  2.06it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.001 to 0.00095
# speechbrain.utils.train_logger - Epoch: 1, lr: 1.00e-03 - train loss: 2.92 - valid loss: 3.26, valid error: 9.62e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-54-29+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100% 5/5 [00:07<00:00,  1.59s/it, train_loss=2.26]
# 100% 5/5 [00:02<00:00,  2.01it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00095 to 0.00091
# speechbrain.utils.train_logger - Epoch: 2, lr: 9.53e-04 - train loss: 2.26 - valid loss: 3.26, valid error: 9.62e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-54-39+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-54-29+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100% 5/5 [00:07<00:00,  1.57s/it, train_loss=1.55]
# 100% 5/5 [00:02<00:00,  1.76it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00091 to 0.00086
# speechbrain.utils.train_logger - Epoch: 3, lr: 9.05e-04 - train loss: 1.55 - valid loss: 3.27, valid error: 9.62e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-54-50+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-54-39+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100% 5/5 [00:07<00:00,  1.60s/it, train_loss=1.34]
# 100% 5/5 [00:03<00:00,  1.37it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00086 to 0.00081
# speechbrain.utils.train_logger - Epoch: 4, lr: 8.58e-04 - train loss: 1.34 - valid loss: 3.26, valid error: 9.62e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-02+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-54-50+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100% 5/5 [00:07<00:00,  1.54s/it, train_loss=1.05]
# 100% 5/5 [00:03<00:00,  1.50it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00081 to 0.00076
# speechbrain.utils.train_logger - Epoch: 5, lr: 8.11e-04 - train loss: 1.05 - valid loss: 3.16, valid error: 9.19e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-13+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-02+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100% 5/5 [00:08<00:00,  1.69s/it, train_loss=0.87]
# 100% 5/5 [00:02<00:00,  1.76it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00076 to 0.00072
# speechbrain.utils.train_logger - Epoch: 6, lr: 7.63e-04 - train loss: 8.70e-01 - valid loss: 2.84, valid error: 8.38e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-24+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-13+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100% 5/5 [00:08<00:00,  1.76s/it, train_loss=0.682]
# 100% 5/5 [00:02<00:00,  1.85it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00072 to 0.00067
# speechbrain.utils.train_logger - Epoch: 7, lr: 7.16e-04 - train loss: 6.82e-01 - valid loss: 2.18, valid error: 7.50e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-36+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-24+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100% 5/5 [00:08<00:00,  1.74s/it, train_loss=0.512]
# 100% 5/5 [00:02<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00067 to 0.00062
# speechbrain.utils.train_logger - Epoch: 8, lr: 6.68e-04 - train loss: 5.12e-01 - valid loss: 1.59, valid error: 3.81e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-47+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-36+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# 100% 5/5 [00:08<00:00,  1.76s/it, train_loss=0.457]
# 100% 5/5 [00:02<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00062 to 0.00057
# speechbrain.utils.train_logger - Epoch: 9, lr: 6.21e-04 - train loss: 4.57e-01 - valid loss: 1.06, valid error: 1.12e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-59+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-47+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# 100% 5/5 [00:08<00:00,  1.77s/it, train_loss=0.461]
# 100% 5/5 [00:02<00:00,  1.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00057 to 0.00053
# speechbrain.utils.train_logger - Epoch: 10, lr: 5.74e-04 - train loss: 4.61e-01 - valid loss: 7.88e-01, valid error: 2.31e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-10+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-55-59+00
# speechbrain.utils.epoch_loop - Going into epoch 11
# 100% 5/5 [00:08<00:00,  1.77s/it, train_loss=0.34]
# 100% 5/5 [00:02<00:00,  1.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00053 to 0.00048
# speechbrain.utils.train_logger - Epoch: 11, lr: 5.26e-04 - train loss: 3.40e-01 - valid loss: 6.23e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-10+00
# speechbrain.utils.epoch_loop - Going into epoch 12
# 100% 5/5 [00:08<00:00,  1.73s/it, train_loss=0.316]
# 100% 5/5 [00:02<00:00,  1.80it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00048 to 0.00043
# speechbrain.utils.train_logger - Epoch: 12, lr: 4.79e-04 - train loss: 3.16e-01 - valid loss: 5.26e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-22+00
# speechbrain.utils.epoch_loop - Going into epoch 13
# 100% 5/5 [00:08<00:00,  1.61s/it, train_loss=0.256]
# 100% 5/5 [00:03<00:00,  1.46it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00043 to 0.00038
# speechbrain.utils.train_logger - Epoch: 13, lr: 4.32e-04 - train loss: 2.56e-01 - valid loss: 4.06e-01, valid error: 7.69e-03
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-45+00
# speechbrain.utils.epoch_loop - Going into epoch 14
# 100% 5/5 [00:08<00:00,  1.61s/it, train_loss=0.275]
# 100% 5/5 [00:03<00:00,  1.38it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00038 to 0.00034
# speechbrain.utils.train_logger - Epoch: 14, lr: 3.84e-04 - train loss: 2.75e-01 - valid loss: 3.29e-01, valid error: 7.69e-03
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-57+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-45+00
# speechbrain.utils.epoch_loop - Going into epoch 15
# 100% 5/5 [00:07<00:00,  1.54s/it, train_loss=0.184]
# 100% 5/5 [00:03<00:00,  1.62it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00034 to 0.00029
# speechbrain.utils.train_logger - Epoch: 15, lr: 3.37e-04 - train loss: 1.84e-01 - valid loss: 3.02e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-08+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-56-57+00
# speechbrain.utils.epoch_loop - Going into epoch 16
# 100% 5/5 [00:08<00:00,  1.68s/it, train_loss=0.191]
# 100% 5/5 [00:02<00:00,  1.83it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00029 to 0.00024
# speechbrain.utils.train_logger - Epoch: 16, lr: 2.89e-04 - train loss: 1.91e-01 - valid loss: 2.74e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-19+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-08+00
# speechbrain.utils.epoch_loop - Going into epoch 17
# 100% 5/5 [00:08<00:00,  1.71s/it, train_loss=0.325]
# 100% 5/5 [00:02<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00024 to 0.00019
# speechbrain.utils.train_logger - Epoch: 17, lr: 2.42e-04 - train loss: 3.25e-01 - valid loss: 2.28e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-30+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-19+00
# speechbrain.utils.epoch_loop - Going into epoch 18
# 100% 5/5 [00:08<00:00,  1.70s/it, train_loss=0.229]
# 100% 5/5 [00:02<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00019 to 0.00015
# speechbrain.utils.train_logger - Epoch: 18, lr: 1.95e-04 - train loss: 2.29e-01 - valid loss: 2.03e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-41+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-30+00
# speechbrain.utils.epoch_loop - Going into epoch 19
# 100% 5/5 [00:08<00:00,  1.73s/it, train_loss=0.233]
# 100% 5/5 [00:02<00:00,  1.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00015 to 0.0001
# speechbrain.utils.train_logger - Epoch: 19, lr: 1.47e-04 - train loss: 2.33e-01 - valid loss: 1.71e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-53+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-41+00
# speechbrain.utils.epoch_loop - Going into epoch 20
# 100% 5/5 [00:09<00:00,  1.82s/it, train_loss=0.177]
# 100% 5/5 [00:02<00:00,  1.82it/s]
# speechbrain.utils.train_logger - Epoch: 20, lr: 1.00e-04 - train loss: 1.77e-01 - valid loss: 1.46e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-58-05+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Xvector/1986/save/CKPT+2025-02-24+04-57-53+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/Xvector/1986/save/CKPT+2025-02-24+04-58-05+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/processing/features.py:1320: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   stats = torch.load(path, map_location=device)
# 100% 5/5 [00:02<00:00,  1.82it/s]
# speechbrain.utils.train_logger - Epoch loaded: 20 - test loss: 1.46e-01, test error: 0.00e+00

# %%
import re
import matplotlib.pyplot as plt

def get_losses(log_file):
    """This function takes in input a path of a log-file and outputs the train
    and valid losses in lists of float numbers"""
    train_losses = []
    valid_losses = []

    # Regex pattern to capture 'train loss: <number>' and 'valid loss: <number>'
    pattern = r"train loss:\s*([\de\.+-]+).*valid loss:\s*([\de\.+-]+)"

    with open(log_file, 'r') as f:
        for line in f:
            # Search each line for the pattern
            match = re.search(pattern, line)
            if match:
                # Convert captured groups to float
                train_loss = float(match.group(1))
                valid_loss = float(match.group(2))
                train_losses.append(train_loss)
                valid_losses.append(valid_loss)

    return train_losses, valid_losses  # Return the two lists

# Usage example:
log_file = '/content/results/Xvector/1986/train_log.txt'
train_losses, valid_losses = get_losses(log_file)

plt.plot(train_losses, label='train')
plt.plot(valid_losses, label='valid')
plt.ylabel('Loss')
plt.xlabel('# Epochs')
plt.legend()
plt.show()

with open(log_file) as f:
    log_text = f.read()
    print(log_text)
# Out:
# Epoch: 1, lr: 1.00e-03 - train loss: 2.92 - valid loss: 3.26, valid error: 9.62e-01
# Epoch: 2, lr: 9.53e-04 - train loss: 2.26 - valid loss: 3.26, valid error: 9.62e-01
# Epoch: 3, lr: 9.05e-04 - train loss: 1.55 - valid loss: 3.27, valid error: 9.62e-01
# Epoch: 4, lr: 8.58e-04 - train loss: 1.34 - valid loss: 3.26, valid error: 9.62e-01
# Epoch: 5, lr: 8.11e-04 - train loss: 1.05 - valid loss: 3.16, valid error: 9.19e-01
# Epoch: 6, lr: 7.63e-04 - train loss: 8.70e-01 - valid loss: 2.84, valid error: 8.38e-01
# Epoch: 7, lr: 7.16e-04 - train loss: 6.82e-01 - valid loss: 2.18, valid error: 7.50e-01
# Epoch: 8, lr: 6.68e-04 - train loss: 5.12e-01 - valid loss: 1.59, valid error: 3.81e-01
# Epoch: 9, lr: 6.21e-04 - train loss: 4.57e-01 - valid loss: 1.06, valid error: 1.12e-01
# Epoch: 10, lr: 5.74e-04 - train loss: 4.61e-01 - valid loss: 7.88e-01, valid error: 2.31e-02
# Epoch: 11, lr: 5.26e-04 - train loss: 3.40e-01 - valid loss: 6.23e-01, valid error: 0.00e+00
# Epoch: 12, lr: 4.79e-04 - train loss: 3.16e-01 - valid loss: 5.26e-01, valid error: 0.00e+00
# Epoch: 13, lr: 4.32e-04 - train loss: 2.56e-01 - valid loss: 4.06e-01, valid error: 7.69e-03
# Epoch: 14, lr: 3.84e-04 - train loss: 2.75e-01 - valid loss: 3.29e-01, valid error: 7.69e-03
# Epoch: 15, lr: 3.37e-04 - train loss: 1.84e-01 - valid loss: 3.02e-01, valid error: 0.00e+00
# Epoch: 16, lr: 2.89e-04 - train loss: 1.91e-01 - valid loss: 2.74e-01, valid error: 0.00e+00
# Epoch: 17, lr: 2.42e-04 - train loss: 3.25e-01 - valid loss: 2.28e-01, valid error: 0.00e+00
# Epoch: 18, lr: 1.95e-04 - train loss: 2.29e-01 - valid loss: 2.03e-01, valid error: 0.00e+00
# Epoch: 19, lr: 1.47e-04 - train loss: 2.33e-01 - valid loss: 1.71e-01, valid error: 0.00e+00
# It might be surprising to see a 0% error on both validation and test. On the other hand, for humans, it might be hard to detect which speaker is speaking among 26 candidates after listening for just a few minutes their voices. For a neural network, instead, this task is very easy. Even on large datasets containing noise recordings and thousands of speakers, a good neural network can identify speakers with 98-99% accuracy.

# %% [markdown]
# ## **Exercise 3: Speaker Identification with MFCCs and Xvectors**
#
# in this exercise, you have to run the same system as exercise 2, but with different speech features in the input.
#
# This time, you should feed the system with mel frequency cepstral coefficients (MFCCs). You have to compute them with `speechbrain.lobes.features.MFCC` (please take a look at the documentation [here](https://speechbrain.readthedocs.io/en/latest/API/speechbrain.lobes.features.html). For this exercise, do not augment the features with the context and with the delta coefficients. You can compute 20 MFFCs.
#
# Modify the hparam file to implement the MFCC-based speaker identification system. Note that you do not need to modify the train.py script as well.
#
# **Your code here**:

# %%
# %%file hparams_xvector_mfccs.yaml
#
# seed: 1986
# __set_seed: !!python/object/apply:torch.manual_seed [!ref <seed>]
#
# output_folder: !ref ./results/TIMIT_tiny/MFCC/Xvector/
# save_folder: !ref <output_folder>/save
# train_log: !ref <output_folder>/train_log.txt
#
# # Data manifests
# train_annotation: train.json
# valid_annotation: valid.json
# test_annotation: test.json
#
# # Training logger
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
#
# # Metrics
# error_stats: !name:speechbrain.utils.metric_stats.MetricStats
#     metric: !name:speechbrain.nnet.losses.classification_error
#         reduction: batch
#
# # Audio parameters
# sample_rate: 16000
# n_mfcc: 20  # Using 20 MFCCs
# n_mels: 20
#
# # Training config
# number_of_epochs: 20
# batch_size: 64
# lr_start: 0.001
# lr_final: 0.0001
# n_classes: 26
# emb_dim: 128
#
# # Data loader
# dataloader_options:
#     batch_size: !ref <batch_size>
#
# # Feature processing
# compute_features: !new:speechbrain.lobes.features.MFCC
#     n_mels: !ref <n_mels>
#     n_mfcc: !ref <n_mfcc>
#     context: False
#     deltas: False
#     n_fft:  400
#     filter_shape: 'triangular'
#     param_change_factor:  1.0
#     param_rand_factor:  0.0
#     left_frames:  5
#     right_frames: 5
#     win_length: 25
#     hop_length: 10
#
# mean_var_norm: !new:speechbrain.processing.features.InputNormalization
#     norm_type: global
#
# # Model architecture
# embedding_model: !new:speechbrain.lobes.models.Xvector.Xvector
#     in_channels: !ref <n_mels>
#     activation: !name:torch.nn.LeakyReLU
#     tdnn_blocks: 5
#     tdnn_channels: [64, 64, 64, 64, 128]
#     tdnn_kernel_sizes: [5, 3, 3, 1, 1]
#     tdnn_dilations: [1, 2, 3, 1, 1]
#     lin_neurons: !ref <emb_dim>
#
# classifier: !new:speechbrain.lobes.models.Xvector.Classifier
#     input_shape: [null, null, !ref <emb_dim>]
#     activation: !name:torch.nn.LeakyReLU
#     lin_blocks: 1
#     lin_neurons: !ref <emb_dim>
#     out_neurons: !ref <n_classes>
#
# # Training components
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <number_of_epochs>
#
# modules:
#     compute_features: !ref <compute_features>
#     mean_var_norm: !ref <mean_var_norm>
#     embedding_model: !ref <embedding_model>
#     classifier: !ref <classifier>
#
# # Optimization
# opt_class: !name:torch.optim.Adam
#     lr: !ref <lr_start>
#
# lr_annealing: !new:speechbrain.nnet.schedulers.LinearScheduler
#     initial_value: !ref <lr_start>
#     final_value: !ref <lr_final>
#     epoch_count: !ref <number_of_epochs>
#
# # Checkpointing
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         embedding_model: !ref <embedding_model>
#         classifier: !ref <classifier>
#         normalizer: !ref <mean_var_norm>
#         counter: !ref <epoch_counter>
# Out:
# Overwriting hparams_xvector_mfccs.yaml

# %% [markdown]
# **Run the code below to train your model.**

# %%
# Delete the output folder to start training from scratch
# (and not from a previous checkpoint).
# !rm -rf ./results/TIMIT_tiny/MFCC/Xvector/

# !rm -rf ./results/TIMIT_tiny/Xvector/MFCCs/1986

# Run Training
# !python train.py hparams_xvector_mfccs.yaml --device='cpu'
# Out:
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:68: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: ./results/TIMIT_tiny/MFCC/Xvector/
# speechbrain.dataio.encoder - Load called, but CategoricalEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# /usr/local/lib/python3.11/dist-packages/speechbrain/core.py:798: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=gradscaler_enabled)
# speechbrain.core - TIMITBrain Model Statistics:
# * Total Number of Trainable Parameters: 97.7k
# * Total Number of Parameters: 97.7k
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
# speechbrain.dataio.encoder - CategoricalEncoder.expect_len was never called: assuming category count of 26 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
# 100% 5/5 [00:08<00:00,  1.69s/it, train_loss=2.95]
# 100% 5/5 [00:03<00:00,  1.52it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.001 to 0.00095
# speechbrain.utils.train_logger - Epoch: 1, lr: 1.00e-03 - train loss: 2.95 - valid loss: 3.27, valid error: 9.62e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+04-59-49+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100% 5/5 [00:07<00:00,  1.58s/it, train_loss=1.92]
# 100% 5/5 [00:03<00:00,  1.37it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00095 to 0.00091
# speechbrain.utils.train_logger - Epoch: 2, lr: 9.53e-04 - train loss: 1.92 - valid loss: 3.29, valid error: 9.62e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-01+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+04-59-49+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100% 5/5 [00:08<00:00,  1.61s/it, train_loss=1.36]
# 100% 5/5 [00:02<00:00,  1.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00091 to 0.00086
# speechbrain.utils.train_logger - Epoch: 3, lr: 9.05e-04 - train loss: 1.36 - valid loss: 3.35, valid error: 9.58e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-11+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-01+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100% 5/5 [00:08<00:00,  1.68s/it, train_loss=1.11]
# 100% 5/5 [00:02<00:00,  2.13it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00086 to 0.00081
# speechbrain.utils.train_logger - Epoch: 4, lr: 8.58e-04 - train loss: 1.11 - valid loss: 3.43, valid error: 9.23e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-11+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100% 5/5 [00:07<00:00,  1.57s/it, train_loss=0.809]
# 100% 5/5 [00:02<00:00,  2.07it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00081 to 0.00076
# speechbrain.utils.train_logger - Epoch: 5, lr: 8.11e-04 - train loss: 8.09e-01 - valid loss: 3.35, valid error: 9.00e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-22+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100% 5/5 [00:08<00:00,  1.70s/it, train_loss=0.808]
# 100% 5/5 [00:02<00:00,  2.04it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00076 to 0.00072
# speechbrain.utils.train_logger - Epoch: 6, lr: 7.63e-04 - train loss: 8.08e-01 - valid loss: 2.93, valid error: 8.31e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-43+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-32+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100% 5/5 [00:08<00:00,  1.70s/it, train_loss=0.465]
# 100% 5/5 [00:02<00:00,  2.05it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00072 to 0.00067
# speechbrain.utils.train_logger - Epoch: 7, lr: 7.16e-04 - train loss: 4.65e-01 - valid loss: 2.16, valid error: 6.69e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-54+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-43+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100% 5/5 [00:07<00:00,  1.57s/it, train_loss=0.449]
# 100% 5/5 [00:03<00:00,  1.53it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00067 to 0.00062
# speechbrain.utils.train_logger - Epoch: 8, lr: 6.68e-04 - train loss: 4.49e-01 - valid loss: 1.50, valid error: 2.73e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-06+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-00-54+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# 100% 5/5 [00:07<00:00,  1.60s/it, train_loss=0.357]
# 100% 5/5 [00:03<00:00,  1.58it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00062 to 0.00057
# speechbrain.utils.train_logger - Epoch: 9, lr: 6.21e-04 - train loss: 3.57e-01 - valid loss: 1.05, valid error: 8.46e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-17+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-06+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# 100% 5/5 [00:08<00:00,  1.62s/it, train_loss=0.365]
# 100% 5/5 [00:02<00:00,  2.02it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00057 to 0.00053
# speechbrain.utils.train_logger - Epoch: 10, lr: 5.74e-04 - train loss: 3.65e-01 - valid loss: 7.40e-01, valid error: 3.08e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-27+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-17+00
# speechbrain.utils.epoch_loop - Going into epoch 11
# 100% 5/5 [00:08<00:00,  1.71s/it, train_loss=0.335]
# 100% 5/5 [00:02<00:00,  1.99it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00053 to 0.00048
# speechbrain.utils.train_logger - Epoch: 11, lr: 5.26e-04 - train loss: 3.35e-01 - valid loss: 5.09e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-39+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-27+00
# speechbrain.utils.epoch_loop - Going into epoch 12
# 100% 5/5 [00:08<00:00,  1.71s/it, train_loss=0.347]
# 100% 5/5 [00:02<00:00,  2.04it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00048 to 0.00043
# speechbrain.utils.train_logger - Epoch: 12, lr: 4.79e-04 - train loss: 3.47e-01 - valid loss: 3.90e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-50+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-39+00
# speechbrain.utils.epoch_loop - Going into epoch 13
# 100% 5/5 [00:08<00:00,  1.67s/it, train_loss=0.208]
# 100% 5/5 [00:02<00:00,  2.01it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00043 to 0.00038
# speechbrain.utils.train_logger - Epoch: 13, lr: 4.32e-04 - train loss: 2.08e-01 - valid loss: 3.16e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-00+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-01-50+00
# speechbrain.utils.epoch_loop - Going into epoch 14
# 100% 5/5 [00:08<00:00,  1.73s/it, train_loss=0.254]
# 100% 5/5 [00:02<00:00,  2.02it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00038 to 0.00034
# speechbrain.utils.train_logger - Epoch: 14, lr: 3.84e-04 - train loss: 2.54e-01 - valid loss: 2.71e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-12+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-00+00
# speechbrain.utils.epoch_loop - Going into epoch 15
# 100% 5/5 [00:07<00:00,  1.55s/it, train_loss=0.187]
# 100% 5/5 [00:03<00:00,  1.54it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00034 to 0.00029
# speechbrain.utils.train_logger - Epoch: 15, lr: 3.37e-04 - train loss: 1.87e-01 - valid loss: 2.41e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-23+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-12+00
# speechbrain.utils.epoch_loop - Going into epoch 16
# 100% 5/5 [00:07<00:00,  1.56s/it, train_loss=0.199]
# 100% 5/5 [00:03<00:00,  1.62it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00029 to 0.00024
# speechbrain.utils.train_logger - Epoch: 16, lr: 2.89e-04 - train loss: 1.99e-01 - valid loss: 2.14e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-34+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-23+00
# speechbrain.utils.epoch_loop - Going into epoch 17
# 100% 5/5 [00:07<00:00,  1.59s/it, train_loss=0.26]
# 100% 5/5 [00:02<00:00,  2.05it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00024 to 0.00019
# speechbrain.utils.train_logger - Epoch: 17, lr: 2.42e-04 - train loss: 2.60e-01 - valid loss: 1.89e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-44+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-34+00
# speechbrain.utils.epoch_loop - Going into epoch 18
# 100% 5/5 [00:08<00:00,  1.66s/it, train_loss=0.18]
# 100% 5/5 [00:02<00:00,  2.02it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00019 to 0.00015
# speechbrain.utils.train_logger - Epoch: 18, lr: 1.95e-04 - train loss: 1.80e-01 - valid loss: 1.75e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-55+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-44+00
# speechbrain.utils.epoch_loop - Going into epoch 19
# 100% 5/5 [00:08<00:00,  1.65s/it, train_loss=0.251]
# 100% 5/5 [00:02<00:00,  2.04it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00015 to 0.0001
# speechbrain.utils.train_logger - Epoch: 19, lr: 1.47e-04 - train loss: 2.51e-01 - valid loss: 1.45e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-03-06+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-02-55+00
# speechbrain.utils.epoch_loop - Going into epoch 20
# 100% 5/5 [00:08<00:00,  1.69s/it, train_loss=0.142]
# 100% 5/5 [00:02<00:00,  1.98it/s]
# speechbrain.utils.train_logger - Epoch: 20, lr: 1.00e-04 - train loss: 1.42e-01 - valid loss: 1.25e-01, valid error: 0.00e+00
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-03-17+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-03-06+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/TIMIT_tiny/MFCC/Xvector/save/CKPT+2025-02-24+05-03-17+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/processing/features.py:1320: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   stats = torch.load(path, map_location=device)
# 100% 5/5 [00:02<00:00,  2.01it/s]
# speechbrain.utils.train_logger - Epoch loaded: 20 - test loss: 1.25e-01, test error: 0.00e+00

# %%
import re
import matplotlib.pyplot as plt

def get_losses(log_file):
    """This function takes in input a path of a log-file and outputs the train
    and valid losses in lists of float numbers"""
    train_losses = []
    valid_losses = []

    # Regex pattern to capture 'train loss: <number>' and 'valid loss: <number>'
    pattern = r"train loss:\s*([\de\.+-]+).*valid loss:\s*([\de\.+-]+)"

    with open(log_file, 'r') as f:
        for line in f:
            # Search each line for the pattern
            match = re.search(pattern, line)
            if match:
                # Convert captured groups to float
                train_loss = float(match.group(1))
                valid_loss = float(match.group(2))
                train_losses.append(train_loss)
                valid_losses.append(valid_loss)

    return train_losses, valid_losses  # Return the two lists

# Usage example:
log_file = '/content/results/TIMIT_tiny/MFCC/Xvector/train_log.txt'
train_losses, valid_losses = get_losses(log_file)

plt.plot(train_losses, label='train')
plt.plot(valid_losses, label='valid')
plt.ylabel('Loss')
plt.xlabel('# Epochs')
plt.legend()
plt.show()

with open(log_file) as f:
    log_text = f.read()
    print(log_text)
# Out:
# Epoch: 1, lr: 1.00e-03 - train loss: 2.95 - valid loss: 3.27, valid error: 9.62e-01
# Epoch: 2, lr: 9.53e-04 - train loss: 1.92 - valid loss: 3.29, valid error: 9.62e-01
# Epoch: 3, lr: 9.05e-04 - train loss: 1.36 - valid loss: 3.35, valid error: 9.58e-01
# Epoch: 4, lr: 8.58e-04 - train loss: 1.11 - valid loss: 3.43, valid error: 9.23e-01
# Epoch: 5, lr: 8.11e-04 - train loss: 8.09e-01 - valid loss: 3.35, valid error: 9.00e-01
# Epoch: 6, lr: 7.63e-04 - train loss: 8.08e-01 - valid loss: 2.93, valid error: 8.31e-01
# Epoch: 7, lr: 7.16e-04 - train loss: 4.65e-01 - valid loss: 2.16, valid error: 6.69e-01
# Epoch: 8, lr: 6.68e-04 - train loss: 4.49e-01 - valid loss: 1.50, valid error: 2.73e-01
# Epoch: 9, lr: 6.21e-04 - train loss: 3.57e-01 - valid loss: 1.05, valid error: 8.46e-02
# Epoch: 10, lr: 5.74e-04 - train loss: 3.65e-01 - valid loss: 7.40e-01, valid error: 3.08e-02
# Epoch: 11, lr: 5.26e-04 - train loss: 3.35e-01 - valid loss: 5.09e-01, valid error: 0.00e+00
# Epoch: 12, lr: 4.79e-04 - train loss: 3.47e-01 - valid loss: 3.90e-01, valid error: 0.00e+00
# Epoch: 13, lr: 4.32e-04 - train loss: 2.08e-01 - valid loss: 3.16e-01, valid error: 0.00e+00
# Epoch: 14, lr: 3.84e-04 - train loss: 2.54e-01 - valid loss: 2.71e-01, valid error: 0.00e+00
# Epoch: 15, lr: 3.37e-04 - train loss: 1.87e-01 - valid loss: 2.41e-01, valid error: 0.00e+00
# Epoch: 16, lr: 2.89e-04 - train loss: 1.99e-01 - valid loss: 2.14e-01, valid error: 0.00e+00
# Epoch: 17, lr: 2.42e-04 - train loss: 2.60e-01 - valid loss: 1.89e-01, valid error: 0.00e+00
