# %% [markdown]
# # **Week 4: Lab Exercises for COMP499/691 Conversational AI**

# %% [markdown]
# The goal of this lab is to familiarize yourself with RNN-based Sequence-to-Sequence learning. This is a fundamental learning paradigm that we find in multiple tasks, such as machine translation and speech recognition.
#
# In the tutorial, we implemented RNN-based models from scratch. In this lab, we will implement it using SpeechBrain.
#
#
# ## **Task Description**
#
# A lucky team of archeologists just did an amazing discovery. They found a document reporting some text in English and some text in an ancient language called Ignotush. The archeologists think that for each sentence in English, there is a corresponding translation in the unknown language (parallel corpus).
# So far, many documents written in Ignotush have been found, but this is the only document reporting on both Ignotush and English.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The team of archeologists worked very hard on this document. They hope this document can help translate all the other ones available in Ignotush.
#
# They first contacted a team of linguists, but they had a hard time learning something useful. At some point, one of the archeologists proposed exploring machine learning techniques and contacted you for help with this problem.
#
# **Run the code below** to download the data.

# %%
# !gdown 1EtiJlE_FT413nIqqh8yiURiuR6d3DSZF
# !gdown 1ScPA77G1gu9kh6WKzNyy9h_VgplWisHl
# !gdown 19QlNE8u7YPLdzvFh0UexDTLCH51LwgZz
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EtiJlE_FT413nIqqh8yiURiuR6d3DSZF
# To: /content/train.csv
# 100% 104k/104k [00:00<00:00, 69.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ScPA77G1gu9kh6WKzNyy9h_VgplWisHl
# To: /content/valid.csv
# 100% 20.7k/20.7k [00:00<00:00, 48.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19QlNE8u7YPLdzvFh0UexDTLCH51LwgZz
# To: /content/test.csv
# 100% 20.9k/20.9k [00:00<00:00, 49.8MB/s]

# %% [markdown]
# Use dropbox, if download from gdrive does not work:

# %%
# %%capture
# !wget -O train.csv  https://www.dropbox.com/scl/fi/tokbl3vuy20e46x3udvrm/train.csv?rlkey=6xig36d642ch0n31qk8drm3ry&dl=0
# !wget -O valid.csv  https://www.dropbox.com/scl/fi/q0zxf2digbuzy8xozqq1z/valid.csv?rlkey=57hma3bj2et87puc88k1coei1&dl=0
# !wget -O test.csv   https://www.dropbox.com/scl/fi/pq7goblr0xfkoyn7utj1g/test.csv?rlkey=8pv3c2agjml2yyy8mi39h676k&dl=0

# %% [markdown]
# The dataset is split into training, validation, and test data as you can see by opening `train.csv`, `valid.csv`, and `test.csv`.
#
# For every sentence in English, you have the corresponding sentence in Ignotush.
#
# We have 1000 sentences for training, 200 for validation, and 200 for testing.
#
# This problem is very popular in machine learning and it is called *machine translation* (the famous Google Translate uses deep learning techniques not too far away from those that we will use in this lab).

# %% [markdown]
# ## **Exercise 1: RNN-based sequence-to-sequence learning**
#
# Fortunately, you studied some sequence-to-sequence learning and you wanted to start with a simple RNN-based encoder-decoder architecture.
#
# Your goal is to implement with [SpeechBrain](https://github.com/speechbrain/speechbrain/) the following architecture:

# %% [markdown]
# ![pictures-Page-5.drawio.png](data:image/png;base64,...)

# %% [markdown]
# **Run the code below** to install speechbrain.

# %%
# %%capture
# !pip install speechbrain

# %% [markdown]
# You wrote the following yaml file that declares all the components that we need.
#
# **Run the code below** to save the hyperparameter file. Please, revise it carefully to start familiarizing yourself with this format.

# %%
# %%file RNN.yaml
#
# # ############################################################################
# # Model: E2E with attention-based Machine Translation
# # Encoder: GRU
# # Decoder: GRU
# # Tokens: Chars
# # losses: NLL
# # Training: Ignotush
# ##############################################################################
#
# # Seed needs to be set at top of yaml, before objects with parameters are instantiated
# seed: 1986
# __set_seed: !apply:torch.manual_seed [!ref <seed>]
#
# # Folder set up
# output_folder: !ref results/RNN/<seed>
# wer_file: !ref <output_folder>/wer.txt
# save_folder: !ref <output_folder>/save
# train_log: !ref <output_folder>/train_log.txt
# cer_file: !ref <output_folder>/test_cer.txt # file were to store the final character error rate on the test set.
#
# # Path where data manifest files are stored
# train_annotation: train.csv
# valid_annotation: valid.csv
# test_annotation: test.csv
#
# # The train logger writes training statistics to a file, as well as stdout.
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
#
# # Training parameters
# number_of_epochs: 50
# batch_size: 100
# lr: 0.01
# lr_final: 0.001
#
#
# # Dataloader options
# train_dataloader_opts:
#     batch_size: !ref <batch_size>
#
# valid_dataloader_opts:
#     batch_size: !ref <batch_size>
#
# test_dataloader_opts:
#     batch_size: !ref <batch_size>
#
#
# # Vocabulary sizes
# voc_size_english: 31
# voc_size_ignotush: 32
#
# # Indexes for begin-of-sentence (bos)
# # and end-of-sentence (eos)
# blank_index: 0 # This special tokes is for padding
# bos_index: 1
# eos_index: 2
#
# # Encoder Parameters
# enc_hidden_size: 128
# enc_num_layers: 2
#
# # Decoder Parameters
# dec_hidden_size: 128
# dec_num_layers: 1
# attn_dim: 128
# dropout: 0.5
#
# # The first object passed to the Brain class is this "Epoch Counter"
# # which is saved by the Checkpointer so that training can be resumed
# # if it gets interrupted at any point.
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <number_of_epochs>
#
# # Encoder
# encoder: !new:speechbrain.nnet.RNN.GRU
#     input_size: !ref <enc_hidden_size>
#     hidden_size: !ref <enc_hidden_size>
#     num_layers: !ref <enc_num_layers>
#     dropout: !ref <dropout>
#
# encoder_emb: !new:torch.nn.Embedding
#     num_embeddings: !ref <voc_size_ignotush>
#     embedding_dim: !ref <enc_hidden_size>
#     padding_idx: !ref <blank_index>
#
# # Attention-based RNN decoder.
# decoder: !new:speechbrain.nnet.RNN.AttentionalRNNDecoder
#     enc_dim: !ref <enc_hidden_size>
#     input_size: !ref <dec_hidden_size>
#     rnn_type: gru
#     attn_type: content
#     hidden_size: !ref <dec_hidden_size>
#     attn_dim: !ref <attn_dim>
#     num_layers: !ref <dec_num_layers>
#     dropout: !ref <dropout>
#
# decoder_emb: !new:torch.nn.Embedding
#     num_embeddings: !ref <voc_size_ignotush>
#     embedding_dim: !ref <dec_hidden_size>
#     padding_idx: !ref <blank_index>
#
# # Linear transformation on the top of the decoder.
# seq_lin: !new:speechbrain.nnet.linear.Linear
#     input_size: !ref <dec_hidden_size>
#     n_neurons: !ref <voc_size_english>
#
# # Final softmax (for log posteriors computation).
# log_softmax: !new:speechbrain.nnet.activations.Softmax
#     apply_log: True
#
#
#
# # Objects in "modules" dict will have their parameters moved to the correct
# # device, as well as having train()/eval() called on them by the Brain class
# modules:
#     encoder: !ref <encoder>
#     encoder_emb: !ref <encoder_emb>
#     decoder: !ref <decoder>
#     decoder_emb: !ref <encoder_emb>
#     seq_lin: !ref <seq_lin>
#
#
# # Gathering all the submodels in a single model object.
# model: !new:torch.nn.ModuleList
#     - - !ref <encoder>
#       - !ref <encoder_emb>
#       - !ref <decoder>
#       - !ref <seq_lin>
#       - !ref <decoder_emb>
#
#
# # This function manages learning rate annealing over the epochs.
# lr_annealing: !new:speechbrain.nnet.schedulers.LinearScheduler
#     initial_value: !ref <lr>
#     final_value: !ref <lr_final>
#     epoch_count: !ref <number_of_epochs>
#
# # This optimizer will be constructed by the Brain class after all parameters
# # are moved to the correct device. Then it will be added to the checkpointer.
# opt_class: !name:torch.optim.Adam
#     lr: !ref <lr>
#
# # This object is used for saving the state of training both so that it
# # can be resumed if it gets interrupted, and also so that the best checkpoint
# # can be later loaded for evaluation or inference.
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         model: !ref <model>
#         counter: !ref <epoch_counter>
# Out:
# Overwriting RNN.yaml

# %% [markdown]
# The RNN.yaml hyperparameter file is coupled with the following training script (train.py).
#
# **Complete the code below** to implement the targeted system. You have to write your code in the `forward` and `compute_objective` methods where required. The code should match what is declared in the YAML file. Take this opportunity to further familiarize yourself with the SpeechBrain training script (they are all similar). In particular, try to understand the data flow: take a look at how we create and process entries declared in the CSV files, how we turn the sequence of chars into a sequence of corresponding integers,  how we turn the processed entries into batches, etc.

# %%
# %%file train.py

#!/usr/bin/env/python3
"""Recipe for training a sequence-to-sequence machine translation system
on "ignotush".
The system employs an encoder, a decoder, and an attention mechanism
between them.

To run this recipe, do the following:
> python train.py train.yaml

With the default hyperparameters, the system employs an GRU encoder and decoder.

The neural network is trained with the negative-log likelihood objective and
characters are used as basic tokens for both english and ignotush.
"""

import os
import sys
import torch
import logging
import speechbrain as sb
from hyperpyyaml import load_hyperpyyaml

logger = logging.getLogger(__name__)


# Brain class for speech recognition training
class Translate(sb.Brain):
    """Class that manages the training loop. See speechbrain.core.Brain."""

    def compute_forward(self, batch, stage):
        """Runs all the computation of the CTC + seq2seq ASR. It returns the
        posterior probabilities of the CTC and seq2seq networks.

        Arguments
        ---------
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.

        Returns
        -------
        predictions : torch.tensor
            Log-probabilities predicted by the decoder.

        At validation/test time, it returns the predicted tokens as well.
        """
        # We first move the batch to the appropriate device.
        # Your code here. Aim for 1 line
        batch = batch.to(self.device)

        # Unpacking inputs
        # Your code here. Aim for 1 line
        enc_ignotush , inp_lens= batch.ignotush_encoded_chars.data, batch.ignotush_encoded_chars.lengths

        # print("Initial Input and length of the ignotush:")
        # print(enc_ignotush.shape)
        # print(inp_lens)

        # Input embeddings
        # Your code here. Aim for 1 line
        enc_emb = self.modules.encoder_emb(enc_ignotush)

        # print("Encoder embedding shape:")
        # print(enc_emb.shape)

        # Running the encoder
        # Your code here. Aim for 1 line
        encoded_signal, _ = self.modules.encoder(enc_emb, lengths=inp_lens)

        # print("Encoder Signal shape:")
        # print(encoded_signal.shape)

        # Unpacking Labels
        # Your code here. Aim for 1 line
        enc_english_bos , inp_lens = batch.english_encoded_chars_bos.data , batch.english_encoded_chars_bos.lengths

        # Decoding Embeddings
        # Your code here. Aim for 1 line
        dec_emb = self.modules.decoder_emb(enc_english_bos)

        # print("Decoder embedding shape: ")
        # print(dec_emb.shape)

        # Running the decoder
        # Your code here. Aim for 1 line

        # print("oooooooooooooooooooo: ")
        # print(inp_lens.shape)
        # print(dec_emb.shape)


        decoder_outputs, _ = self.modules.decoder(dec_emb,encoded_signal,inp_lens)

        # Compute logits (i.e., apply final linear transformation)
        # Your code here. Aim for 1 line
        logits = self.modules.seq_lin(decoder_outputs)

        # Compute log posteriors
        # Your code here. Aim for 1 line
        predictions = self.hparams.log_softmax(logits)

        if stage == sb.Stage.TEST:

            # Getting Some predictions.
            # Note: For simplicity we use teacher forcing also for testing.
            # For a real inference, you would need to implement greedy search
            # and feed into the autoregressive model the actual predictions
            # done at each step by the model.
            hyps = predictions.argmax(-1)

            # getting the first index where the prediciton is eos_index
            stop_indexes = (hyps==self.hparams.eos_index).int()
            stop_indexes = stop_indexes.argmax(dim=1)

            # Converting hyps from indexes to chars
            hyp_lst = []
            for hyp, stop_ind in zip(hyps, stop_indexes):
                # in some cases the eos in not observed (e.g, for the last sentence
                # in the batch)
                if stop_ind == 0:
                    stop_ind = -1
                # Stopping when eos is observed
                hyp = hyp[0:stop_ind]
                # From index to character
                hyp_lst.append(self.label_encoder.decode_ndim(hyp))

            return predictions, hyp_lst

        return predictions


    def compute_objectives(self, predictions, batch, stage):
        """Computes the loss given the predicted and targeted outputs.

        Arguments
        ---------
        predictions : torch.tTensor
            The output tensor from `compute_forward`.
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.

        Returns
        -------
        loss : torch.Tensor
            A one-element tensor used for backpropagating the gradient.
        """
        # Unpacking Labels with eos
        # Your code here. Aim for 1 line
        enc_english_eos, english_lens = batch.english_encoded_chars_eos.data, batch.english_encoded_chars_eos.lengths

        # print(enc_english_eos.shape)
        # print(predictions.shape)

        # Reading the predictions
        if stage == sb.Stage.TEST:
          predictions, hyp_lst = predictions

          for id, inp, label, hyp in zip(batch.id, batch.ignotush_chars, batch.english_chars, hyp_lst):
              print(id)
              print("INP: " + ''.join(inp))
              print("REF: " + ''.join(label))
              print("HYP: " + ''.join(hyp))
              print('--------')

        # Computing the nll_loss
        # Your code here. Aim for 1 line
        loss = sb.nnet.losses.nll_loss(predictions,enc_english_eos,english_lens)

        return loss


    def on_stage_end(self, stage, stage_loss, epoch):
        """Gets called at the end of an epoch.

        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, sb.Stage.TEST
        stage_loss : float
            The average loss for all of the data processed in this stage.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Store the train loss until the validation stage.
        stage_stats = {"loss": stage_loss}
        if stage == sb.Stage.TRAIN:
            self.train_stats = stage_stats


        # Perform end-of-iteration things, like annealing, logging, etc.
        elif stage == sb.Stage.VALID:


            # Update learning rate
            old_lr, new_lr = self.hparams.lr_annealing(epoch)
            sb.nnet.schedulers.update_learning_rate(self.optimizer, new_lr)

            # The train_logger writes a summary to stdout and to the logfile.
            self.hparams.train_logger.log_stats(
                stats_meta={"epoch": epoch, "lr": old_lr},
                train_stats=self.train_stats,
                valid_stats={
                    "loss": stage_loss,
                },
            )
            # Save the current checkpoint and delete previous checkpoints.
            self.checkpointer.save_and_keep_only(
                meta={"loss": stage_stats["loss"]}, min_keys=["loss"],
            )

        # We also write statistics about test data to stdout and to the logfile.
        elif stage == sb.Stage.TEST:

            self.hparams.train_logger.log_stats(
                stats_meta={"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats={
                    "loss": stage_loss,
                },
            )


def dataio_prepare(hparams):
    """This function prepares the datasets to be used in the brain class.
    It also defines the data processing pipeline through user-defined functions.


    Arguments
    ---------
    hparams : dict
        This dictionary is loaded from the `train.yaml` file, and it includes
        all the hyperparameters needed for dataset construction and loading.

    Returns
    -------
    datasets : dict
        Dictionary containing "train", "valid", and "test" keys that correspond
        to the DynamicItemDataset objects.
    """
    # Define text processing pipeline. We start from the raw text and then
    # split it into characters. The tokens with BOS are used for feeding
    # the decoder during training (right shifr), the tokens with EOS
    # are used for computing the cost function.
    @sb.utils.data_pipeline.takes("english")
    @sb.utils.data_pipeline.provides(
        "english_words",
        "english_chars",
        "english_encoded_chars_lst",
        "english_encoded_chars",
        "english_encoded_chars_eos",
        "english_encoded_chars_bos",
        )
    def ignotush_text_pipeline(english):
        """Processes the transcriptions to generate proper labels"""
        yield english
        english_chars = list(english)
        yield english_chars
        english_encoded_chars_lst = label_encoder.encode_sequence(english_chars)
        yield english_encoded_chars_lst
        english_encoded_chars = torch.LongTensor(english_encoded_chars_lst)
        yield english_encoded_chars
        english_encoded_chars_eos = torch.LongTensor(label_encoder.append_eos_index(english_encoded_chars_lst))
        yield english_encoded_chars_eos
        english_encoded_chars_bos = torch.LongTensor(label_encoder.prepend_bos_index(english_encoded_chars_lst))
        yield english_encoded_chars_bos

    @sb.utils.data_pipeline.takes("ignotush")
    @sb.utils.data_pipeline.provides("ignotush_words", "ignotush_chars", "ignotush_encoded_chars")
    def english_text_pipeline(ignotush):
        """Processes the transcriptions to generate proper labels"""
        yield ignotush
        ignotush_chars = list(ignotush)
        yield ignotush_chars
        ignotush_encoded_chars = torch.LongTensor(input_encoder.encode_sequence(ignotush_chars))
        yield ignotush_encoded_chars

    # Define datasets from json data manifest file
    # Define datasets sorted by ascending lengths for efficiency
    datasets = {}
    data_info = {
        "train": hparams["train_annotation"],
        "valid": hparams["valid_annotation"],
        "test": hparams["test_annotation"],
    }

    # The label encoder will assign a different integer to each element
    # in the output vocabulary
    input_encoder = sb.dataio.encoder.CTCTextEncoder()
    label_encoder = sb.dataio.encoder.CTCTextEncoder()

    for dataset in data_info:
        datasets[dataset] = sb.dataio.dataset.DynamicItemDataset.from_csv(
            csv_path=data_info[dataset],
            dynamic_items=[ignotush_text_pipeline, english_text_pipeline],
            output_keys=[
                "id",
                "english_words",
                "english_chars",
                "english_encoded_chars",
                "english_encoded_chars_eos",
                "english_encoded_chars_bos",
                "ignotush_words",
                "ignotush_chars",
                "ignotush_encoded_chars",
            ],
        )
        hparams[f"{dataset}_dataloader_opts"]["shuffle"] = True


    # Load or compute the label encoder
    inp_enc_file = os.path.join(hparams["save_folder"], "input_encoder.txt")

    # The blank symbol is used to indicate padding
    special_labels = {"blank_label": hparams["blank_index"]}

    input_encoder.load_or_create(
        path=inp_enc_file,
        from_didatasets=[datasets["train"]],
        output_key="ignotush_chars",
        special_labels=special_labels,
        sequence_input=True,
    )

    # Load or compute the label encoder
    lab_enc_file = os.path.join(hparams["save_folder"], "label_encoder.txt")
    special_labels = {
        "blank_label": hparams["blank_index"],
        "bos_label": hparams["bos_index"],
        "eos_label": hparams["eos_index"],
    }
    label_encoder.load_or_create(
        path=lab_enc_file,
        from_didatasets=[datasets["train"]],
        output_key="english_chars",
        special_labels=special_labels,
        sequence_input=True,
    )

    return datasets, label_encoder


if __name__ == "__main__":

    # Reading command line arguments
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])

    # Load hyperparameters file with command-line overrides
    with open(hparams_file) as fin:
        hparams = load_hyperpyyaml(fin, overrides)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )


    # We can now directly create the datasets for training, valid, and test
    datasets, label_encoder = dataio_prepare(hparams)

    # Trainer initialization
    translate_brain = Translate(
        modules=hparams["modules"],
        opt_class=hparams["opt_class"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )

    # Making label encoder accessible (needed for computer the character error rate)
    translate_brain.label_encoder = label_encoder

    # The `fit()` method iterates the training loop, calling the methods
    # necessary to update the parameters of the model. Since all objects
    # with changing state are managed by the Checkpointer, training can be
    # stopped at any point, and will be resumed on next call.
    translate_brain.fit(
        translate_brain.hparams.epoch_counter,
        datasets["train"],
        datasets["valid"],
        train_loader_kwargs=hparams["train_dataloader_opts"],
        valid_loader_kwargs=hparams["valid_dataloader_opts"],
    )

    # Load best checkpoint for evaluation
    test_stats = translate_brain.evaluate(
        test_set=datasets["test"],
        min_key="WER",
        test_loader_kwargs=hparams["test_dataloader_opts"],
    )
# Out:
# Overwriting train.py

# %% [markdown]
# **Run the code below** to start training. We here use a CPU because the task is pretty fast. It might take 10-15 minutes to train the RNN model.

# %%
# !rm -rf ./results
# !python train.py RNN.yaml --device='cpu'
# Out:
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/RNN/1986
# speechbrain.dataio.encoder - Moving label 'p' from index 0, because '<blank>' was put at its place.
# speechbrain.dataio.encoder - Load called, but CTCTextEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.dataio.encoder - Moving label 'T' from index 0, because '<blank>' was put at its place.
# speechbrain.dataio.encoder - Moving label 'H' from index 1, because '<bos>' was put at its place.
# speechbrain.dataio.encoder - Moving label 'E' from index 2, because '<eos>' was put at its place.
# speechbrain.dataio.encoder - Load called, but CTCTextEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# /usr/local/lib/python3.11/dist-packages/speechbrain/core.py:796: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=gradscaler_enabled)
# speechbrain.core - Translate Model Statistics:
# * Total Number of Trainable Parameters: 437.0k
# * Total Number of Parameters: 437.0k
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
# speechbrain.dataio.encoder - CTCTextEncoder.expect_len was never called: assuming category count of 31 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
# speechbrain.dataio.encoder - CTCTextEncoder.expect_len was never called: assuming category count of 32 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
# 100% 10/10 [00:18<00:00,  1.82s/it, train_loss=3.6]
# 100% 2/2 [00:00<00:00,  2.12it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.01 to 0.0098
# speechbrain.utils.train_logger - epoch: 1, lr: 1.00e-02 - train loss: 3.60 - valid loss: 2.62
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-36-50+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100% 10/10 [00:16<00:00,  1.69s/it, train_loss=2.48]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0098 to 0.0096
# speechbrain.utils.train_logger - epoch: 2, lr: 9.82e-03 - train loss: 2.48 - valid loss: 2.32
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-37-08+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-36-50+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100% 10/10 [00:16<00:00,  1.69s/it, train_loss=2.28]
# 100% 2/2 [00:01<00:00,  1.48it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0096 to 0.0094
# speechbrain.utils.train_logger - epoch: 3, lr: 9.63e-03 - train loss: 2.28 - valid loss: 2.17
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-37-26+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-37-08+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100% 10/10 [00:17<00:00,  1.72s/it, train_loss=2.14]
# 100% 2/2 [00:00<00:00,  2.07it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0094 to 0.0093
# speechbrain.utils.train_logger - epoch: 4, lr: 9.45e-03 - train loss: 2.14 - valid loss: 2.06
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-37-44+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-37-26+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100% 10/10 [00:16<00:00,  1.67s/it, train_loss=2.02]
# 100% 2/2 [00:00<00:00,  2.14it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0093 to 0.0091
# speechbrain.utils.train_logger - epoch: 5, lr: 9.27e-03 - train loss: 2.02 - valid loss: 1.96
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-38-02+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-37-44+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100% 10/10 [00:16<00:00,  1.66s/it, train_loss=1.92]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0091 to 0.0089
# speechbrain.utils.train_logger - epoch: 6, lr: 9.08e-03 - train loss: 1.92 - valid loss: 1.84
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-38-19+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-38-02+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100% 10/10 [00:17<00:00,  1.76s/it, train_loss=1.77]
# 100% 2/2 [00:01<00:00,  1.92it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0089 to 0.0087
# speechbrain.utils.train_logger - epoch: 7, lr: 8.90e-03 - train loss: 1.77 - valid loss: 1.60
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-38-38+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-38-19+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100% 10/10 [00:16<00:00,  1.68s/it, train_loss=1.45]
# 100% 2/2 [00:00<00:00,  2.05it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0087 to 0.0085
# speechbrain.utils.train_logger - epoch: 8, lr: 8.71e-03 - train loss: 1.45 - valid loss: 1.02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-38-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-38-38+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# 100% 10/10 [00:17<00:00,  1.73s/it, train_loss=0.868]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0085 to 0.0083
# speechbrain.utils.train_logger - epoch: 9, lr: 8.53e-03 - train loss: 8.68e-01 - valid loss: 3.97e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-39-14+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-38-56+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# 100% 10/10 [00:17<00:00,  1.70s/it, train_loss=0.483]
# 100% 2/2 [00:01<00:00,  1.46it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0083 to 0.0082
# speechbrain.utils.train_logger - epoch: 10, lr: 8.35e-03 - train loss: 4.83e-01 - valid loss: 2.20e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-39-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-39-14+00
# speechbrain.utils.epoch_loop - Going into epoch 11
# 100% 10/10 [00:16<00:00,  1.70s/it, train_loss=0.328]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0082 to 0.008
# speechbrain.utils.train_logger - epoch: 11, lr: 8.16e-03 - train loss: 3.28e-01 - valid loss: 1.83e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-39-51+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-39-33+00
# speechbrain.utils.epoch_loop - Going into epoch 12
# 100% 10/10 [00:16<00:00,  1.68s/it, train_loss=0.26]
# 100% 2/2 [00:00<00:00,  2.07it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.008 to 0.0078
# speechbrain.utils.train_logger - epoch: 12, lr: 7.98e-03 - train loss: 2.60e-01 - valid loss: 1.43e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-40-08+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-39-51+00
# speechbrain.utils.epoch_loop - Going into epoch 13
# 100% 10/10 [00:16<00:00,  1.67s/it, train_loss=0.214]
# 100% 2/2 [00:01<00:00,  1.48it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0078 to 0.0076
# speechbrain.utils.train_logger - epoch: 13, lr: 7.80e-03 - train loss: 2.14e-01 - valid loss: 1.14e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-40-27+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-40-08+00
# speechbrain.utils.epoch_loop - Going into epoch 14
# 100% 10/10 [00:17<00:00,  1.75s/it, train_loss=0.188]
# 100% 2/2 [00:00<00:00,  2.04it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0076 to 0.0074
# speechbrain.utils.train_logger - epoch: 14, lr: 7.61e-03 - train loss: 1.88e-01 - valid loss: 9.67e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-40-45+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-40-27+00
# speechbrain.utils.epoch_loop - Going into epoch 15
# 100% 10/10 [00:17<00:00,  1.72s/it, train_loss=0.163]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0074 to 0.0072
# speechbrain.utils.train_logger - epoch: 15, lr: 7.43e-03 - train loss: 1.63e-01 - valid loss: 9.64e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-41-03+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-40-45+00
# speechbrain.utils.epoch_loop - Going into epoch 16
# 100% 10/10 [00:16<00:00,  1.67s/it, train_loss=0.143]
# 100% 2/2 [00:01<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0072 to 0.0071
# speechbrain.utils.train_logger - epoch: 16, lr: 7.24e-03 - train loss: 1.43e-01 - valid loss: 9.34e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-41-21+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-41-03+00
# speechbrain.utils.epoch_loop - Going into epoch 17
# 100% 10/10 [00:17<00:00,  1.76s/it, train_loss=0.127]
# 100% 2/2 [00:00<00:00,  2.06it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0071 to 0.0069
# speechbrain.utils.train_logger - epoch: 17, lr: 7.06e-03 - train loss: 1.27e-01 - valid loss: 7.72e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-41-40+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-41-21+00
# speechbrain.utils.epoch_loop - Going into epoch 18
# 100% 10/10 [00:16<00:00,  1.68s/it, train_loss=0.128]
# 100% 2/2 [00:00<00:00,  2.04it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0069 to 0.0067
# speechbrain.utils.train_logger - epoch: 18, lr: 6.88e-03 - train loss: 1.28e-01 - valid loss: 7.27e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-41-58+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-41-40+00
# speechbrain.utils.epoch_loop - Going into epoch 19
# 100% 10/10 [00:17<00:00,  1.70s/it, train_loss=0.111]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0067 to 0.0065
# speechbrain.utils.train_logger - epoch: 19, lr: 6.69e-03 - train loss: 1.11e-01 - valid loss: 6.10e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-42-16+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-41-58+00
# speechbrain.utils.epoch_loop - Going into epoch 20
# 100% 10/10 [00:17<00:00,  1.75s/it, train_loss=0.0941]
# 100% 2/2 [00:01<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0065 to 0.0063
# speechbrain.utils.train_logger - epoch: 20, lr: 6.51e-03 - train loss: 9.41e-02 - valid loss: 5.99e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-42-34+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-42-16+00
# speechbrain.utils.epoch_loop - Going into epoch 21
# 100% 10/10 [00:17<00:00,  1.71s/it, train_loss=0.0857]
# 100% 2/2 [00:00<00:00,  2.04it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0063 to 0.0061
# speechbrain.utils.train_logger - epoch: 21, lr: 6.33e-03 - train loss: 8.57e-02 - valid loss: 5.63e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-42-52+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-42-34+00
# speechbrain.utils.epoch_loop - Going into epoch 22
# 100% 10/10 [00:16<00:00,  1.68s/it, train_loss=0.0907]
# 100% 2/2 [00:00<00:00,  2.05it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0061 to 0.006
# speechbrain.utils.train_logger - epoch: 22, lr: 6.14e-03 - train loss: 9.07e-02 - valid loss: 5.12e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-43-10+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-42-52+00
# speechbrain.utils.epoch_loop - Going into epoch 23
# 100% 10/10 [00:17<00:00,  1.78s/it, train_loss=0.0783]
# 100% 2/2 [00:01<00:00,  1.51it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.006 to 0.0058
# speechbrain.utils.train_logger - epoch: 23, lr: 5.96e-03 - train loss: 7.83e-02 - valid loss: 5.37e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-43-29+00
# speechbrain.utils.epoch_loop - Going into epoch 24
# 100% 10/10 [00:17<00:00,  1.70s/it, train_loss=0.0786]
# 100% 2/2 [00:00<00:00,  2.06it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0058 to 0.0056
# speechbrain.utils.train_logger - epoch: 24, lr: 5.78e-03 - train loss: 7.86e-02 - valid loss: 5.34e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-43-47+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-43-29+00
# speechbrain.utils.epoch_loop - Going into epoch 25
# 100% 10/10 [00:16<00:00,  1.65s/it, train_loss=0.0715]
# 100% 2/2 [00:00<00:00,  2.10it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0056 to 0.0054
# speechbrain.utils.train_logger - epoch: 25, lr: 5.59e-03 - train loss: 7.15e-02 - valid loss: 4.94e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-44-05+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-43-10+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-43-47+00
# speechbrain.utils.epoch_loop - Going into epoch 26
# 100% 10/10 [00:17<00:00,  1.76s/it, train_loss=0.0613]
# 100% 2/2 [00:01<00:00,  1.46it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0054 to 0.0052
# speechbrain.utils.train_logger - epoch: 26, lr: 5.41e-03 - train loss: 6.13e-02 - valid loss: 4.85e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-44-24+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-44-05+00
# speechbrain.utils.epoch_loop - Going into epoch 27
# 100% 10/10 [00:17<00:00,  1.72s/it, train_loss=0.0682]
# 100% 2/2 [00:00<00:00,  2.05it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0052 to 0.005
# speechbrain.utils.train_logger - epoch: 27, lr: 5.22e-03 - train loss: 6.82e-02 - valid loss: 4.78e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-44-42+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-44-24+00
# speechbrain.utils.epoch_loop - Going into epoch 28
# 100% 10/10 [00:16<00:00,  1.67s/it, train_loss=0.0626]
# 100% 2/2 [00:00<00:00,  2.03it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.005 to 0.0049
# speechbrain.utils.train_logger - epoch: 28, lr: 5.04e-03 - train loss: 6.26e-02 - valid loss: 4.70e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-45-00+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-44-42+00
# speechbrain.utils.epoch_loop - Going into epoch 29
# 100% 10/10 [00:17<00:00,  1.74s/it, train_loss=0.0553]
# 100% 2/2 [00:01<00:00,  1.47it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0049 to 0.0047
# speechbrain.utils.train_logger - epoch: 29, lr: 4.86e-03 - train loss: 5.53e-02 - valid loss: 4.31e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-45-19+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-45-00+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# 100% 10/10 [00:17<00:00,  1.73s/it, train_loss=0.0598]
# 100% 2/2 [00:00<00:00,  2.08it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0047 to 0.0045
# speechbrain.utils.train_logger - epoch: 30, lr: 4.67e-03 - train loss: 5.98e-02 - valid loss: 4.38e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-45-37+00
# speechbrain.utils.epoch_loop - Going into epoch 31
# 100% 10/10 [00:16<00:00,  1.69s/it, train_loss=0.0559]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0045 to 0.0043
# speechbrain.utils.train_logger - epoch: 31, lr: 4.49e-03 - train loss: 5.59e-02 - valid loss: 4.47e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-45-55+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-45-37+00
# speechbrain.utils.epoch_loop - Going into epoch 32
# 100% 10/10 [00:16<00:00,  1.69s/it, train_loss=0.0471]
# 100% 2/2 [00:01<00:00,  1.83it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0043 to 0.0041
# speechbrain.utils.train_logger - epoch: 32, lr: 4.31e-03 - train loss: 4.71e-02 - valid loss: 3.94e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-46-13+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-45-19+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-45-55+00
# speechbrain.utils.epoch_loop - Going into epoch 33
# 100% 10/10 [00:17<00:00,  1.74s/it, train_loss=0.0453]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0041 to 0.0039
# speechbrain.utils.train_logger - epoch: 33, lr: 4.12e-03 - train loss: 4.53e-02 - valid loss: 3.95e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-46-32+00
# speechbrain.utils.epoch_loop - Going into epoch 34
# 100% 10/10 [00:16<00:00,  1.69s/it, train_loss=0.0502]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0039 to 0.0038
# speechbrain.utils.train_logger - epoch: 34, lr: 3.94e-03 - train loss: 5.02e-02 - valid loss: 3.68e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-46-50+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-46-13+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-46-32+00
# speechbrain.utils.epoch_loop - Going into epoch 35
# 100% 10/10 [00:17<00:00,  1.71s/it, train_loss=0.0433]
# 100% 2/2 [00:00<00:00,  2.07it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0038 to 0.0036
# speechbrain.utils.train_logger - epoch: 35, lr: 3.76e-03 - train loss: 4.33e-02 - valid loss: 3.81e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-47-08+00
# speechbrain.utils.epoch_loop - Going into epoch 36
# 100% 10/10 [00:17<00:00,  1.73s/it, train_loss=0.0502]
# 100% 2/2 [00:01<00:00,  1.73it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0036 to 0.0034
# speechbrain.utils.train_logger - epoch: 36, lr: 3.57e-03 - train loss: 5.02e-02 - valid loss: 3.86e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-47-27+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-47-08+00
# speechbrain.utils.epoch_loop - Going into epoch 37
# 100% 10/10 [00:16<00:00,  1.70s/it, train_loss=0.0435]
# 100% 2/2 [00:00<00:00,  2.06it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0034 to 0.0032
# speechbrain.utils.train_logger - epoch: 37, lr: 3.39e-03 - train loss: 4.35e-02 - valid loss: 3.60e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-47-45+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-47-27+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-46-50+00
# speechbrain.utils.epoch_loop - Going into epoch 38
# 100% 10/10 [00:16<00:00,  1.68s/it, train_loss=0.0384]
# 100% 2/2 [00:00<00:00,  2.07it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0032 to 0.003
# speechbrain.utils.train_logger - epoch: 38, lr: 3.20e-03 - train loss: 3.84e-02 - valid loss: 3.77e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-48-03+00
# speechbrain.utils.epoch_loop - Going into epoch 39
# 100% 10/10 [00:18<00:00,  1.81s/it, train_loss=0.0336]
# 100% 2/2 [00:01<00:00,  1.95it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.003 to 0.0028
# speechbrain.utils.train_logger - epoch: 39, lr: 3.02e-03 - train loss: 3.36e-02 - valid loss: 3.68e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-48-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-48-03+00
# speechbrain.utils.epoch_loop - Going into epoch 40
# 100% 10/10 [00:16<00:00,  1.64s/it, train_loss=0.0454]
# 100% 2/2 [00:00<00:00,  2.05it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0028 to 0.0027
# speechbrain.utils.train_logger - epoch: 40, lr: 2.84e-03 - train loss: 4.54e-02 - valid loss: 3.81e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-48-39+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-48-22+00
# speechbrain.utils.epoch_loop - Going into epoch 41
# 100% 10/10 [00:16<00:00,  1.63s/it, train_loss=0.0444]
# 100% 2/2 [00:00<00:00,  2.07it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0027 to 0.0025
# speechbrain.utils.train_logger - epoch: 41, lr: 2.65e-03 - train loss: 4.44e-02 - valid loss: 3.49e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-48-57+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-48-39+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-47-45+00
# speechbrain.utils.epoch_loop - Going into epoch 42
# 100% 10/10 [00:17<00:00,  1.76s/it, train_loss=0.0387]
# 100% 2/2 [00:01<00:00,  1.53it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0025 to 0.0023
# speechbrain.utils.train_logger - epoch: 42, lr: 2.47e-03 - train loss: 3.87e-02 - valid loss: 3.66e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-49-16+00
# speechbrain.utils.epoch_loop - Going into epoch 43
# 100% 10/10 [00:16<00:00,  1.66s/it, train_loss=0.0338]
# 100% 2/2 [00:00<00:00,  2.05it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0023 to 0.0021
# speechbrain.utils.train_logger - epoch: 43, lr: 2.29e-03 - train loss: 3.38e-02 - valid loss: 3.58e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-49-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-49-16+00
# speechbrain.utils.epoch_loop - Going into epoch 44
# 100% 10/10 [00:16<00:00,  1.67s/it, train_loss=0.0315]
# 100% 2/2 [00:00<00:00,  2.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0021 to 0.0019
# speechbrain.utils.train_logger - epoch: 44, lr: 2.10e-03 - train loss: 3.15e-02 - valid loss: 3.48e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-49-51+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-49-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-48-57+00
# speechbrain.utils.epoch_loop - Going into epoch 45
# 100% 10/10 [00:17<00:00,  1.75s/it, train_loss=0.0318]
# 100% 2/2 [00:01<00:00,  1.51it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0019 to 0.0017
# speechbrain.utils.train_logger - epoch: 45, lr: 1.92e-03 - train loss: 3.18e-02 - valid loss: 3.22e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-50-10+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-49-51+00
# speechbrain.utils.epoch_loop - Going into epoch 46
# 100% 10/10 [00:16<00:00,  1.69s/it, train_loss=0.0387]
# 100% 2/2 [00:00<00:00,  2.03it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0017 to 0.0016
# speechbrain.utils.train_logger - epoch: 46, lr: 1.73e-03 - train loss: 3.87e-02 - valid loss: 3.29e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-50-28+00
# speechbrain.utils.epoch_loop - Going into epoch 47
# 100% 10/10 [00:16<00:00,  1.67s/it, train_loss=0.0344]
# 100% 2/2 [00:00<00:00,  2.12it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0016 to 0.0014
# speechbrain.utils.train_logger - epoch: 47, lr: 1.55e-03 - train loss: 3.44e-02 - valid loss: 3.33e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-50-46+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-50-28+00
# speechbrain.utils.epoch_loop - Going into epoch 48
# 100% 10/10 [00:17<00:00,  1.77s/it, train_loss=0.0227]
# 100% 2/2 [00:01<00:00,  1.61it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0014 to 0.0012
# speechbrain.utils.train_logger - epoch: 48, lr: 1.37e-03 - train loss: 2.27e-02 - valid loss: 3.35e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-51-05+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-50-46+00
# speechbrain.utils.epoch_loop - Going into epoch 49
# 100% 10/10 [00:16<00:00,  1.67s/it, train_loss=0.0263]
# 100% 2/2 [00:00<00:00,  2.11it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0012 to 0.001
# speechbrain.utils.train_logger - epoch: 49, lr: 1.18e-03 - train loss: 2.63e-02 - valid loss: 3.37e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-51-23+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-51-05+00
# speechbrain.utils.epoch_loop - Going into epoch 50
# 100% 10/10 [00:16<00:00,  1.67s/it, train_loss=0.025]
# 100% 2/2 [00:00<00:00,  2.13it/s]
# speechbrain.utils.train_logger - epoch: 50, lr: 1.00e-03 - train loss: 2.50e-02 - valid loss: 3.33e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/RNN/1986/save/CKPT+2025-02-09+00-51-41+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results
# HYP: AND LONGITUDE SEVENTEEN DEGREES
# --------
# snt55
# INP: pji922ojiah355xna3ojia3ottya85zyoji1uuklah5
# REF: TRIGGER SHOOK HER HEAD WONDERFUL SO
# HYP: TRIGGER SHOOK HER HEAD WONDERFUL SOOK   O  O  O   O  OK O
# --------
# snt160
# INP: ttha91atta835kloa1ttm9klfa51a89klyavotthpha8ojioatt1pojia3oji
# REF: AS IF A WHOLE FAMILY OF WILD BEASTS WERE AFTER HER
# HYP: AS IF A WHOLE FAMILY OF WILD BEAMTS WERE AFTER HER
# --------
# snt105
# INP: uu6a1ji5map3omap3jiuuhpattap39qxnajioqpttz2uuklttjiaq5kluumz
# REF: UP FROM THEM THRUST A THICK RECTANGULAR COLUMN
# HYP: UP FROM THEM THRUST A THICK RECTANGULAR COLL
# --------
# snt43
# INP: 53ap3ttpaqttklm
# REF: OH THAT CALM
# HYP: OH THAT CALM
# --------
# snt155
# INP: p3oakl57oap3oa6tthh95z
# REF: THE LOVE THE PASSION
# HYP: THE LOVE THE PASSION
# --------
# snt80
# INP: z5a83ojioahtt9yayji5uuop
# REF: NO WHERE SAID DROUET
# HYP: NO WHERE SAID DROUET
# --------
# snt96
# INP: 9z79poyavfap3oamttji-1uu9ha51ahpofzoap5amoopa39haji5fttkla3923zohh
# REF: INVITED BY THE MARQUIS OF STEYNE TO MEET HIS ROYAL HIGHNESS
# HYP: INVITED BY THE MARQUIS OF STEYNE TO MEET HIS ROYAL HIGHNESS
# --------
# snt32
# INP: 8oamuuhpa-1uuttxnoah3oaq5uuklyapttxnoa5uujia2kl5vo
# REF: WE MUST QUAKE SHE COULD TAKE OUR GLOBE
# HYP: WE MUST QUAKE SHE COULD TAKE OUR GLADD
# --------
# snt158
# INP: zottjiklfahuu115qttpoyap55
# REF: NEARLY SUFFOCATED TOO
# HYP: NEARLY SUFFOCATED TO
# --------
# snt138
# INP: vo22oya63ji5zh9oahptt22oji9z2ap5a3ojia1oop
# REF: BEGGED PHRONSIE STAGGERING TO HER FEET
# HYP: BEGGED PHRONSIE STAGGERING TO HER FEET
# --------
# snt178
# INP: p3ojioa8ttham9hpojiaqji58ah9pp9z2auu65za5zoa51ap3oa1ttklklozapjiooh
# REF: THERE WAS MISTER CROW SITTING UPON ONE OF THE FALLEN TREES
# HYP: THERE WAS MISTER CROW SITTING UPON ONE OF THE FALLEN TREES
# --------
# snt42
# INP: p3oamttza835hoa35uuhoaf5uua3tt7oa0uuhpaklo1pafoh
# REF: THE MAN WHOSE HOUSE YOU HAVE JUST LEFT YES
# HYP: THE MAN WHOSE HOUSE YOU HAVE JUST LEFT YEST
# --------
# snt79
# INP: 3ttyap3oa5yyohpao11oqpap3oa85jixna8tthavottuup91uuklklfao4oquupoy
# REF: HAD THE ODDEST EFFECT THE WORK WAS BEAUTIFULLY EXECUTED
# HYP: HAD THE ODDEST EFFECT THE WORK WAS BEAUTIFULLY EXECUTED
# --------
# snt82
# INP: ttha9pa8ojioa9zhp9zqp97oklfa19zy9z2amfhokl1ah5ayoh5klttpo
# --------
# snt20
# INP: ttha3oa6uupa5zoa155pa9zatt1pojiah3579z2a9pa511
# REF: AS HE PUT ONE FOOT IN AFTER SHOVING IT OFF
# HYP: AS HE PUT ONE FOOT IN AFTER SHOVING IT OFF
# --------
# snt166
# INP: p3ttpa9pa8tthaz5pa9za5jiyojiam923pavoaozpojioya5zap3oa05uujizttkl
# REF: THAT IT WAS NOT IN ORDER MIGHT BE ENTERED ON THE JOURNAL
# HYP: THAT IT WAS NOT IN ORDER MIGHT BE ENTERED ON THE JOURNAL
# --------
# snt84
# INP: ttzyap3oa2kl55ma839q3a57ojih3tty58oyap3oa35uuhoa8tthah5ajioqozp
# REF: AND THE GLOOM WHICH OVERSHADOWED THE HOUSE WAS SO RECENT
# HYP: AND THE GLOOM WHICH OVERSHADOWED THE HOUSE WAS SO RECEN
# --------
# snt29
# INP: ttmoojiattkl9ap35uu23pap3ttpa3ojia759qoah5uuzyoyajittp3ojiaott2oji
# REF: AMEER ALI THOUGHT THAT HER VOICE SOUNDED RATHER EAGER
# HYP: AMEER ALI THOUGHT THAT HER VOICE SOUNDED RATHER EAGEE
# --------
# snt41
# INP: 53aqojiptt9zklfav5vamfaq39kly
# REF: OH CERTAINLY BOB MY CHILD
# HYP: OH CERTAINLY BOB MY CHILD
# --------
# snt181
# INP: 39ha759qoa8tthahpotty9ojiaz58avuupa2ji9ma83ttpay5af5uua8ttzp
# REF: HIS VOICE WAS STEADIER NOW BUT GRIM WHAT DO YOU WANT
# HYP: HIS VOICE WAS STEADIER NOW BUT GRIM WHAT DO YOU WANT
# --------
# snt131
# INP: 9za835hoahoji79qoa3oa3ttyattajioklttp97o
# REF: IN WHOSE SERVICE HE HAD A RELATIVE
# HYP: IN WHOSE SERVICE HE HAD A RELATIVE
# --------
# snt119
# INP: 83ozatta759qoaqttmoa5uupa51ap3oa25jihoaqkl5hoavf
# REF: WHEN A VOICE CAME OUT OF THE GORSE CLOSE BY
# HYP: WHEN A VOICE CAME OUT OF THE GORSE CLOSE BY
# --------
# snt44
# INP: 85jip3fa15hpojia1ttp3ojia8oklkla8oklkl
# REF: WORTHY FOSTER FATHER WELL WELL
# HYP: WORTHY FOSTER FATHER WELL WELL WL L WEL L   WL LL WL LL WL
# --------
# snt14
# INP: hatta1ttqpav5fha3oahtt9yaq5z19yozp9ttklklf
# REF: S A FACT BOYS HE SAID CONFIDENTIALLY
# HYP: S A FACT BOYS HE SAID CONFIDENTIALLY
# --------
#  50% 1/2 [00:00<00:00,  2.04it/s]snt129
# INP: h3oa3tthzrpa6tt9ya3ojiayuuohattzyattha1ttjiattha9aqttzamttxnoa5uup
# REF: SHE HASN'T PAID HER DUES AND AS FAR AS I CAN MAKE OUT
# HYP: SHE HASN'T PAID HER DUES AND AS FAR AS I CAN MAKE OU
# --------
# snt94
# INP: ttzyay9zoa89p3axn9ppfattzya8ttklxna9zap3oa2kl5ttm9z2a89p3axn9ppf
# REF: AND DINE WITH KITTY AND WALK IN THE GLOAMING WITH KITTY
# INP: ttzyapuujizoya39haofoha89p3a9zy911ojiozqoap5ap3oa5p3ojiah9yo
# REF: AND TURNED HIS EYES WITH INDIFFERENCE TO THE OTHER SIDE
# HYP: AND TURNED HIS EYES WITH INDIFFERENCE TO THE OTHER SIDE
# --------
# snt194
# INP: ttzya51attklklap3oa6ji56ojipfattzya51ap3oap9pkloattklh5
# REF: AND OF ALL THE PROPERTY AND OF THE TITLE ALSO
# HYP: AND OF ALL THE PROPERTY AND OF THE TITLE ALSO
# --------
# snt17
# INP: voattpa6jiuuyozqorhap5az923pattpao923p
# REF: BE AT PRUDENCE'S TO NIGHT AT EIGHT
# HYP: BE AT PRUDENCE'S TO NIGHT AT EIGHT TT
# --------
# snt169
# INP: p3oa5klya85mttzakl55xnoyatt1pojiap3oakl9zoz
# REF: THE OLD WOMAN LOOKED AFTER THE LINEN
# HYP: THE OLD WOMAN LOOKED AFTER THE LINENEE
# --------
# snt170
# INP: tt3avuupap3oattmttkl19aji5ttyah92z5jioahuujioklfaf5uua89klklahooap3ttp
# REF: AH BUT THE AMALFI ROAD SIGNORE SURELY YOU WILL SEE THAT
# HYP: AH BUT THE AMALFI ROAD SIGNORE SURELY YOU WILL SEE THAL
# --------
# snt128
# INP: ttzya3oa8ozpauu6ap5attklklap3o9jiaqtthpkloh
# REF: AND HE WENT UP TO ALL THEIR CASTLES
# HYP: AND HE WENT UP TO ALL THEIR CASTLES
# --------
# snt77
# INP: 839q3ah5moa3tt7oaqkltt9moya15jia39m
# REF: WHICH SOME HAVE CLAIMED FOR HIM
# HYP: WHICH SOME HAVE CLAIMED FOR HIM
# --------
# snt47
# INP: 9ha3o923pozoya9zp5ah5mop39z2ahp9klklam5jioa9zpojiohp9z2
# REF: IS HEIGHTENED INTO SOMETHING STILL MORE INTERESTING
# HYP: IS HEIGHTENED INTO SOMETHING STILL MORE INTORESTING
# --------
# snt121
# INP: h9zqoap3ttpamfakl91oa5zap3fajio75klpay5p3akl9o
# REF: SINCE THAT MY LIFE ON THY REVOLT DOTH LIE
# HYP: SINCE THAT MY LIFE ON THY REVOLT DOTH LIE
# --------
# snt190
# INP: ttzyap3oaq5klklo2oah8oklklha51ap3oaji5uu23aji9yojih
# REF: AND THE COLLEGE SWELLS OF THE ROUGH RIDERS
# HYP: AND THE COLLEGE SWELLS OF THE ROUGH RIDERS
# --------
# snt174
# INP: vuupa5uujiaq39klyjiozattjioa3ttjiyklfauuhoyap5ahuuq3ap39z2h
# REF: BUT OUR CHILDREN ARE HARDLY USED TO SUCH THINGS
# HYP: BUT OUR CHILDREN ARE HARDLY USED TO SUCH THING
# --------
# snt184
# INP: 6jitt8zah5uu6
# REF: PRAWN SOUP
# HYP: PRAWN SOU
# --------
# snt33
# INP: 197oayttfhattjioam5jioap3ttza9ajio-1uu9jio
# REF: FIVE DAYS ARE MORE THAN I REQUIRE
# HYP: FIVE DAYS ARE MORE THAN I REQUIRE
# --------
# snt144
# INP: fohao7ozam5jittkl9pfap3oaq3ttjim9z2am5jittkl9pfa51akl57o
# REF: YES EVEN MORALITY THE CHARMING MORALITY OF LOVE
# HYP: YES EVEN MORALITY THE CHARMING MORALITY TF LOVEN
# --------
# snt73
# INP: z5jip3ttz2ojiattvvof
# REF: NORTHANGER ABBEY
# HYP: NORTHANGER ABBEY
# --------
# snt113
# INP: p3ttpa9am923pa79o8ap3oatty0ttqozpaq5pptt2o
# REF: THAT I MIGHT VIEW THE ADJACENT COTTAGE
# HYP: THAT I MIGHT VIEW THE ADJACENT COTTAGENT TT
# --------
# snt64
# INP: p3oaf5uuz2a85mttza83ozah3oa56ozoyap3oay55jia9zap3oam5jiz9z2
# REF: THE YOUNG WOMAN WHEN SHE OPENED THE DOOR IN THE MORNING
# HYP: THE YOUNG WOMAN WHEN SHE OPENED THE MOOR IN THE MORNING
# --------
# snt48
# INP: pttxnoap3oap39z2ahtt9yaxn8tt9jif5a9a8tthaz5pa05xn9z2
# REF: TAKE THE THING SAID KWAIRYO I WAS NOT JOKING
# HYP: TAKE THE THING SAID KWAIRYO I WAS NOT JOKING
# --------
# snt51
# INP: p3oapozp3a51attuu2uuhpaokloqpji919ohap3om
# REF: THE TENTH OF AUGUST ELECTRIFIES THEM
# HYP: THE TENTH OF AUGUST ELECTRIFIES THEN
# --------
# snt168
# INP: 5zoa-1uuttjipojia65uuzyha51avuuppojiah94attzq3579oh
# REF: ONE QUARTER POUNDS OF BUTTER SIX ANCHOVIES
# HYP: ONE QUARTER POUNDS OF BUTTER SIX ANCHOVIES
# --------
# snt140
# INP: 89p3aqji565kloa8ojioam9z2kloyattzya05hpkloya5zap3oahptt9jiqttho
# REF: WITH CROPOLE WERE MINGLED AND JOSTLED ON THE STAIRCASE
# HYP: WITH CROPOLE WERE MINGLED AND JOSTLED ON THE STAIRCAS
# --------
# snt137
# INP: m9hhuuhaqfzap39ttaq53ozam9hhamap9klyozavuujiji9pp
# REF: MISSUS CYN THIA COHEN MISS M TILDEN BURRITT
# HYP: MISSUS CY  THIA COHEN MISS M TILDEN BURRITTTTTTTTTTTTTTTTT
# --------
# snt117
# INP: p3o9jia2jittzy1ttp3ojiap3oa6ji56ji9op5jia51ap3oakl97ojifahpttvklo
# REF: THEIR GRANDFATHER THE PROPRIETOR OF THE LIVERY STABLE
# HYP: THEIR GRANDFATHER THE PROPRIETOR OF THE LIVERY STABLE
# --------
# snt22
# INP: f5uuay5axnz58ao7ojifp39z2a51aq5uujiho
# REF: YOU DO KNOW EVERYTHING OF COURSE
# HYP: YOU DO KNOW EVERYTHING OF COURSE
# --------
# snt112
# INP: 8oa3ttyavjiottxn1tthpa9zap3oaptt7ojizaxn9pq3oz
# REF: WE HAD BREAKFAST IN THE TAVERN KITCHEN
# HYP: WE HAD BREAKFAST IN THE TAVERN KITCHEN
# --------
# snt13
# INP: tthap3oa891oa51attamtthpojia51a35uuzyh
# REF: AS THE WIFE OF A MASTER OF HOUNDS
# HYP: AS THE WIFE OF A MASTER OF HOUNDS
# --------
# snt157
# INP: p3oaklttz2uutt2oaf5uua3tt7oap35uu23pa6ji56ojiap5aom6kl5f
# REF: THE LANGUAGE YOU HAVE THOUGHT PROPER TO EMPLOY
# HYP: JUST PASSIVELY AFRAID QUESTION
# --------
# snt177
# INP: ttzyaz58ap3ttpa9a8tthauuzyojiap3oaklooa51ap3oa8ttklkl
# REF: AND NOW THAT I WAS UNDER THE LEE OF THE WALL
# HYP: AND NOW THAT I WAS UNDER THE LEE OF THE WALL
# --------
# snt120
# INP: ttzyahz58a2522kloha1ji5may5qp5jiahq3ttzs
# REF: AND SNOW GOGGLES FROM DOCTOR SCHANZ
# HYP: AND SNOW GOGGLES FROM DOCTOR SCHANZ
# --------
# snt10
# INP: mfa255yzohha83fay9yzrpaf5uuahttfah5a9aqji9oy
# REF: MY GOODNESS WHY DIDN'T YOU SAY SO I CRIED
# HYP: MY GOODNESS WHY DIDN'T YOU SAY SO I CRIED
# --------
# snt164
# INP: 8ttha79h9vkloa1ji5map3oa39klkla8orklklaquupattqji5hhap35hoa19oklyh
# REF: WAS VISIBLE FROM THE HILL WE'LL CUT ACROSS THOSE FIELDS
# HYP: WAS VISIBLE FROM THE HILL WE'LL WUT ACROSS THOSE FIELDS
# --------
# snt81
# INP: ttzyap3ofavuuji9oya39ma9zap3oaq9pfa51aytt79y
# REF: AND THEY BURIED HIM IN THE CITY OF DAVID
# HYP: AND THEY BURIED HIM IN THE CITY OF DAVID
# --------
# snt68
# INP: 835a8tthattkljiottyfatthkloo6a9zavoy
# REF: WHO WAS ALREADY ASLEEP IN BED
# HYP: WHO WAS ALREADY ASLEEP IN BED
# --------
# snt78
# INP: voqttuuhoap3oa5ji919qohap3ji5uu23a839q3ap3ofa6tthhattjioa89yo
# REF: BECAUSE THE ORIFICES THROUGH WHICH THEY PASS ARE WIDE
# HYP: BECAUSE THE ORIFICES THROUGH WHICH THEY PASS ARE WIDE
# --------
# snt23
# INP: ttklkla3ttyattza9zttkl9ozttvkloaji923pa51a65hhohh95z
# REF: ALL HAD AN INALIENABLE RIGHT OF POSSESSION
# HYP: ALL HAD AN INALIENABLE RIGHT OF POSSESSION
# --------
# snt187
# INP: p3oamtt29hpjittpoa3ttyah8ttfoya15ji8ttjiy
# REF: THE MAGISTRATE HAD SWAYED FORWARD
# HYP: THE MAGISTRATE HAD SWAYED FORWAR
# --------
# snt173
# INP: ttzyah5akl5z2attha5zoa2tt9zhah5mop39z2ap3ojioa9haz5p39z2akl5hp
# REF: AND SO LONG AS ONE GAINS SOMETHING THERE IS NOTHING LOST
# HYP: AND SO LONG AS ONE GAINS SOMETHING THERE IS NOTHING TOST
# --------
# snt65
# INP: 89p3attavjittzyfav5ppkloauuzyojia3ojiatt6ji5zahpottkl9z2auu6ahptt9jih
# REF: WITH A BRANDY BOTTLE UNDER HER APRON STEALING UP STAIRS
# HYP: WITH A BRANDY BOTTLE UNDER HER APRON STEALING UP STAIR
# --------
# snt183
# INP: ttam9hhuuhamojiqfahm9p3avoqxn5zoyap5amoap5aq5moap5a3ojiaqkltthh
# REF: A MISSUS MERCY SMITH BECKONED TO ME TO COME TO HER CLASS
# HYP: A MISSUS MERCY SMITH BECKONED TO ME TO COME TO HER CLAS
# --------
# snt153
# INP: ttzya9ah3ttklklavoq5moa-1uu9poa8oklklatt2tt9zatthavo15jioattpa19jihp
# REF: AND I SHALL BECOME QUITE WELL AGAIN AS BEFORE AT FIRST
# HYP: AND I SHALL BECOME QUITE WELL AGAIN AS BEFORE AT FIR
# --------
# snt2
# INP: ttha3oajioqttklkloyahuuq3oprhahttf9z2attpahttjitt25hhtt
# REF: AS HE RECALLED SUCHET'S SAYING AT SARAGOSSA
# HYP: AS HE RECALLED SUCHET'S SAYING AT SARAGOSSSGOOSSSSS
# --------
# snt71
# INP: ttzyayjiohhoya9zattza5klyahpttvkloahuu9pa51aqkl5p3ohap3oa6otthttzp
# REF: AND DRESSED IN AN OLD STABLE SUIT OF CLOTHES THE PEASANT
# HYP: AND DRESSED IN AN OLD STABLE SUIT OF CLOTHES THE PEASANT
# --------
# snt8
# INP: ttzya358am923paf5uuaklottjizavfattqq9yozpa5jiattji2uumozp
# REF: AND HOW MIGHT YOU LEARN BY ACCIDENT OR ARGUMENT
# HYP: AND HOW MIGHT YOU LEARN BY ACCIDENT OR ARGUMENT
# --------
# snt53
# INP: 89p3ap3oay92z9pfa51attam5zttjiq3attzyap3oatt9jia51atta1ttp3oji
# REF: WITH THE DIGNITY OF A MONARCH AND THE AIR OF A FATHER
# HYP: WITH THE DIGNITY OF A MONARCH AND THE AIR OF A FATHER
# --------
# snt54
# INP: ttzyap3oa835kloa51azo8avjiuuzh89qxna8ojioa5qquu69oy
# REF: AND THE WHOLE OF NEW BRUNSWICK WERE OCCUPIED
# HYP: AND THE WHOLE OF NEW BRUNSWICK WERE OCCUPIED
# --------
# snt109
# INP: 3oakl57oyap5a3tt7oap3oaqkl5p3akltt9y
# REF: HE LOVED TO HAVE THE CLOTH LAID
# HYP: HE LOVED TO HAVE THE CLOTH LAID
# --------
# snt136
# INP: pojiohtta8tthah94poozattzya7ttm6ttaho7ozpooz
# REF: TERESA WAS SIXTEEN AND VAMPA SEVENTEEN
# HYP: TERESA WAS SIXTEEN AND VAMPA SEVENTEEN TEE
# --------
# snt152
# INP: 39ha3ottjipattqp95za9ha6jioppfa8ottxnao7ozafop
# REF: HIS HEART ACTION IS PRETTY WEAK EVEN YET
# HYP: HIS HEART ACTION IS PRETTY WEAK EVEN YETTY
# --------
# snt103
# INP: 2ooa2ooap3oa1ji52a3566oyaho7ojittklap9moh
# REF: GEE GEE THE FROG HOPPED SEVERAL TIMES
# HYP: GEE GEE THE FROG HOPPED SEVERAL TIME
# --------
# 100% 2/2 [00:00<00:00,  2.08it/s]
# speechbrain.utils.train_logger - Epoch loaded: 50 - test loss: 6.52e-02

# %% [markdown]
# At test time, we print both hypotheses and references. If everything works well, you should have learned a very plausible translation from Ingnotush to English:

# %% [markdown]
# ```
# snt136
# INP: pojiohtta8tthah94poozattzya7ttm6ttaho7ozpooz
# REF: TERESA WAS SIXTEEN AND VAMPA SEVENTEEN
# HYP: TERESA WAS SIXTEEN AND VAMPA SEVENTEEN
# --------
# snt152
# INP: 39ha3ottjipattqp95za9ha6jioppfa8ottxnao7ozafop
# epoch: 28, lr: 5.04e-03 - train loss: 3.57e-02 - valid loss: 2.55e-02
# epoch: 29, lr: 4.86e-03 - train loss: 3.45e-02 - valid loss: 2.48e-02
# epoch: 30, lr: 4.67e-03 - train loss: 3.40e-02 - valid loss: 2.41e-02
# epoch: 31, lr: 4.49e-03 - train loss: 2.88e-02 - valid loss: 2.13e-02
# epoch: 32, lr: 4.31e-03 - train loss: 3.01e-02 - valid loss: 2.03e-02
# epoch: 33, lr: 4.12e-03 - train loss: 3.11e-02 - valid loss: 2.36e-02
# epoch: 34, lr: 3.94e-03 - train loss: 2.63e-02 - valid loss: 2.00e-02
# epoch: 35, lr: 3.76e-03 - train loss: 2.51e-02 - valid loss: 2.31e-02
# epoch: 36, lr: 3.57e-03 - train loss: 2.32e-02 - valid loss: 2.09e-02
# epoch: 37, lr: 3.39e-03 - train loss: 2.09e-02 - valid loss: 1.98e-02
# epoch: 38, lr: 3.20e-03 - train loss: 1.98e-02 - valid loss: 1.86e-02
# epoch: 39, lr: 3.02e-03 - train loss: 1.94e-02 - valid loss: 1.81e-02
# epoch: 40, lr: 2.84e-03 - train loss: 1.82e-02 - valid loss: 2.12e-02
# epoch: 41, lr: 2.65e-03 - train loss: 1.63e-02 - valid loss: 1.88e-02
# epoch: 42, lr: 2.47e-03 - train loss: 1.61e-02 - valid loss: 1.79e-02
# epoch: 43, lr: 2.29e-03 - train loss: 1.51e-02 - valid loss: 1.49e-02
# epoch: 44, lr: 2.10e-03 - train loss: 1.41e-02 - valid loss: 1.71e-02
# epoch: 45, lr: 1.92e-03 - train loss: 1.42e-02 - valid loss: 1.71e-02
# epoch: 46, lr: 1.73e-03 - train loss: 1.32e-02 - valid loss: 1.60e-02
# epoch: 47, lr: 1.55e-03 - train loss: 1.24e-02 - valid loss: 1.56e-02
# epoch: 48, lr: 1.37e-03 - train loss: 1.50e-02 - valid loss: 1.56e-02
# epoch: 49, lr: 1.18e-03 - train loss: 1.23e-02 - valid loss: 1.49e-02
# epoch: 50, lr: 1.00e-03 - train loss: 1.19e-02 - valid loss: 1.46e-02
# Epoch loaded: 50 - test loss: 2.90e-02
# ```

# %% [markdown]
# Note that variations to the performance are expected. The most important thing is to get a good test loss (e.g., < 4.00e-02).
#
# We can now plot the training and validation losses stored in the log file.
#
# **Complete the code below** to plot the training and validation curves.

# %%
import matplotlib.pyplot as plt

def get_losses(log_file):
  """This function takes in input a path of a log-file and outputs the train and
  valid losses in lists of float numbers"""
  train_losses = []
  valid_losses = []

  with open(log_file, 'r') as f:
    for line in f:
      if 'train loss' and 'valid loss' in line:
        valid_losses.append(float(line.split()[-1]))
        train_losses.append(float(line.split()[-5]))


  # Add a return statement to return the losses
  return train_losses, valid_losses # This line was added to fix the error


log_file = 'results/RNN/1986/train_log.txt'
train_losses, valid_losses = get_losses(log_file)

plt.plot(train_losses, label='train')
plt.plot(valid_losses, label='valid')
plt.ylabel('Loss')
plt.xlabel('# Epochs')
plt.legend()
plt.show()

# %% [markdown]
# You should get something like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
